# %%
import yfinance as yf
import numpy as np
import pandas as pd
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback
import pandas_ta as ta
from sklearn.preprocessing import StandardScaler

# ------------------------------
# 1. Tải và xử lý dữ liệu MSFT
# ------------------------------
# df = yf.download("MSFT", start="2010-01-01", end="2025-06-30")
# if isinstance(df.columns, pd.MultiIndex):
#     df.columns = df.columns.droplevel(1)
# df = df.reset_index()
df = pd.read_csv("stock_best_1y.csv")
df = df[['Date', 'Close', 'High', 'Low', 'Open', 'Volume']]
df.columns.name = None

# Tính chỉ báo kỹ thuật
# This automatically calculates RSI and adds a new column named 'RSI_14'
df.ta.rsi(length=14, append=True)
# This calculates EMA and adds a new column named 'EMA_14'
df.ta.ema(length=14, append=True)
# ✅ ADD THIS LINE TO FIX THE ERROR
df.rename(columns={'RSI_14': 'RSI', 'EMA_14': 'EMA'}, inplace=True)
# Clean up the DataFrame
df = df.dropna().reset_index(drop=True)

# Chuẩn hóa dữ liệu
scaler = StandardScaler()
df[['Close', 'Open', 'High', 'Low', 'Volume', 'RSI', 'EMA']] = scaler.fit_transform(
    df[['Close', 'Open', 'High', 'Low', 'Volume', 'RSI', 'EMA']]
)

# Lưu giá trị gốc của Close để tính toán giao dịch
df['Close_raw'] = df['Close'].copy()  # Placeholder, will be replaced with actual scaling reversal

# ------------------------------
# 2. Môi trường RL tùy chỉnh
# ------------------------------
class StockTradingEnv(gym.Env):
    def __init__(self, df):
        super(StockTradingEnv, self).__init__()
        self.df = df
        self.max_steps = len(df)

        # Action: 0-4: BUY (19%-51%), 5-9: SELL (50%-79%)
        self.action_space = spaces.Discrete(10)
        self.buy_pcts = np.linspace(0.24, 0.53, 5)  # [19%, 27.25%, 35.5%, 43.75%, 51%]
        self.sell_pcts = np.linspace(0.22, 0.73, 5)  # [50%, 57.25%, 64.5%, 71.75%, 79%]

        # Quan sát: [cash, stock_owned, close, moving_avg, volume, RSI, EMA]
        self.observation_space = spaces.Box(
            low=np.array([-5000, 0, -np.inf, -np.inf, -np.inf, -np.inf, -np.inf]),
            high=np.array([np.inf, np.inf, np.inf, np.inf, np.inf, np.inf, np.inf]),
            shape=(7,),
            dtype=np.float32
        )

        # Luật giao dịch
        self.init_cash = 100_000
        self.transaction_fee = 0.03
        self.penalty_sessions = 25
        self.penalty_fee = 3981
        self.total_asset_min = 1000
        self.cash_min = -5000
        self.win_threshold = 1_000_000
        self.scaler = scaler  # Store scaler for reversing normalization

    def reset(self):
        self.step_idx = 0
        self.cash = self.init_cash
        self.stock_owned = 0
        self.last_trade_step = 0
        self.prev_total_asset = self.cash  # Track previous portfolio value
        return self._get_obs()

    def _get_obs(self):
        row = self.df.iloc[self.step_idx]
        moving_avg = self.df['Close'].iloc[max(0, self.step_idx-5):self.step_idx+1].mean()
        return np.array([
            self.cash,
            self.stock_owned,
            row['Close'],
            moving_avg,
            row['Volume'],
            row['RSI'],
            row['EMA']
        ], dtype=np.float32)

    def step(self, action):
        done = False
        traded = False
        price_scaled = self.df['Close'][self.step_idx]
        # Reverse normalization to get raw price for transaction
        price_raw = price_scaled * self.scaler.scale_[df.columns.get_loc('Close')] + self.scaler.mean_[df.columns.get_loc('Close')]
        reward = 0

        # Tính giá trị danh mục trước khi thực hiện hành động
        self.prev_total_asset = self.cash + self.stock_owned * price_raw

        # Buy
        if action <= 4:
            pct = self.buy_pcts[action]
            budget = pct * self.cash
            if self.cash > 0:
                max_affordable = self.cash / (1 + self.transaction_fee)  # Max spendable after fee
                quantity = min(budget / price_raw, max_affordable / price_raw)
                cost = quantity * price_raw * (1 + self.transaction_fee)
                if cost <= self.cash:
                    self.cash -= cost
                    self.stock_owned += quantity
                    traded = True
                else:
                    reward -= 10  # Penalty for insufficient cash
            else:
                reward -= 10  # Penalty for invalid buy

        # Sell
        elif action >= 5 and self.stock_owned > 0:
            pct = self.sell_pcts[action - 5]
            quantity = pct * self.stock_owned
            if quantity > 0:
                revenue = quantity * price_raw * (1 - self.transaction_fee)
                self.cash += revenue
                self.stock_owned -= quantity
                traded = True
            else:
                reward -= 10  # Penalty for zero quantity
        elif action >= 5 and self.stock_owned == 0:
            reward -= 10  # Penalty for selling without shares

        # Phạt nếu không giao dịch quá lâu
        if traded:
            self.last_trade_step = self.step_idx
        elif self.step_idx - self.last_trade_step >= self.penalty_sessions:
            self.cash -= self.penalty_fee
            reward -= self.penalty_fee

        # Tính giá trị danh mục sau hành động
        total_asset = self.cash + self.stock_owned * price_raw
        reward += (total_asset - self.prev_total_asset) / self.init_cash  # Normalized reward

        # Điều kiện kết thúc
        self.step_idx += 1
        if self.step_idx >= self.max_steps - 1:
            done = True
        elif total_asset < self.total_asset_min or self.cash < self.cash_min:
            reward -= 1000
            done = True
        elif total_asset >= self.win_threshold:
            reward += 1000
            done = True

        return self._get_obs(), reward, done, {}

# ------------------------------
# 3. Callback để log huấn luyện
# ------------------------------
class LoggerCallback(BaseCallback):
    def __init__(self, env, verbose=1):
        super().__init__(verbose)
        self.env_ref = env
        self.last_step = 0

    def _on_step(self):
        step = self.num_timesteps
        if step - self.last_step >= 1000:
            self.last_step = step
            cash = self.env_ref.cash
            stock_val = self.env_ref.stock_owned * (self.env_ref.df['Close'][self.env_ref.step_idx] * self.env_ref.scaler.scale_[self.env_ref.df.columns.get_loc('Close')] + self.env_ref.scaler.mean_[self.env_ref.df.columns.get_loc('Close')])
            total_asset = cash + stock_val
            print(f"\n📊 Step {step} | Action: {self.locals['actions']} | Cash: ${cash:,.2f} | Stocks: ${stock_val:,.2f} | Total: ${total_asset:,.2f}")
        return True

# ------------------------------
# 4. Train PPO Agent
# ------------------------------
env = StockTradingEnv(df)
callback = LoggerCallback(env)

model = PPO(
    "MlpPolicy",
    env,
    verbose=1,
    learning_rate=1e-4,
    batch_size=64,
    n_steps=2048,
    gamma=0.99,
    tensorboard_log="./tensorboard_logs"
)

model.learn(total_timesteps=1_000_000, callback=callback)
model.save("ppo_msft_trader")
print("✅ Huấn luyện hoàn tất!")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# c:\Users\Hi\anaconda3\envs\all\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Logging to ./tensorboard_logs\PPO_1
#
# 📊 Step 1000 | Action: [7] | Cash: $49,737.23 | Stocks: $23,653.47 | Total: $73,390.70
#
# 📊 Step 2000 | Action: [6] | Cash: $53,524.76 | Stocks: $619.40 | Total: $54,144.16
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 236      |
# |    ep_rew_mean     | -14.6    |
# | time/              |          |
# |    fps             | 821      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
#
# 📊 Step 3000 | Action: [8] | Cash: $24,955.19 | Stocks: $14,167.60 | Total: $39,122.79
#
# 📊 Step 4000 | Action: [1] | Cash: $9,844.51 | Stocks: $19,132.10 | Total: $28,976.61
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -13.8       |
# | time/                   |             |
# |    fps                  | 558         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.006909198 |
# |    clip_fraction        | 0.0589      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | -0.00226    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0115     |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00558    |
# |    value_loss           | 5.77        |
# -----------------------------------------
#
# 📊 Step 5000 | Action: [0] | Cash: $34,478.33 | Stocks: $46,524.43 | Total: $81,002.76
#
# 📊 Step 6000 | Action: [1] | Cash: $27,028.39 | Stocks: $28,547.73 | Total: $55,576.13
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -12.4       |
# | time/                   |             |
# |    fps                  | 501         |
# |    iterations           | 3           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010682006 |
# |    clip_fraction        | 0.0496      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | -0.00142    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.93        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00703    |
# |    value_loss           | 0.907       |
# -----------------------------------------
#
# 📊 Step 7000 | Action: [2] | Cash: $17,973.66 | Stocks: $30,109.59 | Total: $48,083.25
#
# 📊 Step 8000 | Action: [4] | Cash: $14,483.99 | Stocks: $22,579.10 | Total: $37,063.08
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -11.4       |
# | time/                   |             |
# |    fps                  | 480         |
# |    iterations           | 4           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009160159 |
# |    clip_fraction        | 0.0276      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | -0.00187    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0231     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00439    |
# |    value_loss           | 0.481       |
# -----------------------------------------
#
# 📊 Step 9000 | Action: [1] | Cash: $29,698.55 | Stocks: $60,710.41 | Total: $90,408.96
#
# 📊 Step 10000 | Action: [2] | Cash: $10,060.20 | Stocks: $60,626.01 | Total: $70,686.20
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -11.3       |
# | time/                   |             |
# |    fps                  | 462         |
# |    iterations           | 5           |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.011656603 |
# |    clip_fraction        | 0.0761      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.23       |
# |    explained_variance   | 5.77e-05    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0329     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.00857    |
# |    value_loss           | 2.14        |
# -----------------------------------------
#
# 📊 Step 11000 | Action: [5] | Cash: $37,986.17 | Stocks: $18,235.61 | Total: $56,221.78
#
# 📊 Step 12000 | Action: [1] | Cash: $5,152.00 | Stocks: $28,985.07 | Total: $34,137.07
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 236        |
# |    ep_rew_mean          | -10.8      |
# | time/                   |            |
# |    fps                  | 451        |
# |    iterations           | 6          |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00840303 |
# |    clip_fraction        | 0.0302     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.19      |
# |    explained_variance   | -0.000225  |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0182     |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00353   |
# |    value_loss           | 0.617      |
# ----------------------------------------
#
# 📊 Step 13000 | Action: [8] | Cash: $60,865.66 | Stocks: $28,338.84 | Total: $89,204.50
#
# 📊 Step 14000 | Action: [5] | Cash: $40,802.70 | Stocks: $32,516.76 | Total: $73,319.46
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -9.67       |
# | time/                   |             |
# |    fps                  | 455         |
# |    iterations           | 7           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011201175 |
# |    clip_fraction        | 0.0849      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.11       |
# |    explained_variance   | -0.00246    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0189     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00937    |
# |    value_loss           | 0.434       |
# -----------------------------------------
#
# 📊 Step 15000 | Action: [0] | Cash: $4,692.59 | Stocks: $58,927.08 | Total: $63,619.68
#
# 📊 Step 16000 | Action: [4] | Cash: $815.29 | Stocks: $56,499.46 | Total: $57,314.75
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -8.51       |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 8           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.011042416 |
# |    clip_fraction        | 0.0523      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.08       |
# |    explained_variance   | -0.00931    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0442     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.00643    |
# |    value_loss           | 0.0523      |
# -----------------------------------------
#
# 📊 Step 17000 | Action: [2] | Cash: $22,809.71 | Stocks: $73,070.05 | Total: $95,879.76
#
# 📊 Step 18000 | Action: [0] | Cash: $2,931.61 | Stocks: $81,844.49 | Total: $84,776.10
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -8.39       |
# | time/                   |             |
# |    fps                  | 456         |
# |    iterations           | 9           |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.012333427 |
# |    clip_fraction        | 0.0725      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | -0.00746    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0387     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.00807    |
# |    value_loss           | 0.0522      |
# -----------------------------------------
#
# 📊 Step 19000 | Action: [4] | Cash: $9,771.53 | Stocks: $66,687.09 | Total: $76,458.62
#
# 📊 Step 20000 | Action: [1] | Cash: $4,996.45 | Stocks: $65,456.22 | Total: $70,452.67
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -8.02       |
# | time/                   |             |
# |    fps                  | 453         |
# |    iterations           | 10          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012812627 |
# |    clip_fraction        | 0.0541      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.96       |
# |    explained_variance   | -0.000561   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00667    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00718    |
# |    value_loss           | 0.519       |
# -----------------------------------------
#
# 📊 Step 21000 | Action: [0] | Cash: $7,575.32 | Stocks: $56,559.94 | Total: $64,135.26
#
# 📊 Step 22000 | Action: [2] | Cash: $8,007.74 | Stocks: $80,924.54 | Total: $88,932.28
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -7.43       |
# | time/                   |             |
# |    fps                  | 445         |
# |    iterations           | 11          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013241313 |
# |    clip_fraction        | 0.0917      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.87       |
# |    explained_variance   | -0.00112    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0266     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00872    |
# |    value_loss           | 0.285       |
# -----------------------------------------
#
# 📊 Step 23000 | Action: [3] | Cash: $125.51 | Stocks: $88,771.12 | Total: $88,896.63
#
# 📊 Step 24000 | Action: [2] | Cash: $8,138.62 | Stocks: $78,612.50 | Total: $86,751.13
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 236        |
# |    ep_rew_mean          | -6.78      |
# | time/                   |            |
# |    fps                  | 443        |
# |    iterations           | 12         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01566302 |
# |    clip_fraction        | 0.16       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.72      |
# |    explained_variance   | -0.00642   |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.00652    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0146    |
# |    value_loss           | 0.0521     |
# ----------------------------------------
#
# 📊 Step 25000 | Action: [0] | Cash: $29,128.78 | Stocks: $36,402.35 | Total: $65,531.13
#
# 📊 Step 26000 | Action: [1] | Cash: $9,544.87 | Stocks: $84,602.67 | Total: $94,147.53
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -5.76       |
# | time/                   |             |
# |    fps                  | 439         |
# |    iterations           | 13          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010850873 |
# |    clip_fraction        | 0.0751      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | -0.00396    |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.0319      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.00987    |
# |    value_loss           | 0.101       |
# -----------------------------------------
#
# 📊 Step 27000 | Action: [8] | Cash: $76,241.92 | Stocks: $22,302.40 | Total: $98,544.32
#
# 📊 Step 28000 | Action: [2] | Cash: $669.90 | Stocks: $76,185.64 | Total: $76,855.55
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -4.83       |
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 14          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.011085942 |
# |    clip_fraction        | 0.0559      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.5        |
# |    explained_variance   | -0.000739   |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00663    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00733    |
# |    value_loss           | 0.236       |
# -----------------------------------------
#
# 📊 Step 29000 | Action: [3] | Cash: $16,034.86 | Stocks: $68,419.66 | Total: $84,454.52
#
# 📊 Step 30000 | Action: [9] | Cash: $72,784.66 | Stocks: $27,066.66 | Total: $99,851.32
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -4.5        |
# | time/                   |             |
# |    fps                  | 441         |
# |    iterations           | 15          |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.013831296 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.0114     |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00599    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 0.0513      |
# -----------------------------------------
#
# 📊 Step 31000 | Action: [0] | Cash: $28,829.90 | Stocks: $77,812.09 | Total: $106,642.00
#
# 📊 Step 32000 | Action: [1] | Cash: $9,340.22 | Stocks: $77,219.27 | Total: $86,559.49
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -3.38        |
# | time/                   |              |
# |    fps                  | 440          |
# |    iterations           | 16           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0032800317 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.31        |
# |    explained_variance   | -0.165       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0206      |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00653     |
# |    value_loss           | 0.00185      |
# ------------------------------------------
#
# 📊 Step 33000 | Action: [0] | Cash: $14,183.03 | Stocks: $82,619.30 | Total: $96,802.33
#
# 📊 Step 34000 | Action: [0] | Cash: $673.12 | Stocks: $99,618.81 | Total: $100,291.93
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -2.65        |
# | time/                   |              |
# |    fps                  | 437          |
# |    iterations           | 17           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0069947923 |
# |    clip_fraction        | 0.0426       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | -0.186       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0308      |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0066      |
# |    value_loss           | 0.0014       |
# ------------------------------------------
#
# 📊 Step 35000 | Action: [0] | Cash: $695.56 | Stocks: $112,257.26 | Total: $112,952.82
#
# 📊 Step 36000 | Action: [0] | Cash: $12,576.38 | Stocks: $97,162.25 | Total: $109,738.63
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -2.31        |
# | time/                   |              |
# |    fps                  | 442          |
# |    iterations           | 18           |
# |    time_elapsed         | 83           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0050697345 |
# |    clip_fraction        | 0.0458       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | -0.251       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.00201      |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00486     |
# |    value_loss           | 0.00138      |
# ------------------------------------------
#
# 📊 Step 37000 | Action: [4] | Cash: $17,854.94 | Stocks: $87,829.02 | Total: $105,683.96
#
# 📊 Step 38000 | Action: [0] | Cash: $32,115.78 | Stocks: $65,753.80 | Total: $97,869.58
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -2.28       |
# | time/                   |             |
# |    fps                  | 442         |
# |    iterations           | 19          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.006006433 |
# |    clip_fraction        | 0.0529      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | -0.00826    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00289    |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0064     |
# |    value_loss           | 0.0505      |
# -----------------------------------------
#
# 📊 Step 39000 | Action: [0] | Cash: $1,234.85 | Stocks: $103,541.31 | Total: $104,776.16
#
# 📊 Step 40000 | Action: [0] | Cash: $3,566.66 | Stocks: $98,999.51 | Total: $102,566.17
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -2.05       |
# | time/                   |             |
# |    fps                  | 440         |
# |    iterations           | 20          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.004265162 |
# |    clip_fraction        | 0.0292      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | -0.00338    |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00303    |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.00652    |
# |    value_loss           | 0.0502      |
# -----------------------------------------
#
# 📊 Step 41000 | Action: [0] | Cash: $1,569.51 | Stocks: $114,506.16 | Total: $116,075.66
#
# 📊 Step 42000 | Action: [0] | Cash: $10,567.40 | Stocks: $89,422.28 | Total: $99,989.68
#
# 📊 Step 43000 | Action: [5] | Cash: $22,667.01 | Stocks: $83,221.11 | Total: $105,888.11
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -1.61        |
# | time/                   |              |
# |    fps                  | 437          |
# |    iterations           | 21           |
# |    time_elapsed         | 98           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0034244852 |
# |    clip_fraction        | 0.0135       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.99        |
# |    explained_variance   | -0.642       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.00355      |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00297     |
# |    value_loss           | 0.000787     |
# ------------------------------------------
#
# 📊 Step 44000 | Action: [0] | Cash: $956.96 | Stocks: $102,637.73 | Total: $103,594.69
#
# 📊 Step 45000 | Action: [0] | Cash: $639.69 | Stocks: $120,930.32 | Total: $121,570.01
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -1.29       |
# | time/                   |             |
# |    fps                  | 437         |
# |    iterations           | 22          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.003100128 |
# |    clip_fraction        | 0.0223      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.936      |
# |    explained_variance   | -0.605      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00979    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00454    |
# |    value_loss           | 0.000849    |
# -----------------------------------------
#
# 📊 Step 46000 | Action: [0] | Cash: $21,737.49 | Stocks: $78,698.12 | Total: $100,435.61
#
# 📊 Step 47000 | Action: [0] | Cash: $26,945.35 | Stocks: $76,906.42 | Total: $103,851.77
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -1.06        |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 23           |
# |    time_elapsed         | 107          |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0037433356 |
# |    clip_fraction        | 0.0279       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.897       |
# |    explained_variance   | -0.413       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.024        |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00644     |
# |    value_loss           | 0.000646     |
# ------------------------------------------
#
# 📊 Step 48000 | Action: [0] | Cash: $23,386.98 | Stocks: $95,622.83 | Total: $119,009.80
#
# 📊 Step 49000 | Action: [0] | Cash: $1,265.95 | Stocks: $100,522.11 | Total: $101,788.07
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.939       |
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 24           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0038814275 |
# |    clip_fraction        | 0.0437       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.861       |
# |    explained_variance   | -0.121       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00504     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00623     |
# |    value_loss           | 0.000675     |
# ------------------------------------------
#
# 📊 Step 50000 | Action: [0] | Cash: $357.58 | Stocks: $106,449.27 | Total: $106,806.85
#
# 📊 Step 51000 | Action: [0] | Cash: $5,314.97 | Stocks: $99,167.67 | Total: $104,482.65
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.618       |
# | time/                   |              |
# |    fps                  | 433          |
# |    iterations           | 25           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0053871763 |
# |    clip_fraction        | 0.0711       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.822       |
# |    explained_variance   | -0.379       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00594     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00635     |
# |    value_loss           | 0.000648     |
# ------------------------------------------
#
# 📊 Step 52000 | Action: [0] | Cash: $18,115.41 | Stocks: $94,616.52 | Total: $112,731.93
#
# 📊 Step 53000 | Action: [0] | Cash: $6,409.81 | Stocks: $99,818.93 | Total: $106,228.74
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.599       |
# | time/                   |              |
# |    fps                  | 432          |
# |    iterations           | 26           |
# |    time_elapsed         | 123          |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0039018886 |
# |    clip_fraction        | 0.0554       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.725       |
# |    explained_variance   | -0.498       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0098      |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00757     |
# |    value_loss           | 0.000494     |
# ------------------------------------------
#
# 📊 Step 54000 | Action: [0] | Cash: $10,718.09 | Stocks: $103,397.60 | Total: $114,115.69
#
# 📊 Step 55000 | Action: [0] | Cash: $2,687.92 | Stocks: $94,970.34 | Total: $97,658.26
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.579       |
# | time/                   |              |
# |    fps                  | 431          |
# |    iterations           | 27           |
# |    time_elapsed         | 128          |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0039777104 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.695       |
# |    explained_variance   | -0.771       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0209      |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00472     |
# |    value_loss           | 0.000611     |
# ------------------------------------------
#
# 📊 Step 56000 | Action: [5] | Cash: $25,416.59 | Stocks: $91,255.58 | Total: $116,672.16
#
# 📊 Step 57000 | Action: [0] | Cash: $16,316.96 | Stocks: $97,398.34 | Total: $113,715.30
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.563       |
# | time/                   |              |
# |    fps                  | 429          |
# |    iterations           | 28           |
# |    time_elapsed         | 133          |
# |    total_timesteps      | 57344        |
# | train/                  |              |
# |    approx_kl            | 0.0042179055 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.659       |
# |    explained_variance   | -0.596       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0107      |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -0.00629     |
# |    value_loss           | 0.000558     |
# ------------------------------------------
#
# 📊 Step 58000 | Action: [3] | Cash: $560.71 | Stocks: $118,649.26 | Total: $119,209.97
#
# 📊 Step 59000 | Action: [0] | Cash: $100,000.00 | Stocks: $0.00 | Total: $100,000.00
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.548       |
# | time/                   |              |
# |    fps                  | 429          |
# |    iterations           | 29           |
# |    time_elapsed         | 138          |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0032325173 |
# |    clip_fraction        | 0.0382       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.636       |
# |    explained_variance   | -0.575       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0249      |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00779     |
# |    value_loss           | 0.000499     |
# ------------------------------------------
#
# 📊 Step 60000 | Action: [0] | Cash: $8,011.94 | Stocks: $100,892.83 | Total: $108,904.77
#
# 📊 Step 61000 | Action: [0] | Cash: $743.12 | Stocks: $104,047.17 | Total: $104,790.29
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.436       |
# | time/                   |              |
# |    fps                  | 429          |
# |    iterations           | 30           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0028955324 |
# |    clip_fraction        | 0.0246       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.61        |
# |    explained_variance   | -0.365       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.000682    |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00511     |
# |    value_loss           | 0.000534     |
# ------------------------------------------
#
# 📊 Step 62000 | Action: [0] | Cash: $105.42 | Stocks: $119,705.44 | Total: $119,810.86
#
# 📊 Step 63000 | Action: [0] | Cash: $37,017.21 | Stocks: $73,459.24 | Total: $110,476.45
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -0.323      |
# | time/                   |             |
# |    fps                  | 430         |
# |    iterations           | 31          |
# |    time_elapsed         | 147         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.002923605 |
# |    clip_fraction        | 0.0283      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.555      |
# |    explained_variance   | -0.298      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.86e-06    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00387    |
# |    value_loss           | 0.000412    |
# -----------------------------------------
#
# 📊 Step 64000 | Action: [0] | Cash: $8,243.17 | Stocks: $92,192.38 | Total: $100,435.54
#
# 📊 Step 65000 | Action: [5] | Cash: $22,338.01 | Stocks: $81,329.33 | Total: $103,667.34
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.313       |
# | time/                   |              |
# |    fps                  | 431          |
# |    iterations           | 32           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0019063313 |
# |    clip_fraction        | 0.0118       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.59        |
# |    explained_variance   | -0.141       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.0209      |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00458     |
# |    value_loss           | 0.000402     |
# ------------------------------------------
#
# 📊 Step 66000 | Action: [4] | Cash: $50.09 | Stocks: $112,808.91 | Total: $112,859.00
#
# 📊 Step 67000 | Action: [0] | Cash: $268.13 | Stocks: $112,812.12 | Total: $113,080.25
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 236        |
# |    ep_rew_mean          | -0.3       |
# | time/                   |            |
# |    fps                  | 431        |
# |    iterations           | 33         |
# |    time_elapsed         | 156        |
# |    total_timesteps      | 67584      |
# | train/                  |            |
# |    approx_kl            | 0.00260645 |
# |    clip_fraction        | 0.0274     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.574     |
# |    explained_variance   | -0.376     |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.00435   |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0043    |
# |    value_loss           | 0.000388   |
# ----------------------------------------
#
# 📊 Step 68000 | Action: [0] | Cash: $1,273.00 | Stocks: $105,905.41 | Total: $107,178.40
#
# 📊 Step 69000 | Action: [0] | Cash: $3,726.26 | Stocks: $116,667.63 | Total: $120,393.89
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -0.287      |
# | time/                   |             |
# |    fps                  | 431         |
# |    iterations           | 34          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.004258734 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.558      |
# |    explained_variance   | -0.39       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00377    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00488    |
# |    value_loss           | 0.000408    |
# -----------------------------------------
#
# 📊 Step 70000 | Action: [0] | Cash: $4,555.95 | Stocks: $109,382.02 | Total: $113,937.98
#
# 📊 Step 71000 | Action: [0] | Cash: $326.85 | Stocks: $115,159.19 | Total: $115,486.05
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -0.278      |
# | time/                   |             |
# |    fps                  | 432         |
# |    iterations           | 35          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.002093181 |
# |    clip_fraction        | 0.0137      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.519      |
# |    explained_variance   | -0.307      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00708    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00335    |
# |    value_loss           | 0.000364    |
# -----------------------------------------
#
# 📊 Step 72000 | Action: [4] | Cash: $9,972.42 | Stocks: $90,537.91 | Total: $100,510.33
#
# 📊 Step 73000 | Action: [0] | Cash: $1,091.20 | Stocks: $118,970.00 | Total: $120,061.20
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -0.269      |
# | time/                   |             |
# |    fps                  | 434         |
# |    iterations           | 36          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.004210828 |
# |    clip_fraction        | 0.0417      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.547      |
# |    explained_variance   | -0.244      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0311     |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00783    |
# |    value_loss           | 0.000286    |
# -----------------------------------------
#
# 📊 Step 74000 | Action: [0] | Cash: $8,257.23 | Stocks: $109,593.40 | Total: $117,850.62
#
# 📊 Step 75000 | Action: [1] | Cash: $7,965.51 | Stocks: $118,367.02 | Total: $126,332.54
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.26        |
# | time/                   |              |
# |    fps                  | 434          |
# |    iterations           | 37           |
# |    time_elapsed         | 174          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0028533775 |
# |    clip_fraction        | 0.0305       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.499       |
# |    explained_variance   | -0.243       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00474     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00514     |
# |    value_loss           | 0.000279     |
# ------------------------------------------
#
# 📊 Step 76000 | Action: [0] | Cash: $10,314.23 | Stocks: $88,444.09 | Total: $98,758.33
#
# 📊 Step 77000 | Action: [0] | Cash: $532.47 | Stocks: $112,873.89 | Total: $113,406.36
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -0.253      |
# | time/                   |             |
# |    fps                  | 436         |
# |    iterations           | 38          |
# |    time_elapsed         | 178         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.003587735 |
# |    clip_fraction        | 0.0379      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.515      |
# |    explained_variance   | -0.345      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0162     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00647    |
# |    value_loss           | 0.000309    |
# -----------------------------------------
#
# 📊 Step 78000 | Action: [0] | Cash: $567.68 | Stocks: $119,409.19 | Total: $119,976.88
#
# 📊 Step 79000 | Action: [3] | Cash: $1.03 | Stocks: $132,392.20 | Total: $132,393.22
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -0.247      |
# | time/                   |             |
# |    fps                  | 435         |
# |    iterations           | 39          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.002126499 |
# |    clip_fraction        | 0.0116      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.501      |
# |    explained_variance   | -0.522      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00516    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00237    |
# |    value_loss           | 0.000278    |
# -----------------------------------------
#
# 📊 Step 80000 | Action: [0] | Cash: $8,600.87 | Stocks: $117,536.03 | Total: $126,136.90
#
# 📊 Step 81000 | Action: [4] | Cash: $594.70 | Stocks: $107,387.11 | Total: $107,981.81
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.242       |
# | time/                   |              |
# |    fps                  | 436          |
# |    iterations           | 40           |
# |    time_elapsed         | 187          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0035009342 |
# |    clip_fraction        | 0.0407       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.463       |
# |    explained_variance   | -0.252       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00343     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0044      |
# |    value_loss           | 0.000248     |
# ------------------------------------------
#
# 📊 Step 82000 | Action: [4] | Cash: $119.84 | Stocks: $112,055.01 | Total: $112,174.85
#
# 📊 Step 83000 | Action: [0] | Cash: $3,364.90 | Stocks: $127,635.07 | Total: $130,999.97
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.238       |
# | time/                   |              |
# |    fps                  | 437          |
# |    iterations           | 41           |
# |    time_elapsed         | 192          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0015057343 |
# |    clip_fraction        | 0.0151       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.494       |
# |    explained_variance   | -0.464       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.000824     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00365     |
# |    value_loss           | 0.000224     |
# ------------------------------------------
#
# 📊 Step 84000 | Action: [0] | Cash: $368.84 | Stocks: $117,860.36 | Total: $118,229.20
#
# 📊 Step 85000 | Action: [0] | Cash: $1,309.69 | Stocks: $103,324.28 | Total: $104,633.98
#
# 📊 Step 86000 | Action: [0] | Cash: $8,563.78 | Stocks: $106,303.68 | Total: $114,867.46
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.234       |
# | time/                   |              |
# |    fps                  | 437          |
# |    iterations           | 42           |
# |    time_elapsed         | 196          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0021400847 |
# |    clip_fraction        | 0.0174       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.477       |
# |    explained_variance   | -0.936       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00395     |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00273     |
# |    value_loss           | 0.000187     |
# ------------------------------------------
#
# 📊 Step 87000 | Action: [0] | Cash: $10,373.78 | Stocks: $105,378.16 | Total: $115,751.94
#
# 📊 Step 88000 | Action: [5] | Cash: $24,416.48 | Stocks: $94,460.43 | Total: $118,876.91
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.228       |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 43           |
# |    time_elapsed         | 200          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0036258493 |
# |    clip_fraction        | 0.0314       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.51        |
# |    explained_variance   | -0.228       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0109       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00552     |
# |    value_loss           | 0.000183     |
# ------------------------------------------
#
# 📊 Step 89000 | Action: [0] | Cash: $5,406.59 | Stocks: $98,215.71 | Total: $103,622.30
#
# 📊 Step 90000 | Action: [0] | Cash: $6,076.66 | Stocks: $117,021.68 | Total: $123,098.33
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -0.225      |
# | time/                   |             |
# |    fps                  | 438         |
# |    iterations           | 44          |
# |    time_elapsed         | 205         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.003741846 |
# |    clip_fraction        | 0.0386      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.543      |
# |    explained_variance   | -0.285      |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00379    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00527    |
# |    value_loss           | 0.000185    |
# -----------------------------------------
#
# 📊 Step 91000 | Action: [0] | Cash: $3,547.82 | Stocks: $112,436.66 | Total: $115,984.48
#
# 📊 Step 92000 | Action: [0] | Cash: $3,445.73 | Stocks: $112,253.21 | Total: $115,698.93
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.221       |
# | time/                   |              |
# |    fps                  | 438          |
# |    iterations           | 45           |
# |    time_elapsed         | 210          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0033629981 |
# |    clip_fraction        | 0.0345       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.512       |
# |    explained_variance   | -0.114       |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00674     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0071      |
# ...
#
# 📊 Step 972000 | Action: [1] | Cash: $0.00 | Stocks: $128,276.43 | Total: $128,276.43
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.0295      |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 475          |
# |    time_elapsed         | 11903        |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0024138899 |
# |    clip_fraction        | 0.00972      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.628       |
# |    explained_variance   | 0.716        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.000718     |
# |    n_updates            | 4740         |
# |    policy_gradient_loss | -0.00188     |
# |    value_loss           | 2.37e-06     |
# ------------------------------------------
#
# 📊 Step 973000 | Action: [4] | Cash: $0.00 | Stocks: $134,231.39 | Total: $134,231.39
#
# 📊 Step 974000 | Action: [2] | Cash: $0.02 | Stocks: $105,182.57 | Total: $105,182.59
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 236        |
# |    ep_rew_mean          | -0.0294    |
# | time/                   |            |
# |    fps                  | 81         |
# |    iterations           | 476        |
# |    time_elapsed         | 11912      |
# |    total_timesteps      | 974848     |
# | train/                  |            |
# |    approx_kl            | 0.00443698 |
# |    clip_fraction        | 0.0536     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.64      |
# |    explained_variance   | 0.55       |
# |    learning_rate        | 0.0001     |
# |    loss                 | -0.00545   |
# |    n_updates            | 4750       |
# |    policy_gradient_loss | -0.00196   |
# |    value_loss           | 7.5e-06    |
# ----------------------------------------
#
# 📊 Step 975000 | Action: [4] | Cash: $0.00 | Stocks: $133,657.49 | Total: $133,657.49
#
# 📊 Step 976000 | Action: [4] | Cash: $0.00 | Stocks: $125,680.39 | Total: $125,680.39
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.129       |
# | time/                   |              |
# |    fps                  | 81           |
# |    iterations           | 477          |
# |    time_elapsed         | 11919        |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 0.0026866193 |
# |    clip_fraction        | 0.0122       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.652       |
# |    explained_variance   | 0.684        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0034       |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | -0.000792    |
# |    value_loss           | 2.21e-06     |
# ------------------------------------------
#
# 📊 Step 977000 | Action: [4] | Cash: $0.00 | Stocks: $139,815.12 | Total: $139,815.12
#
# 📊 Step 978000 | Action: [2] | Cash: $63.19 | Stocks: $100,342.12 | Total: $100,405.30
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.13        |
# | time/                   |              |
# |    fps                  | 82           |
# |    iterations           | 478          |
# |    time_elapsed         | 11923        |
# |    total_timesteps      | 978944       |
# | train/                  |              |
# |    approx_kl            | 0.0025652214 |
# |    clip_fraction        | 0.00928      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.717       |
# |    explained_variance   | 0.00244      |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.0024       |
# |    n_updates            | 4770         |
# |    policy_gradient_loss | -0.00195     |
# |    value_loss           | 0.0489       |
# ------------------------------------------
#
# 📊 Step 979000 | Action: [1] | Cash: $0.00 | Stocks: $125,821.99 | Total: $125,821.99
#
# 📊 Step 980000 | Action: [4] | Cash: $0.00 | Stocks: $131,278.72 | Total: $131,278.72
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -0.129      |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 479         |
# |    time_elapsed         | 11932       |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.007468337 |
# |    clip_fraction        | 0.0357      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.658      |
# |    explained_variance   | -4.52       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0053     |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.00309    |
# |    value_loss           | 4.07e-05    |
# -----------------------------------------
#
# 📊 Step 981000 | Action: [4] | Cash: $0.00 | Stocks: $141,830.10 | Total: $141,830.10
#
# 📊 Step 982000 | Action: [1] | Cash: $21,146.53 | Stocks: $76,352.77 | Total: $97,499.29
#
# 📊 Step 983000 | Action: [4] | Cash: $0.00 | Stocks: $115,651.79 | Total: $115,651.79
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 236        |
# |    ep_rew_mean          | -0.129     |
# | time/                   |            |
# |    fps                  | 82         |
# |    iterations           | 480        |
# |    time_elapsed         | 11938      |
# |    total_timesteps      | 983040     |
# | train/                  |            |
# |    approx_kl            | 0.03400825 |
# |    clip_fraction        | 0.148      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.833     |
# |    explained_variance   | -0.488     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 0.0146     |
# |    n_updates            | 4790       |
# |    policy_gradient_loss | -0.00266   |
# |    value_loss           | 4.59e-06   |
# ----------------------------------------
#
# 📊 Step 984000 | Action: [4] | Cash: $0.00 | Stocks: $127,224.86 | Total: $127,224.86
#
# 📊 Step 985000 | Action: [4] | Cash: $0.00 | Stocks: $149,999.52 | Total: $149,999.52
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -0.129      |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 481         |
# |    time_elapsed         | 11944       |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.004658754 |
# |    clip_fraction        | 0.0124      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.849      |
# |    explained_variance   | 0.596       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.0118     |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.00154    |
# |    value_loss           | 2.16e-06    |
# -----------------------------------------
#
# 📊 Step 986000 | Action: [4] | Cash: $0.00 | Stocks: $144,924.98 | Total: $144,924.98
#
# 📊 Step 987000 | Action: [4] | Cash: $0.00 | Stocks: $111,189.76 | Total: $111,189.76
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -0.129      |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 482         |
# |    time_elapsed         | 11950       |
# |    total_timesteps      | 987136      |
# | train/                  |             |
# |    approx_kl            | 0.003286777 |
# |    clip_fraction        | 0.00967     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.864      |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00147    |
# |    n_updates            | 4810        |
# |    policy_gradient_loss | -0.000584   |
# |    value_loss           | 1.72e-06    |
# -----------------------------------------
#
# 📊 Step 988000 | Action: [1] | Cash: $0.00 | Stocks: $121,903.95 | Total: $121,903.95
#
# 📊 Step 989000 | Action: [1] | Cash: $0.00 | Stocks: $147,269.90 | Total: $147,269.90
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -0.129      |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 483         |
# |    time_elapsed         | 11961       |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.001230174 |
# |    clip_fraction        | 0.00762     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.87       |
# |    explained_variance   | 0.751       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00141    |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.00288    |
# |    value_loss           | 1.52e-06    |
# -----------------------------------------
#
# 📊 Step 990000 | Action: [2] | Cash: $0.00 | Stocks: $137,404.23 | Total: $137,404.23
#
# 📊 Step 991000 | Action: [2] | Cash: $0.00 | Stocks: $108,311.55 | Total: $108,311.55
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.129       |
# | time/                   |              |
# |    fps                  | 82           |
# |    iterations           | 484          |
# |    time_elapsed         | 11975        |
# |    total_timesteps      | 991232       |
# | train/                  |              |
# |    approx_kl            | 0.0014674538 |
# |    clip_fraction        | 0.0333       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.793       |
# |    explained_variance   | 0.763        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.00418      |
# |    n_updates            | 4830         |
# |    policy_gradient_loss | -0.00131     |
# |    value_loss           | 1.71e-06     |
# ------------------------------------------
#
# 📊 Step 992000 | Action: [1] | Cash: $0.00 | Stocks: $132,211.76 | Total: $132,211.76
#
# 📊 Step 993000 | Action: [4] | Cash: $0.00 | Stocks: $124,060.66 | Total: $124,060.66
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -0.129      |
# | time/                   |             |
# |    fps                  | 82          |
# |    iterations           | 485         |
# |    time_elapsed         | 11987       |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.004087058 |
# |    clip_fraction        | 0.0264      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.846      |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 0.00137     |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.00163    |
# |    value_loss           | 1.66e-06    |
# -----------------------------------------
#
# 📊 Step 994000 | Action: [1] | Cash: $0.00 | Stocks: $138,877.90 | Total: $138,877.90
#
# 📊 Step 995000 | Action: [4] | Cash: $0.20 | Stocks: $106,125.22 | Total: $106,125.42
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.129       |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 486          |
# |    time_elapsed         | 11991        |
# |    total_timesteps      | 995328       |
# | train/                  |              |
# |    approx_kl            | 0.0038559595 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.772       |
# |    explained_variance   | 0.779        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.000171    |
# |    n_updates            | 4850         |
# |    policy_gradient_loss | -0.000344    |
# |    value_loss           | 1.45e-06     |
# ------------------------------------------
#
# 📊 Step 996000 | Action: [2] | Cash: $0.00 | Stocks: $127,082.89 | Total: $127,082.89
#
# 📊 Step 997000 | Action: [4] | Cash: $0.00 | Stocks: $126,632.66 | Total: $126,632.66
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 236         |
# |    ep_rew_mean          | -0.129      |
# | time/                   |             |
# |    fps                  | 83          |
# |    iterations           | 487         |
# |    time_elapsed         | 11994       |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.006073614 |
# |    clip_fraction        | 0.0354      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.8        |
# |    explained_variance   | 0.775       |
# |    learning_rate        | 0.0001      |
# |    loss                 | -0.00498    |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.00122    |
# |    value_loss           | 1.68e-06    |
# -----------------------------------------
#
# 📊 Step 998000 | Action: [4] | Cash: $0.00 | Stocks: $140,840.25 | Total: $140,840.25
#
# 📊 Step 999000 | Action: [2] | Cash: $748.82 | Stocks: $96,913.74 | Total: $97,662.56
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.0293      |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 488          |
# |    time_elapsed         | 11997        |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0011387335 |
# |    clip_fraction        | 0.00771      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.78        |
# |    explained_variance   | 0.756        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 0.00171      |
# |    n_updates            | 4870         |
# |    policy_gradient_loss | -0.000405    |
# |    value_loss           | 2.13e-06     |
# ------------------------------------------
#
# 📊 Step 1000000 | Action: [4] | Cash: $0.00 | Stocks: $122,205.51 | Total: $122,205.51
#
# 📊 Step 1001000 | Action: [4] | Cash: $0.00 | Stocks: $133,914.99 | Total: $133,914.99
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 236          |
# |    ep_rew_mean          | -0.0292      |
# | time/                   |              |
# |    fps                  | 83           |
# |    iterations           | 489          |
# |    time_elapsed         | 12000        |
# |    total_timesteps      | 1001472      |
# | train/                  |              |
# |    approx_kl            | 0.0036632733 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.804       |
# |    explained_variance   | 0.773        |
# |    learning_rate        | 0.0001       |
# |    loss                 | -0.00141     |
# |    n_updates            | 4880         |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 1.82e-06     |
# ------------------------------------------
# ✅ Huấn luyện hoàn tất!

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.env_checker import check_env
import pandas_ta as ta
from sklearn.preprocessing import StandardScaler

# ------------------------------
# 1. Load and Process Data
# ------------------------------
df = pd.read_csv("stock.csv")
df = df[['Date', 'Close', 'High', 'Low', 'Open', 'Volume']]
df.columns.name = None

# Calculate technical indicators
df.ta.rsi(length=14, append=True)
df.ta.ema(length=14, append=True)
df.rename(columns={'RSI_14': 'RSI', 'EMA_14': 'EMA'}, inplace=True)

# Save the raw close prices for reward calculation and evaluation later
df['Close_raw'] = df['Close'].copy()
df = df.dropna().reset_index(drop=True)

# Scale the features
scaler = StandardScaler()
scaled_features = ['Close', 'Open', 'High', 'Low', 'Volume', 'RSI', 'EMA']
df[scaled_features] = scaler.fit_transform(df[scaled_features])


# ------------------------------
# 2. Split Data into Train and Test Sets
# ------------------------------
train_size = int(len(df) * 0.8)
train_df = df[:train_size].reset_index(drop=True)
test_df = df[train_size:].reset_index(drop=True)


# ------------------------------
# 3. Custom Reinforcement Learning Environment
# ------------------------------
class StockTradingEnv(gym.Env):
    def __init__(self, df, scaler):
        super(StockTradingEnv, self).__init__()
        self.df = df
        self.scaler = scaler # Store the scaler
        self.max_steps = len(df)
        self.action_space = spaces.Discrete(10)
        self.buy_pcts = np.linspace(0.24, 0.53, 5)  
        self.sell_pcts = np.linspace(0.22, 0.73, 5) 
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(7,), dtype=np.float32
        )
        self.init_cash = 100_000
        self.transaction_fee = 0.03
        self.penalty_sessions = 25
        self.penalty_fee = 3981
        self.total_asset_min = 1000
        self.cash_min = -5000
        self.win_threshold = 1_000_000

    def reset(self):
        self.step_idx = 0
        self.cash = self.init_cash
        self.stock_owned = 0
        self.cost_basis = 0
        self.last_trade_step = 0
        self.prev_total_asset = self.cash
        return self._get_obs()

    def _get_obs(self):
        # FIX: Clamp the index to the last valid row to prevent IndexError
        # when the episode ends and an observation for the terminal state is needed.
        obs_idx = min(self.step_idx, self.max_steps - 1)
        row = self.df.iloc[obs_idx]
        moving_avg = self.df['Close'].iloc[max(0, obs_idx - 5):obs_idx + 1].mean()
        return np.array([
            self.cash / self.init_cash,
            self.stock_owned,
            row['Close'],
            moving_avg,
            row['Volume'],
            row['RSI'],
            row['EMA']
        ], dtype=np.float32)

    def step(self, action):
        done = False
        traded = False
        # Use Close_raw for actual transaction calculations
        price_raw = self.df['Close_raw'].iloc[self.step_idx]
        reward = 0

        self.prev_total_asset = self.cash + self.stock_owned * price_raw

        # --- BUY ---
        if action <= 4:
            pct = self.buy_pcts[action]
            budget = pct * self.cash
            if budget > 1:
                quantity = (budget / price_raw) * (1 - self.transaction_fee)
                cost = quantity * price_raw * (1 + self.transaction_fee)
                new_total_cost = self.cost_basis * self.stock_owned + cost
                self.stock_owned += quantity
                self.cost_basis = new_total_cost / self.stock_owned if self.stock_owned > 0 else 0
                self.cash -= cost
                traded = True
        # --- SELL ---
        elif action >= 5 and self.stock_owned > 0:
            pct = self.sell_pcts[action - 5]
            quantity = pct * self.stock_owned
            if quantity > 0:
                revenue = quantity * price_raw * (1 - self.transaction_fee)
                self.cash += revenue
                profit = revenue - (quantity * self.cost_basis)
                if profit > 0:
                    reward += profit * 0.1
                self.stock_owned -= quantity
                if self.stock_owned < 1e-6:
                    self.stock_owned = 0
                    self.cost_basis = 0
                traded = True
        
        total_asset = self.cash + self.stock_owned * price_raw
        reward += (total_asset - self.prev_total_asset) / self.init_cash
        if self.cash < 1:
            reward -= 0.01

        if traded:
            self.last_trade_step = self.step_idx
        elif self.step_idx - self.last_trade_step >= self.penalty_sessions:
            self.cash -= self.penalty_fee
            reward -= self.penalty_fee / self.init_cash

        self.step_idx += 1
        if self.step_idx >= self.max_steps or total_asset < self.total_asset_min or self.cash < self.cash_min:
            done = True
        elif total_asset >= self.win_threshold:
            reward += 10
            done = True
        
        # The _get_obs method now handles the index clamping internally.
        return self._get_obs(), reward, done, {}

class LoggerCallback(BaseCallback):
    def __init__(self, env, verbose=1):
        super().__init__(verbose)
        # The environment is vectorized, so we need to access the underlying environment
        # FIX: Access the actual environment inside the Monitor wrapper
        self.env_ref = env.envs[0]
        self.last_step = 0

    def _on_step(self):
        step = self.num_timesteps
        if step - self.last_step >= 5000: # Log every 5000 steps
            self.last_step = step
            
            # FIX: Access the attributes from the unwrapped environment
            # Access the Monitor's internal env to get the custom attributes
            actual_env = self.training_env.envs[0].env
            cash = actual_env.cash
            stock_owned = actual_env.stock_owned
            step_idx = min(actual_env.step_idx, len(actual_env.df) - 1)
            
            # Use the raw price for accurate valuation
            price_raw = actual_env.df['Close_raw'].iloc[step_idx]
            stock_val = stock_owned * price_raw
            total_asset = cash + stock_val
            
            # Print the real-time portfolio status
            print(f"\n📊 Step {step} | Action: {self.locals['actions']} | Cash: ${cash:,.2f} | Stocks: ${stock_val:,.2f} | Total: ${total_asset:,.2f}")
        return True

# ------------------------------
# 4. Train PPO Agent
# ------------------------------
env_train = StockTradingEnv(train_df, scaler)
# check_env(env_train) # Optional: check if the env follows the Gym API

model = PPO(
    "MlpPolicy",
    env_train,
    verbose=1,
    learning_rate=3e-5,
    batch_size=64,
    n_steps=2048,
    gamma=0.99,
    tensorboard_log="./tensorboard_logs"
)

# --- FIX: Instantiate and use the LoggerCallback ---
# The callback now correctly accesses the underlying environment
callback = LoggerCallback(model.get_env())

print("🚀 Starting model training...")
# Restore timesteps for a full run and pass the callback
model.learn(total_timesteps=1_000_000, progress_bar=False, callback=callback)
model.save("ppo_stock_trader_v3")
print("✅ Training complete!")


# ------------------------------
# 5. Evaluate the Trained Agent with Step-by-Step Logging
# ------------------------------
print("\n🧪 Starting evaluation on test data...")

model = PPO.load("ppo_stock_trader_v3")
env_test = StockTradingEnv(test_df, scaler)
obs = env_test.reset()

print("\n--- STEP-BY-STEP BACKTEST ---")
print(f"{'Step':<5}{'Date':<12}{'Action':<12}{'Price':<10}{'Cash':<15}{'Stocks':<12}{'Portfolio':<15}")
print("-" * 83)

# Loop until the environment is done
for i in range(env_test.max_steps):
    action_idx, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = env_test.step(action_idx)

    step_num = env_test.step_idx -1
    date = test_df['Date'].iloc[step_num]
    price = test_df['Close_raw'].iloc[step_num]
    cash = env_test.cash
    stocks_owned = env_test.stock_owned
    portfolio_value = cash + stocks_owned * price

    if action_idx <= 4:
        action_str = f"BUY ({env_test.buy_pcts[action_idx]*100:.0f}%)"
    else:
        action_str = f"SELL ({env_test.sell_pcts[action_idx-5]*100:.0f}%)"
    
    print(f"{step_num:<5}{date:<12}{action_str:<12}${price:<9.2f}${cash: <14,.2f}{stocks_owned:<12.2f}${portfolio_value: <14,.2f}")

    if done:
        print("--- Backtest finished ---")
        break

# --- Final portfolio summary ---
# Use the last available price for the final calculation
final_price = test_df['Close_raw'].iloc[-1]
final_portfolio_value = env_test.cash + env_test.stock_owned * final_price
profit = final_portfolio_value - env_test.init_cash
profit_pct = (profit / env_test.init_cash) * 100

print("\n--- FINAL RESULTS ---")
print(f"Initial Portfolio: ${env_test.init_cash:,.2f}")
print(f"Final Portfolio:   ${final_portfolio_value:,.2f}")
print(f"Profit/Loss:       ${profit:,.2f} ({profit_pct:.2f}%)")
print("-----------------------")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# 🚀 Starting model training...
# Logging to ./tensorboard_logs\PPO_10
# c:\Users\Hi\anaconda3\envs\all\Lib\site-packages\stable_baselines3\common\vec_env\patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 726      |
# |    ep_rew_mean     | 16       |
# | time/              |          |
# |    fps             | 2218     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 738           |
# |    ep_rew_mean          | 13.2          |
# | time/                   |               |
# |    fps                  | 1436          |
# |    iterations           | 2             |
# |    time_elapsed         | 2             |
# |    total_timesteps      | 4096          |
# | train/                  |               |
# |    approx_kl            | 0.00068938825 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | -0.00532      |
# |    learning_rate        | 3e-05         |
# |    loss                 | 1.56          |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.00109      |
# |    value_loss           | 1.82          |
# -------------------------------------------
#
# 📊 Step 5000 | Action: [7] | Cash: $2,978.57 | Stocks: $367.72 | Total: $3,346.30
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 745          |
# |    ep_rew_mean          | 27           |
# | time/                   |              |
# |    fps                  | 1328         |
# |    iterations           | 3            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0015217826 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | -0.00571     |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.0369       |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 1.28         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 743           |
# |    ep_rew_mean          | 23.9          |
# | time/                   |               |
# |    fps                  | 1265          |
# |    iterations           | 4             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 8192          |
# | train/                  |               |
# |    approx_kl            | 0.00013082146 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.3          |
# |    explained_variance   | 0.00352       |
# |    learning_rate        | 3e-05         |
# |    loss                 | 36            |
# |    n_updates            | 30            |
# |    policy_gradient_loss | -0.000251     |
# |    value_loss           | 37.2          |
# -------------------------------------------
#
# 📊 Step 10000 | Action: [0] | Cash: $9,182.04 | Stocks: $3,709.58 | Total: $12,891.62
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 745          |
# |    ep_rew_mean          | 26.3         |
# | time/                   |              |
# |    fps                  | 1241         |
# |    iterations           | 5            |
# |    time_elapsed         | 8            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0017982728 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.3         |
# |    explained_variance   | 0.0214       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.545        |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00193     |
# |    value_loss           | 1.44         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 747          |
# |    ep_rew_mean          | 24.1         |
# | time/                   |              |
# |    fps                  | 1221         |
# |    iterations           | 6            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0002736285 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0.0159       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 5.37         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.000285    |
# |    value_loss           | 20.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 747         |
# |    ep_rew_mean          | 25.6        |
# | time/                   |             |
# |    fps                  | 1204        |
# |    iterations           | 7           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.001127867 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.0612      |
# |    learning_rate        | 3e-05       |
# |    loss                 | 1.09        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0021     |
# |    value_loss           | 8.41        |
# -----------------------------------------
#
# 📊 Step 15000 | Action: [9] | Cash: $54,011.88 | Stocks: $17,090.33 | Total: $71,102.22
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 750          |
# |    ep_rew_mean          | 25.1         |
# | time/                   |              |
# |    fps                  | 1195         |
# |    iterations           | 8            |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0008785104 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0.1          |
# |    learning_rate        | 3e-05        |
# |    loss                 | 8.69         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000687    |
# |    value_loss           | 5.38         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 750          |
# |    ep_rew_mean          | 26.3         |
# | time/                   |              |
# |    fps                  | 1189         |
# |    iterations           | 9            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0002210339 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0.0508       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 2.55         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.000174    |
# |    value_loss           | 15.3         |
# ------------------------------------------
#
# 📊 Step 20000 | Action: [7] | Cash: $3,625.77 | Stocks: $1,430.23 | Total: $5,055.99
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 750          |
# |    ep_rew_mean          | 25.5         |
# | time/                   |              |
# |    fps                  | 1186         |
# |    iterations           | 10           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 20480        |
# | train/                  |              |
# |    approx_kl            | 0.0019788914 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.29        |
# |    explained_variance   | 0.168        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 2.85         |
# |    n_updates            | 90           |
# |    policy_gradient_loss | -0.00252     |
# |    value_loss           | 2.99         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 751          |
# |    ep_rew_mean          | 24.2         |
# | time/                   |              |
# |    fps                  | 1181         |
# |    iterations           | 11           |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 22528        |
# | train/                  |              |
# |    approx_kl            | 0.0014590588 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.28        |
# |    explained_variance   | 0.169        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 1.43         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 1.4          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 754          |
# |    ep_rew_mean          | 26.3         |
# | time/                   |              |
# |    fps                  | 1179         |
# |    iterations           | 12           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0058638747 |
# |    clip_fraction        | 0.0176       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.26        |
# |    explained_variance   | 0.191        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.0972       |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00383     |
# |    value_loss           | 0.521        |
# ------------------------------------------
#
# 📊 Step 25000 | Action: [7] | Cash: $73,298.79 | Stocks: $17,869.37 | Total: $91,168.16
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 758           |
# |    ep_rew_mean          | 26            |
# | time/                   |               |
# |    fps                  | 1176          |
# |    iterations           | 13            |
# |    time_elapsed         | 22            |
# |    total_timesteps      | 26624         |
# | train/                  |               |
# |    approx_kl            | 0.00010261443 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.25         |
# |    explained_variance   | 0.0253        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 10.9          |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -0.000219     |
# |    value_loss           | 27.5          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 761          |
# |    ep_rew_mean          | 27           |
# | time/                   |              |
# |    fps                  | 1175         |
# |    iterations           | 14           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0017534143 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.25        |
# |    explained_variance   | 0.181        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 0.395        |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.00207     |
# |    value_loss           | 4.65         |
# ------------------------------------------
#
# 📊 Step 30000 | Action: [3] | Cash: $6,094.40 | Stocks: $10,178.35 | Total: $16,272.75
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 763         |
# |    ep_rew_mean          | 27.1        |
# | time/                   |             |
# |    fps                  | 1174        |
# |    iterations           | 15          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.000258548 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | 0.0975      |
# |    learning_rate        | 3e-05       |
# |    loss                 | 4.65        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.000378   |
# |    value_loss           | 9.7         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 768          |
# |    ep_rew_mean          | 26.4         |
# | time/                   |              |
# |    fps                  | 1169         |
# |    iterations           | 16           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0064479373 |
# |    clip_fraction        | 0.00635      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.22        |
# |    explained_variance   | 0.272        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 1.34         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00404     |
# |    value_loss           | 1.26         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 774           |
# |    ep_rew_mean          | 30.3          |
# | time/                   |               |
# |    fps                  | 1169          |
# |    iterations           | 17            |
# |    time_elapsed         | 29            |
# |    total_timesteps      | 34816         |
# | train/                  |               |
# |    approx_kl            | 0.00029032966 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.2          |
# |    explained_variance   | 0.0186        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 0.52          |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.000776     |
# |    value_loss           | 89.9          |
# -------------------------------------------
#
# 📊 Step 35000 | Action: [9] | Cash: $1,151.36 | Stocks: $58.69 | Total: $1,210.04
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 782         |
# |    ep_rew_mean          | 30.7        |
# | time/                   |             |
# |    fps                  | 1169        |
# |    iterations           | 18          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.003238735 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 0.22        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00367    |
# |    value_loss           | 4.89        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 790          |
# |    ep_rew_mean          | 36           |
# | time/                   |              |
# |    fps                  | 1167         |
# |    iterations           | 19           |
# |    time_elapsed         | 33           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0002606636 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.17        |
# |    explained_variance   | 0.118        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 32.2         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.000479    |
# |    value_loss           | 21.1         |
# ------------------------------------------
#
# 📊 Step 40000 | Action: [0] | Cash: $309.81 | Stocks: $21,963.26 | Total: $22,273.07
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 797          |
# |    ep_rew_mean          | 36.8         |
# | time/                   |              |
# |    fps                  | 1166         |
# |    iterations           | 20           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0018280621 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.16        |
# |    explained_variance   | 0.089        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 88.2         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00186     |
# |    value_loss           | 54.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 804          |
# |    ep_rew_mean          | 38.1         |
# | time/                   |              |
# |    fps                  | 1165         |
# |    iterations           | 21           |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.0019460202 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.14        |
# |    explained_variance   | 0.269        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 1.67         |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00221     |
# |    value_loss           | 6.93         |
# ------------------------------------------
#
# 📊 Step 45000 | Action: [0] | Cash: $6,470.53 | Stocks: $4,833.46 | Total: $11,303.99
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 809           |
# |    ep_rew_mean          | 39.9          |
# | time/                   |               |
# |    fps                  | 1158          |
# |    iterations           | 22            |
# |    time_elapsed         | 38            |
# |    total_timesteps      | 45056         |
# | train/                  |               |
# |    approx_kl            | 0.00045153673 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.13         |
# |    explained_variance   | 0.119         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 6.76          |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -0.00117      |
# |    value_loss           | 34.9          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 816           |
# |    ep_rew_mean          | 45            |
# | time/                   |               |
# |    fps                  | 1130          |
# |    iterations           | 23            |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 47104         |
# | train/                  |               |
# |    approx_kl            | 0.00072405447 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.11         |
# |    explained_variance   | 0.0736        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 34.2          |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.00142      |
# |    value_loss           | 132           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 822           |
# |    ep_rew_mean          | 46.4          |
# | time/                   |               |
# |    fps                  | 1104          |
# |    iterations           | 24            |
# |    time_elapsed         | 44            |
# |    total_timesteps      | 49152         |
# | train/                  |               |
# |    approx_kl            | 0.00069576607 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.1          |
# |    explained_variance   | 0.187         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 14.5          |
# |    n_updates            | 230           |
# |    policy_gradient_loss | -0.000594     |
# |    value_loss           | 31.5          |
# -------------------------------------------
#
# 📊 Step 50000 | Action: [8] | Cash: $6,276.48 | Stocks: $4,212.69 | Total: $10,489.17
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 827          |
# |    ep_rew_mean          | 47.1         |
# | time/                   |              |
# |    fps                  | 1078         |
# |    iterations           | 25           |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0023931942 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0.265        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 5.06         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00186     |
# |    value_loss           | 11           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 833          |
# |    ep_rew_mean          | 51.1         |
# | time/                   |              |
# |    fps                  | 1061         |
# |    iterations           | 26           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 53248        |
# | train/                  |              |
# |    approx_kl            | 0.0008987696 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0.19         |
# |    learning_rate        | 3e-05        |
# |    loss                 | 8.83         |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.00109     |
# |    value_loss           | 34.9         |
# ------------------------------------------
#
# 📊 Step 55000 | Action: [1] | Cash: $1,528.12 | Stocks: $9,260.77 | Total: $10,788.89
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 838          |
# |    ep_rew_mean          | 51.6         |
# | time/                   |              |
# |    fps                  | 1042         |
# |    iterations           | 27           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0010932316 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.09        |
# |    explained_variance   | 0.132        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 58.9         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.00125     |
# |    value_loss           | 86.9         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 842           |
# |    ep_rew_mean          | 58            |
# | time/                   |               |
# |    fps                  | 1020          |
# |    iterations           | 28            |
# |    time_elapsed         | 56            |
# |    total_timesteps      | 57344         |
# | train/                  |               |
# |    approx_kl            | 0.00023940284 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2.08         |
# |    explained_variance   | 0.164         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 13.4          |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -0.00034      |
# |    value_loss           | 56            |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 847          |
# |    ep_rew_mean          | 62.4         |
# | time/                   |              |
# |    fps                  | 1001         |
# |    iterations           | 29           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0009599836 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.08        |
# |    explained_variance   | 0.105        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 15.2         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00108     |
# |    value_loss           | 209          |
# ------------------------------------------
#
# 📊 Step 60000 | Action: [4] | Cash: $89.33 | Stocks: $8,166.58 | Total: $8,255.91
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 853         |
# |    ep_rew_mean          | 66.9        |
# | time/                   |             |
# |    fps                  | 984         |
# |    iterations           | 30          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.001330859 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.07       |
# |    explained_variance   | 0.0946      |
# |    learning_rate        | 3e-05       |
# |    loss                 | 132         |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.00127    |
# |    value_loss           | 158         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 857          |
# |    ep_rew_mean          | 68.1         |
# | time/                   |              |
# |    fps                  | 972          |
# |    iterations           | 31           |
# |    time_elapsed         | 65           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0048483843 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.05        |
# |    explained_variance   | 0.234        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 13.2         |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.00288     |
# |    value_loss           | 31.2         |
# ------------------------------------------
#
# 📊 Step 65000 | Action: [2] | Cash: $1,109.96 | Stocks: $8,900.43 | Total: $10,010.39
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 860          |
# |    ep_rew_mean          | 69.9         |
# | time/                   |              |
# |    fps                  | 961          |
# |    iterations           | 32           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0024859542 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.02        |
# |    explained_variance   | 0.158        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 46.1         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00222     |
# |    value_loss           | 33.6         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 864           |
# |    ep_rew_mean          | 71.2          |
# | time/                   |               |
# |    fps                  | 949           |
# |    iterations           | 33            |
# |    time_elapsed         | 71            |
# |    total_timesteps      | 67584         |
# | train/                  |               |
# |    approx_kl            | 0.00034289603 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -2            |
# |    explained_variance   | 0.196         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 8.45          |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -0.000502     |
# |    value_loss           | 45.4          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 867          |
# |    ep_rew_mean          | 73.2         |
# | time/                   |              |
# |    fps                  | 939          |
# |    iterations           | 34           |
# |    time_elapsed         | 74           |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0008777123 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.01        |
# |    explained_variance   | 0.272        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 15.7         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.00143     |
# |    value_loss           | 23.8         |
# ------------------------------------------
#
# 📊 Step 70000 | Action: [9] | Cash: $11,274.10 | Stocks: $1,379.33 | Total: $12,653.43
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 870          |
# |    ep_rew_mean          | 79.1         |
# | time/                   |              |
# |    fps                  | 931          |
# |    iterations           | 35           |
# |    time_elapsed         | 76           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0017650736 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.01        |
# |    explained_variance   | 0.0886       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 17.6         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00159     |
# |    value_loss           | 134          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 873          |
# |    ep_rew_mean          | 83.5         |
# | time/                   |              |
# |    fps                  | 922          |
# |    iterations           | 36           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0006319023 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.01        |
# |    explained_variance   | 0.116        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 58.3         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.000591    |
# |    value_loss           | 131          |
# ------------------------------------------
#
# 📊 Step 75000 | Action: [4] | Cash: $28.48 | Stocks: $53,307.22 | Total: $53,335.70
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 870         |
# |    ep_rew_mean          | 86.2        |
# | time/                   |             |
# |    fps                  | 913         |
# |    iterations           | 37          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.004646418 |
# |    clip_fraction        | 0.0106      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 63.3        |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00382    |
# |    value_loss           | 196         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 874          |
# |    ep_rew_mean          | 90.6         |
# | time/                   |              |
# |    fps                  | 904          |
# |    iterations           | 38           |
# |    time_elapsed         | 86           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0015438781 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.96        |
# |    explained_variance   | 0.0843       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 135          |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.0014      |
# |    value_loss           | 242          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 877          |
# |    ep_rew_mean          | 92.9         |
# | time/                   |              |
# |    fps                  | 897          |
# |    iterations           | 39           |
# |    time_elapsed         | 88           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0010765275 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.95        |
# |    explained_variance   | 0.157        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 15           |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.0012      |
# |    value_loss           | 91           |
# ------------------------------------------
#
# 📊 Step 80000 | Action: [7] | Cash: $28,602.56 | Stocks: $32,036.92 | Total: $60,639.47
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 879          |
# |    ep_rew_mean          | 96.3         |
# | time/                   |              |
# |    fps                  | 890          |
# |    iterations           | 40           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0016419514 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.93        |
# |    explained_variance   | 0.16         |
# |    learning_rate        | 3e-05        |
# |    loss                 | 7.29         |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00197     |
# |    value_loss           | 68.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 881          |
# |    ep_rew_mean          | 102          |
# | time/                   |              |
# |    fps                  | 884          |
# |    iterations           | 41           |
# |    time_elapsed         | 94           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0011231484 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.101        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 38.9         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00124     |
# |    value_loss           | 151          |
# ------------------------------------------
#
# 📊 Step 85000 | Action: [0] | Cash: $60.64 | Stocks: $45,225.91 | Total: $45,286.56
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 883          |
# |    ep_rew_mean          | 111          |
# | time/                   |              |
# |    fps                  | 879          |
# |    iterations           | 42           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0003542048 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.0459       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 52.9         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.000474    |
# |    value_loss           | 670          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 885          |
# |    ep_rew_mean          | 119          |
# | time/                   |              |
# |    fps                  | 874          |
# |    iterations           | 43           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0014604492 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.88        |
# |    explained_variance   | 0.0466       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 1.81e+03     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00148     |
# |    value_loss           | 787          |
# ------------------------------------------
#
# 📊 Step 90000 | Action: [5] | Cash: $14,564.03 | Stocks: $49,371.23 | Total: $63,935.27
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 885          |
# |    ep_rew_mean          | 122          |
# | time/                   |              |
# |    fps                  | 869          |
# |    iterations           | 44           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0019398709 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.89        |
# |    explained_variance   | 0.0513       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 114          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00132     |
# |    value_loss           | 363          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 887          |
# |    ep_rew_mean          | 126          |
# | time/                   |              |
# |    fps                  | 864          |
# |    iterations           | 45           |
# |    time_elapsed         | 106          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0018752413 |
# |    clip_fraction        | 0.00112      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.131        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 53.4         |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00149     |
# |    value_loss           | 66.3         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 892           |
# |    ep_rew_mean          | 134           |
# | time/                   |               |
# |    fps                  | 860           |
# |    iterations           | 46            |
# |    time_elapsed         | 109           |
# |    total_timesteps      | 94208         |
# | train/                  |               |
# |    approx_kl            | 0.00074109994 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.91         |
# |    explained_variance   | 0.0475        |
# |    learning_rate        | 3e-05         |
# |    loss                 | 24.3          |
# |    n_updates            | 450           |
# |    policy_gradient_loss | -0.000748     |
# |    value_loss           | 186           |
# -------------------------------------------
#
# 📊 Step 95000 | Action: [6] | Cash: $13,768.74 | Stocks: $13,278.68 | Total: $27,047.42
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 897         |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 855         |
# |    iterations           | 47          |
# |    time_elapsed         | 112         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.004341776 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.9        |
# |    explained_variance   | 0.103       |
# |    learning_rate        | 3e-05       |
# |    loss                 | 21.8        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00285    |
# |    value_loss           | 187         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 900          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 852          |
# |    iterations           | 48           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0021547605 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.9         |
# |    explained_variance   | 0.0422       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 266          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.00157     |
# |    value_loss           | 635          |
# ------------------------------------------
#
# 📊 Step 100000 | Action: [0] | Cash: $5,234.64 | Stocks: $4,184.03 | Total: $9,418.67
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 904          |
# |    ep_rew_mean          | 152          |
# | time/                   |              |
# |    fps                  | 848          |
# |    iterations           | 49           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0022575124 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.0477       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 114          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.00177     |
# |    value_loss           | 164          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | 159           |
# | time/                   |               |
# |    fps                  | 844           |
# |    iterations           | 50            |
# |    time_elapsed         | 121           |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 0.00026837533 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.92         |
# |    explained_variance   | 0.181         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 65.2          |
# |    n_updates            | 490           |
# |    policy_gradient_loss | -0.000485     |
# |    value_loss           | 56.1          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 913          |
# |    ep_rew_mean          | 162          |
# | time/                   |              |
# |    fps                  | 840          |
# |    iterations           | 51           |
# |    time_elapsed         | 124          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0008629377 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.91        |
# |    explained_variance   | 0.0601       |
# |    learning_rate        | 3e-05        |
# |    loss                 | 266          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.000659    |
# |    value_loss           | 479          |
# ------------------------------------------
#
# 📊 Step 105000 | Action: [8] | Cash: $4,402.19 | Stocks: $2,787.15 | Total: $7,189.34
# ------------------------------------------
# | rollout/                |              |
# ...
# | time/                   |              |
# |    fps                  | 897          |
# |    iterations           | 477          |
# |    time_elapsed         | 1087         |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 8.088327e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 0.339        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 375          |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | -0.000317    |
# |    value_loss           | 485          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 822           |
# |    ep_rew_mean          | 342           |
# | time/                   |               |
# |    fps                  | 898           |
# |    iterations           | 478           |
# |    time_elapsed         | 1090          |
# |    total_timesteps      | 978944        |
# | train/                  |               |
# |    approx_kl            | 6.0505205e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.68         |
# |    explained_variance   | 0.467         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 97.3          |
# |    n_updates            | 4770          |
# |    policy_gradient_loss | -0.00019      |
# |    value_loss           | 251           |
# -------------------------------------------
#
# 📊 Step 980000 | Action: [1] | Cash: $208.25 | Stocks: $27,039.96 | Total: $27,248.21
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 822           |
# |    ep_rew_mean          | 344           |
# | time/                   |               |
# |    fps                  | 898           |
# |    iterations           | 479           |
# |    time_elapsed         | 1091          |
# |    total_timesteps      | 980992        |
# | train/                  |               |
# |    approx_kl            | 3.1458418e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.68         |
# |    explained_variance   | 0.485         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 73.6          |
# |    n_updates            | 4780          |
# |    policy_gradient_loss | -0.000115     |
# |    value_loss           | 314           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 822           |
# |    ep_rew_mean          | 345           |
# | time/                   |               |
# |    fps                  | 898           |
# |    iterations           | 480           |
# |    time_elapsed         | 1093          |
# |    total_timesteps      | 983040        |
# | train/                  |               |
# |    approx_kl            | 0.00013020213 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.68         |
# |    explained_variance   | 0.546         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 92.6          |
# |    n_updates            | 4790          |
# |    policy_gradient_loss | -0.000478     |
# |    value_loss           | 152           |
# -------------------------------------------
#
# 📊 Step 985000 | Action: [4] | Cash: $2,013.67 | Stocks: $10,431.87 | Total: $12,445.53
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 831          |
# |    ep_rew_mean          | 351          |
# | time/                   |              |
# |    fps                  | 898          |
# |    iterations           | 481          |
# |    time_elapsed         | 1095         |
# |    total_timesteps      | 985088       |
# | train/                  |              |
# |    approx_kl            | 7.422423e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 0.611        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 51.5         |
# |    n_updates            | 4800         |
# |    policy_gradient_loss | -0.000295    |
# |    value_loss           | 111          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 836           |
# |    ep_rew_mean          | 358           |
# | time/                   |               |
# |    fps                  | 898           |
# |    iterations           | 482           |
# |    time_elapsed         | 1098          |
# |    total_timesteps      | 987136        |
# | train/                  |               |
# |    approx_kl            | 2.8276496e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.68         |
# |    explained_variance   | 0.272         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 104           |
# |    n_updates            | 4810          |
# |    policy_gradient_loss | -0.000173     |
# |    value_loss           | 924           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 837          |
# |    ep_rew_mean          | 356          |
# | time/                   |              |
# |    fps                  | 899          |
# |    iterations           | 483          |
# |    time_elapsed         | 1100         |
# |    total_timesteps      | 989184       |
# | train/                  |              |
# |    approx_kl            | 3.917259e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.69        |
# |    explained_variance   | 0.445        |
# |    learning_rate        | 3e-05        |
# |    loss                 | 209          |
# |    n_updates            | 4820         |
# |    policy_gradient_loss | -9.62e-05    |
# |    value_loss           | 813          |
# ------------------------------------------
#
# 📊 Step 990000 | Action: [5] | Cash: $6,149.36 | Stocks: $22,747.94 | Total: $28,897.31
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 816           |
# |    ep_rew_mean          | 355           |
# | time/                   |               |
# |    fps                  | 899           |
# |    iterations           | 484           |
# |    time_elapsed         | 1102          |
# |    total_timesteps      | 991232        |
# | train/                  |               |
# |    approx_kl            | 0.00031001845 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.7          |
# |    explained_variance   | 0.636         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 46.1          |
# |    n_updates            | 4830          |
# |    policy_gradient_loss | -0.000637     |
# |    value_loss           | 152           |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 816           |
# |    ep_rew_mean          | 361           |
# | time/                   |               |
# |    fps                  | 899           |
# |    iterations           | 485           |
# |    time_elapsed         | 1104          |
# |    total_timesteps      | 993280        |
# | train/                  |               |
# |    approx_kl            | 8.2489685e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.72         |
# |    explained_variance   | 0.347         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 205           |
# |    n_updates            | 4840          |
# |    policy_gradient_loss | -0.000424     |
# |    value_loss           | 547           |
# -------------------------------------------
#
# 📊 Step 995000 | Action: [4] | Cash: $47.35 | Stocks: $9,486.88 | Total: $9,534.23
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 819           |
# |    ep_rew_mean          | 365           |
# | time/                   |               |
# |    fps                  | 899           |
# |    iterations           | 486           |
# |    time_elapsed         | 1106          |
# |    total_timesteps      | 995328        |
# | train/                  |               |
# |    approx_kl            | 0.00018137175 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.71         |
# |    explained_variance   | 0.644         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 74            |
# |    n_updates            | 4850          |
# |    policy_gradient_loss | -0.000376     |
# |    value_loss           | 179           |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 820          |
# |    ep_rew_mean          | 364          |
# | time/                   |              |
# |    fps                  | 899          |
# |    iterations           | 487          |
# |    time_elapsed         | 1108         |
# |    total_timesteps      | 997376       |
# | train/                  |              |
# |    approx_kl            | 8.909573e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.71        |
# |    explained_variance   | 0.53         |
# |    learning_rate        | 3e-05        |
# |    loss                 | 206          |
# |    n_updates            | 4860         |
# |    policy_gradient_loss | -0.000262    |
# |    value_loss           | 315          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 815           |
# |    ep_rew_mean          | 361           |
# | time/                   |               |
# |    fps                  | 899           |
# |    iterations           | 488           |
# |    time_elapsed         | 1110          |
# |    total_timesteps      | 999424        |
# | train/                  |               |
# |    approx_kl            | 0.00018119454 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.72         |
# |    explained_variance   | 0.564         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 163           |
# |    n_updates            | 4870          |
# |    policy_gradient_loss | -0.000371     |
# |    value_loss           | 180           |
# -------------------------------------------
#
# 📊 Step 1000000 | Action: [4] | Cash: $4,251.05 | Stocks: $42,845.11 | Total: $47,096.16
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 815           |
# |    ep_rew_mean          | 362           |
# | time/                   |               |
# |    fps                  | 899           |
# |    iterations           | 489           |
# |    time_elapsed         | 1113          |
# |    total_timesteps      | 1001472       |
# | train/                  |               |
# |    approx_kl            | 0.00045501057 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.73         |
# |    explained_variance   | 0.522         |
# |    learning_rate        | 3e-05         |
# |    loss                 | 55.2          |
# |    n_updates            | 4880          |
# |    policy_gradient_loss | -0.000962     |
# |    value_loss           | 128           |
# -------------------------------------------
# ✅ Training complete!
#
# 🧪 Starting evaluation on test data...
#
# --- STEP-BY-STEP BACKTEST ---
# Step Date        Action      Price     Cash           Stocks      Portfolio
# -----------------------------------------------------------------------------------
# 0    2024-06-07  BUY (53%)   $170.01   $47,047.70     302.39      $98,457.70
# 1    2024-06-10  BUY (53%)   $170.38   $22,134.86     444.35      $97,843.97
# 2    2024-06-11  BUY (53%)   $169.32   $10,413.94     511.56      $97,031.57
# 3    2024-06-12  BUY (53%)   $169.00   $4,899.52      543.24      $96,707.25
# 4    2024-06-13  BUY (53%)   $169.12   $2,305.11      558.13      $96,696.87
# 5    2024-06-14  BUY (53%)   $169.21   $1,084.50      565.14      $96,711.56
# 6    2024-06-17  BUY (53%)   $169.50   $510.23        568.43      $96,858.72
# 7    2024-06-18  BUY (53%)   $170.55   $240.05        569.97      $97,447.70
# 8    2024-06-20  BUY (53%)   $173.92   $112.94        570.68      $99,364.78
# 9    2024-06-21  BUY (53%)   $172.46   $53.14         571.01      $98,529.86
# 10   2024-06-24  BUY (53%)   $175.01   $25.00         571.17      $99,985.11
# 11   2024-06-25  BUY (53%)   $172.60   $11.76         571.24      $98,608.22
# 12   2024-06-26  BUY (53%)   $171.87   $5.53          571.28      $98,191.03
# 13   2024-06-27  BUY (53%)   $170.85   $2.60          571.29      $97,608.24
# 14   2024-06-28  BUY (53%)   $172.95   $1.22          571.30      $98,807.92
# 15   2024-07-01  BUY (53%)   $175.10   $1.22          571.30      $100,036.22
# 16   2024-07-02  BUY (53%)   $177.30   $1.22          571.30      $101,293.08
# 17   2024-07-03  BUY (53%)   $175.73   $1.22          571.30      $100,396.13
# 18   2024-07-05  BUY (53%)   $176.02   $1.22          571.30      $100,561.82
# 19   2024-07-08  BUY (53%)   $177.64   $1.22          571.30      $101,487.32
# 20   2024-07-09  BUY (53%)   $176.48   $1.22          571.30      $100,824.61
# 21   2024-07-10  BUY (53%)   $177.84   $1.22          571.30      $101,601.58
# 22   2024-07-11  BUY (53%)   $178.31   $1.22          571.30      $101,870.09
# 23   2024-07-12  BUY (53%)   $182.83   $1.22          571.30      $104,452.38
# 24   2024-07-15  BUY (53%)   $182.88   $1.22          571.30      $104,480.95
# 25   2024-07-16  BUY (53%)   $185.81   $1.22          571.30      $106,154.86
# 26   2024-07-17  BUY (53%)   $187.45   $1.22          571.30      $107,091.80
# 27   2024-07-18  BUY (53%)   $185.22   $1.22          571.30      $105,817.79
# 28   2024-07-19  BUY (53%)   $183.25   $1.22          571.30      $104,692.33
# 29   2024-07-22  BUY (53%)   $184.15   $1.22          571.30      $105,206.50
# 30   2024-07-23  BUY (53%)   $184.10   $1.22          571.30      $105,177.94
# 31   2024-07-24  BUY (53%)   $184.02   $1.22          571.30      $105,132.23
# 32   2024-07-25  BUY (53%)   $191.98   $1.22          571.30      $109,679.79
# 33   2024-07-26  BUY (53%)   $191.75   $1.22          571.30      $109,548.40
# 34   2024-07-29  BUY (53%)   $191.50   $1.22          571.30      $109,405.57
# 35   2024-07-30  BUY (53%)   $191.04   $1.22          571.30      $109,142.77
# 36   2024-07-31  BUY (53%)   $192.14   $1.22          571.30      $109,771.20
# 37   2024-08-01  BUY (53%)   $189.66   $1.22          571.30      $108,354.38
# 38   2024-08-02  BUY (53%)   $189.12   $1.22          571.30      $108,045.87
# 39   2024-08-05  BUY (53%)   $183.31   $-3,979.78     571.30      $100,745.61
# 40   2024-08-06  BUY (53%)   $186.80   $-7,960.78     571.30      $98,758.45
# --- Backtest finished ---
#
# --- FINAL RESULTS ---
# Initial Portfolio: $100,000.00
# Final Portfolio:   $144,496.89
# Profit/Loss:       $44,496.89 (44.50%)
# -----------------------

# %%
import numpy as np
import pandas as pd
import gym
from gym import spaces
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env
import asyncio
import platform

# Tham số từ tài liệu
BUY_MIN = 0.24  # 24%
BUY_MAX = 0.53  # 53%
SELL_MIN = 0.22  # 22%
SELL_MAX = 0.73  # 73%
TRANSACTION_FEE = 0.03  # 3%
TRANSACTION_SESSION = 25  # Số phiên không giao dịch
TRANSACTION_PENALTY = 3981  # USD
INITIAL_CASH = 1000  # 1000 USD (theo hình ảnh)
WIN_CONDITION = 1000000  # 1,000,000 USD
LOSE_CONDITION = -5000  # -5,000 USD

class StockTradingEnv(gym.Env):
    def __init__(self, df):
        super(StockTradingEnv, self).__init__()
        self.df = df
        self.current_step = 0
        self.cash = INITIAL_CASH
        self.shares = 0
        self.total_assets = INITIAL_CASH
        self.no_trade_sessions = 0

        # Observation space: [cash, shares, OHLC prices, total_assets]
        self.observation_space = spaces.Box(
            low=0, high=np.inf, shape=(6,), dtype=np.float32
        )

        # Action space: [action_type (0: hold, 1: buy, 2: sell), amount (0 to 1)]
        self.action_space = spaces.Box(
            low=np.array([0, 0]), high=np.array([2, 1]), dtype=np.float32
        )

        self.history_log = []

    def reset(self):
        self.current_step = 0
        self.cash = INITIAL_CASH
        self.shares = 0
        self.total_assets = INITIAL_CASH
        self.no_trade_sessions = 0
        self.history_log = []
        return self._get_observation()

    def _get_observation(self):
        row = self.df.iloc[self.current_step]
        return np.array([
            self.cash,
            self.shares,
            row['Open'],
            row['High'],
            row['Low'],
            row['Close']
        ], dtype=np.float32)

    def step(self, action):
        action_type = int(action[0])
        amount = action[1]
        done = False
        reward = 0
        row = self.df.iloc[self.current_step]
        current_price = row['Close']

        # Thực hiện hành động
        if action_type == 1:  # Buy
            buy_percentage = BUY_MIN + (BUY_MAX - BUY_MIN) * amount
            buy_amount = self.cash * buy_percentage
            shares_to_buy = (buy_amount * (1 - TRANSACTION_FEE)) / current_price
            self.cash -= buy_amount
            self.shares += shares_to_buy
            self.no_trade_sessions = 0
        elif action_type == 2:  # Sell
            sell_percentage = SELL_MIN + (SELL_MAX - SELL_MIN) * amount
            shares_to_sell = self.shares * sell_percentage
            sell_amount = shares_to_sell * current_price * (1 - TRANSACTION_FEE)
            self.cash += sell_amount
            self.shares -= shares_to_sell
            self.no_trade_sessions = 0
        else:  # Hold
            self.no_trade_sessions += 1
            if self.no_trade_sessions >= TRANSACTION_SESSION:
                self.cash -= TRANSACTION_PENALTY
                self.no_trade_sessions = 0
                reward -= TRANSACTION_PENALTY

        # Cập nhật tổng tài sản
        self.total_assets = self.cash + self.shares * current_price

        # Kiểm tra điều kiện dừng
        if self.total_assets >= WIN_CONDITION:
            reward += 10000
            done = True
        elif self.cash <= LOSE_CONDITION:
            reward -= 10000
            done = True

        # Tính reward dựa trên thay đổi tổng tài sản
        if self.current_step > 0:
            prev_assets = self.cash + self.shares * self.df.iloc[self.current_step - 1]['Close']
            reward += (self.total_assets - prev_assets)

        # Ghi log lịch sử
        self.history_log.append({
            'step': self.current_step,
            'cash': self.cash,
            'shares': self.shares,
            'total_assets': self.total_assets,
            'action': action_type,
            'amount': amount
        })

        self.current_step += 1
        if self.current_step >= len(self.df):
            done = True

        return self._get_observation(), reward, done, {}

    def render(self, mode='human'):
        print(f"Step: {self.current_step}, Cash: {self.cash:.2f}, Shares: {self.shares:.2f}, Total Assets: {self.total_assets:.2f}")


# Đọc dữ liệu từ file CSV
df = pd.read_csv("stock_1y.csv")
env = StockTradingEnv(df)
print(check_env(env))

# Huấn luyện mô hình PPO
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10000)

# Lưu mô hình
model.save("ppo_stock_trading")

# Kiểm tra mô hình trên cùng dữ liệu (do chỉ có 1 năm)
obs = env.reset()
total_reward = 0
done = False
while not done:
    action, _ = model.predict(obs)
    obs, reward, done, _ = env.step(action)
    total_reward += reward
    env.render()
# Out:
# c:\Users\Hi\anaconda3\envs\all\Lib\site-packages\gym\spaces\box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[9], line 133
#     131 df = pd.read_csv("stock_1y.csv")
#     132 env = StockTradingEnv(df)
# --> 133 print(check_env(env))
#     135 # Huấn luyện mô hình PPO
#     136 model = PPO("MlpPolicy", env, verbose=1)
#
# File c:\Users\Hi\anaconda3\envs\all\Lib\site-packages\stable_baselines3\common\env_checker.py:430, in check_env(env, warn, skip_render_check)
#     415 def check_env(env: gym.Env, warn: bool = True, skip_render_check: bool = True) -> None:
#     416     """
#     417     Check that an environment follows Gym API.
#     418     This is particularly useful when using a custom environment.
#    (...)
#     428         True by default (useful for the CI)
#     429     """
# --> 430     assert isinstance(
#     431         env, gym.Env
#     432     ), "Your environment must inherit from the gymnasium.Env class cf. https://gymnasium.farama.org/api/env/"
#     434     # ============= Check the spaces (observation and action) ================
#     435     _check_spaces(env)
#
# AssertionError: Your environment must inherit from the gymnasium.Env class cf. https://gymnasium.farama.org/api/env/
