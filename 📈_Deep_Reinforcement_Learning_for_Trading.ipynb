# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
franoisgeorgesjulien_crypto_path = kagglehub.dataset_download('franoisgeorgesjulien/crypto')

print('Data source import complete.')
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/franoisgeorgesjulien/crypto?dataset_version_number=3...
# 100%|██████████| 79.8M/79.8M [00:00<00:00, 126MB/s]
# Extracting files...
# Data source import complete.

# %% [markdown]
# <br>
#
#
# # <span style="color:#5E6997"> Unleashing the Power of Deep Reinforcement Learning for Trading </span>
# ## <span style="color:#5E6997"> Exploring the Intersection of Reinforcement Learning and Neural Networks </span>
#
#
# <br>
#
# ### **Table of Contents**
# * [<span style="color:#A690A4"> 1. Introduction](#intro)
# * [<span style="color:#A690A4"> 2. Data Engineering](#data_eng)
# * [<span style="color:#A690A4"> 3. DRL Environment Architecture](#env)
# * [<span style="color:#A690A4"> 4. DRL Agent Architecture](#agent)
#
# <br>
#
# ## <span style="color:#5E6997"> Project Overview </span> <a class="anchor" id="intro"></a>
#
#
# ### Introduction
# Financial markets are a dynamic, complex ecosystem where traditional trading strategies are continually challenged by evolving market conditions, global events, and intricate patterns that define asset prices. In response to this ever-changing landscape, our team has embarked on a pioneering journey to develop a sophisticated DRL-based algorithmic trading system.
#
# Deep Reinforcement Learning, a subset of artificial intelligence, offers the promise of adaptive, self-improving trading strategies. Inspired by the way humans learn through trial and error, our DRL model navigates financial markets, learning and adapting to new information in real-time, all with the goal of maximizing returns while managing risk.
#
# This project represents a convergence of finance, machine learning, and technology. Our DRL model is designed to make informed trading decisions, considering historical data, market indicators, and other relevant factors, ultimately offering the potential to outperform traditional trading methods. The ability to harness the power of neural networks, paired with reinforcement learning principles, promises a new era in algorithmic trading.
#
# In this project, we will explore the development and implementation of our DRL model, highlighting its capabilities, challenges, and real-world implications in the realm of financial markets. We invite you to journey with us through the intricacies of this innovative approach, where artificial intelligence meets finance, and together, we aim to shape the future of trading.
#
# <br>
#
# ### Objective & Scope
# - Collect, clean & analyze Bitcoin crypto market data
# - Features Engineering
# - Build a DRL trading environment
# - Train & improve the agent
#
# <br>
#
# ### Deep Reinformencement Learning Model
#
# - **Reinforcement Learning Algorithm (RLA):** PPO (Proximal Policy Optimization)
#
# - **Neural Network Architecture for Policy (Agent's action):** MLP Policy (Multi-Layer Perceptron Policy)
#     - **Architecture Details:**
#         - **Input Layer:** The MLP policy takes observations from the environment as input.
#         - **Hidden Layers:** The network typically consists of one or more hidden layers, each containing multiple neurons. The specific number of layers and neurons may vary depending on the complexity of the problem.
#         - **Activation Functions:** Each layer in the MLP policy may utilize activation functions like ReLU (Rectified Linear Unit) or Tanh.
#         - **Output Layer**: The output layer provides the probabilities or values associated with different actions the agent can take.
#     - **Training Process:**
#         - The model is trained using PPO, which involves optimizing the policy network to maximize cumulative rewards while ensuring that policy updates are within a safe margin.
#
# <br>
#
# Enjoy and looking forward to read your feedback.
#
# F.G.J

# %% [markdown]
# ## <span style="color:#5E6997"> Data Engineering </span> <a class="anchor" id="data_eng"></a>

# %%
pip install stable-baselines3
# Out:
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (1.1.1)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.6.0+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable-baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.2)
# Downloading stable_baselines3-2.6.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 3.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 80.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 20.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 31.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 43.5 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable-baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable-baselines3-2.6.0

# %%
pip install 'shimmy>=0.2.1'
# Out:
# Collecting shimmy>=0.2.1
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from shimmy>=0.2.1) (2.0.2)
# Requirement already satisfied: gymnasium>=1.0.0a1 in /usr/local/lib/python3.11/dist-packages (from shimmy>=0.2.1) (1.1.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy>=0.2.1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy>=0.2.1) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy>=0.2.1) (0.0.4)
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Installing collected packages: shimmy
# Successfully installed shimmy-2.0.0

# %%
import pandas as pd
import gym
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
import warnings
warnings.filterwarnings("ignore")

# %%
# Assuming crypto_data.csv is in the specified directory
file_path = franoisgeorgesjulien_crypto_path + '/crypto_data.csv'
new_var = pd.read_csv(file_path)
df = new_var

# %%
df.head()
# Out:
#                   date     symbol    open    high     low   close  \
# 0  2020-12-25 05:00:00  1INCHUSDT  0.2000  3.0885  0.2000  2.5826
# 1  2020-12-25 06:00:00  1INCHUSDT  2.5824  2.6900  2.2249  2.5059
# 2  2020-12-25 07:00:00  1INCHUSDT  2.5152  2.8870  2.3609  2.6237
# 3  2020-12-25 08:00:00  1INCHUSDT  2.6318  2.8247  2.4650  2.6134
# 4  2020-12-25 09:00:00  1INCHUSDT  2.6104  2.7498  2.5629  2.6365
#
#    volume usdt  tradecount  token  hour     day
# 0     35530516       48768  1INCH     5  Friday
# 1     22440875       31099  1INCH     6  Friday
# 2     21300426       33001  1INCH     7  Friday
# 3     17491813       30459  1INCH     8  Friday
# 4      9919400       21023  1INCH     9  Friday

# %%
df.columns
# Out:
# Index(['date', 'symbol', 'open', 'high', 'low', 'close', 'volume usdt',
#        'tradecount', 'token', 'hour', 'day'],
#       dtype='object')

# %%
start_date = '2020-08-17 04:00:00'
end_date = '2023-10-19 23:00:00'

# %%
data_df = df.copy(deep=True)

# %%
data_df = data_df[(data_df['token'] == 'BTC') & (data_df['date'] >= start_date) & (data_df['date'] <= end_date)]

# %%
data_df.columns
# Out:
# Index(['date', 'symbol', 'open', 'high', 'low', 'close', 'volume usdt',
#        'tradecount', 'token', 'hour', 'day'],
#       dtype='object')

# %% [markdown]
# ### Mapping 'day' days to numerical values

# %%
day_mapping = {
    'Monday': 1,
    'Tuesday': 2,
    'Wednesday': 3,
    'Thursday': 4,
    'Friday': 5,
    'Saturday': 6,
    'Sunday': 7
}

data_df['day'] = data_df['day'].apply(lambda x: day_mapping[x])

# %% [markdown]
# ### Creating new columns EMAs (EMA 13 25 32 100 200)

# %%
data_df['ema_13'] = data_df['close'].ewm(span=13).mean()
data_df['ema_25'] = data_df['close'].ewm(span=25).mean()
data_df['ema_32'] = data_df['close'].ewm(span=32).mean()
data_df['ema_100'] = data_df['close'].ewm(span=100).mean()
data_df['ema_200'] = data_df['close'].ewm(span=200).mean()

# %% [markdown]
# ### Creating Candle Volatility Against Price Close (high - low / close)

# %%
data_df['vol_close'] = (data_df['high'] - data_df['low']) / data_df['close']

# %% [markdown]
# ### Creating EMA for Candle Volatility/Price

# %%
# EMA for 2 hours (candles)
data_df['vol_close_ema_3'] = data_df['vol_close'].ewm(span=3, adjust=False).mean()

# EMA for 4 hours (candles)
data_df['vol_close_ema_6'] = data_df['vol_close'].ewm(span=6, adjust=False).mean()

# EMA for 8 hours ((candles)
data_df['vol_close_ema_12'] = data_df['vol_close'].ewm(span=12, adjust=False).mean()

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 27812 entries, 343607 to 371418
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              27812 non-null  object
#  1   symbol            27812 non-null  object
#  2   open              27812 non-null  float64
#  3   high              27812 non-null  float64
#  4   low               27812 non-null  float64
#  5   close             27812 non-null  float64
#  6   volume usdt       27812 non-null  int64
#  7   tradecount        27812 non-null  int64
#  8   token             27812 non-null  object
#  9   hour              27812 non-null  int64
#  10  day               27812 non-null  int64
#  11  ema_13            27812 non-null  float64
#  12  ema_25            27812 non-null  float64
#  13  ema_32            27812 non-null  float64
#  14  ema_100           27812 non-null  float64
#  15  ema_200           27812 non-null  float64
#  16  vol_close         27812 non-null  float64
#  17  vol_close_ema_3   27812 non-null  float64
#  18  vol_close_ema_6   27812 non-null  float64
#  19  vol_close_ema_12  27812 non-null  float64
# dtypes: float64(13), int64(4), object(3)
# memory usage: 4.5+ MB

# %%
data_df['date'] = pd.to_datetime(data_df['date'])

# %%
columns_to_drop = ['symbol', 'token']
data_df = data_df.drop(columns=columns_to_drop)

# %%
#data_df = data_df.astype(float)
#data_df.set_index('date', inplace=True)

# %%
data_df.to_csv('data_featured.csv', index=False)

# %%
train_df = data_df.copy(deep=True)
train_df.reset_index(drop=True, inplace=True)

# %%
train_df
# Out:
#                      date      open      high       low     close  \
# 0     2020-08-17 04:00:00  11844.72  11858.91  11802.35  11809.38
# 1     2020-08-17 05:00:00  11809.39  11836.90  11790.00  11800.01
# 2     2020-08-17 06:00:00  11800.00  11846.74  11785.23  11806.37
# 3     2020-08-17 07:00:00  11806.37  11843.01  11792.32  11807.21
# 4     2020-08-17 08:00:00  11806.94  11885.00  11806.91  11868.77
# ...                   ...       ...       ...       ...       ...
# 27807 2023-10-19 19:00:00  28646.98  28765.76  28645.00  28750.75
# 27808 2023-10-19 20:00:00  28750.75  28882.07  28684.80  28715.38
# 27809 2023-10-19 21:00:00  28715.39  28739.73  28604.09  28604.09
# 27810 2023-10-19 22:00:00  28604.09  28704.99  28598.60  28649.65
# 27811 2023-10-19 23:00:00  28649.64  28717.82  28630.19  28713.71
#
#        volume usdt  tradecount  hour  day        ema_13        ema_25  \
# 0         17196539       28800     4    1  11809.380000  11809.380000
# 1         19958274       28571     5    1  11804.334615  11804.507600
# 2         19327915       29762     6    1  11805.119921  11805.178699
# 3         22698672       33111     7    1  11805.768697  11805.749021
# 4         28031116       37458     8    1  11822.518351  11820.447106
# ...            ...         ...   ...  ...           ...           ...
# 27807     29840591       49985    19    4  28551.404418  28476.370598
# 27808     49976234       59830    20    4  28574.829501  28494.755937
# 27809     32056663       42623    21    4  28579.009572  28503.166249
# 27810     22004203       28479    22    4  28589.101062  28514.434230
# 27811     17582981       27099    23    4  28606.902339  28529.763135
#
#              ema_32       ema_100       ema_200  vol_close  vol_close_ema_3  \
# 0      11809.380000  11809.380000  11809.380000   0.004789         0.004789
# 1      11804.548594  11804.648150  11804.671575   0.003975         0.004382
# 2      11805.194058  11805.233617  11805.243387   0.005210         0.004796
# 3      11805.746245  11805.742633  11805.742440   0.004293         0.004545
# 4      11819.974205  11818.857316  11818.601316   0.006579         0.005562
# ...             ...           ...           ...        ...              ...
# 27807  28449.944844  28143.362798  27837.239673   0.004200         0.005770
# 27808  28466.031824  28154.689871  27845.977388   0.006870         0.006320
# 27809  28474.398986  28163.588884  27853.520797   0.004742         0.005531
# 27810  28485.020259  28173.213856  27861.442481   0.003713         0.004622
# 27811  28498.880244  28183.916750  27869.922755   0.003052         0.003837
#
#        vol_close_ema_6  vol_close_ema_12
# 0             0.004789          0.004789
# 1             0.004557          0.004664
# 2             0.004743          0.004748
# 3             0.004615          0.004678
# 4             0.005176          0.004971
# ...                ...               ...
# 27807         0.006508          0.006222
# 27808         0.006611          0.006322
# 27809         0.006077          0.006079
# 27810         0.005402          0.005715
# 27811         0.004730          0.005305
#
# [27812 rows x 18 columns]

# %%
df_test = data_df[10000:]
df_test = df_test.reset_index(drop=True)

# %% [markdown]
# ## <span style="color:#5E6997"> DRL Environment Architecture </span> <a class="anchor" id="env"></a>

# %% [markdown]
# **Environment Controls:**
# - **data**: A DataFrame containing the financial data. (passed when called the function 'env' CryptoTradingEnv(data_df))
# - **take_profit_range**: A tuple representing the range for take profit levels.
# - **stop_loss_range**: A tuple representing the range for stop loss levels.
# - **max_stop_loss**: The maximum allowable stop loss.
# - **position_size**: The maximum allowable position size.
# - **initial_balance**: The initial capital.
# - **balance**: Current balance.
# - **position**: The current position (0 for no position, 1 for long position).
# - **position_open**: The price at which the position was opened.
# - **num_trades**: The number of trades.
# - **profit_loss**: The cumulative profit/loss.
# - **position_size**: The calculated position size as a percentage of the current balance (controlled within the code).
#
#  <br>
#
# **Obversations:**
# - open, high, low, close, volume usdt, hour, day, ema_13, ema_25, ema_32, ema_100, ema_200, vol_close_ema_3, vol_close_ema_6, vol_close_ema_12
#
#  <br>
#
# **Initial Reward Calculation:**
# - When an action is taken, the reward variable is initialized to 0.
# - The variable trade_outcome is used to calculate the profit or loss associated with the most recent trade. It is initialized to 0.
#
#  <br>
#
# **Opening and Closing Trades:**
# - If the agent takes the action to open a position (action code 1), and it is not already in a trade (self.position == 0), it calculates the position_size based on the balance or maximum position size, and records the opening price.
# - If the agent takes the action to close a position (action code 2), and it is currently in a trade (self.position == 1), it calculates the trade outcome as the difference between the opening price and the current market price.
# - The profit_loss is updated with the trade outcome, representing the cumulative profit or loss across all trades.
# - The balance is adjusted based on the trade outcome.
#
#  <br>
#
# **Take Profit and Stop Loss:**
# - The code checks whether the trade outcome is greater than 0 (a winning trade) and whether it reaches the take profit level defined by self.take_profit_range.
# - If the trade reaches the take profit level (>0), a reward of 0.5 is assigned to indicate a successful trade.
# - If the trade is closed within the take profit range, an extra reward of 1 is assigned to indicate a successful trade.
# - If the trade outcome is less than 0 (a losing trade), the code checks for two conditions:
# - If the trade outcome is egual or exceeds the maximum allowable stop loss (self.max_stop_loss * self.balance), a malus reward of -0.7 is assigned, indicating that the trade reached the maximum stop loss.
# - If the trade outcome falls within the stop loss range defined by self.stop_loss_range, a reward of -1 is assigned, indicating that the trade reached the stop loss.
#
#  <br>
#
# **Trade Outcome Within Range:**
# - If trade_within_range is True, it means that the trade outcome fell within the specified take profit range. In this case, self.winning_trade_within_range is incremented to keep track of such trades.
#
#  <br>
#
# **Cumulative Returns and Episode Tracking:**
# - The reward is also added to the episode_returns list to track rewards for the current episode.
# - The cumulative_returns is updated with the reward to keep track of cumulative returns.
#
#  <br>
#
# **Completing an Episode:**
# - If the current step reaches the end of the trading data (self.current_step >= self.n_steps), the done flag is set to True, indicating that the episode has ended.

# %% [markdown]
# # DRL Environment v1

# %%
class CryptoTradingEnv(gym.Env):
    def __init__(self, data, take_profit_position_range=(0.10, 0.80), stop_loss_position_range=(0.00, 0.15), max_stop_loss_position=0.30):
        super(CryptoTradingEnv, self).__init__()

        self.data = data
        self.n_steps = len(data)
        self.current_step = 0
        self.initial_balance = 100000
        self.balance = self.initial_balance
        self.position = 0
        self.position_open = 0 # Price at which the position was opened
        self.num_trades = 0  # Number of trades
        self.profit_loss = 0  # PnL Profit/Loss
        self.max_stop_loss_position = max_stop_loss_position

        self.take_profit_position_range = take_profit_position_range
        self.stop_loss_position_range = stop_loss_position_range

        # 0=Hold, 1=Open Position, 2=Close Position
        self.action_space = gym.spaces.Discrete(3)

        # Observations
        n_features = 15
        self.observation_space = gym.spaces.Box(low=0, high=1, shape=(n_features,))

        self.episode_returns = []
        self.cumulative_returns = 0
        self.winning_trades = 0
        self.losing_trades = 0
        self.hourly_returns = []

        self.overall_rewards = 0


    def step(self, action):
        self.current_step += 1
        done = False

        reward = 0
        trade_outcome = 0
        trade_within_range = False

        if action == 1:  # Open Position
            if self.position == 0:  # Only open a position if not already in a trade
                position_size = 0.05 * self.balance

                self.position_open = self.data.loc[self.current_step, 'open']
                self.position = 1
                self.num_trades += 1
                print(f"Opened trade at step {self.current_step} with position size: {position_size:.2f}")
        elif action == 2:  # Close Position
            if self.position == 1:  # Only close a position if currently in a trade
                position_close = self.data.loc[self.current_step, 'open']
                trade_outcome = position_close - self.position_open
                self.profit_loss += trade_outcome
                self.position = 0
                self.position_open = 0
                print(f"Closed trade at step {self.current_step}")
                print(f"------------------------------> Trade outcome: {trade_outcome}")

                self.balance += trade_outcome

                # Check for take profit and stop loss
                if trade_outcome > 0:
                    if trade_outcome >= self.take_profit_position_range[0] * self.position:
                        reward = 1  # Trade reached take profit
                        self.winning_trades += 1  # +1 winning trades count
                        if trade_outcome <= self.take_profit_position_range[1] * self.position and trade_outcome >= self.take_profit_position_range[0] * self.position:
                           # self.trade_within_range = True
                            print("Trade reached take profit")
                elif trade_outcome < 0:
                    if abs(trade_outcome) >= self.max_stop_loss_position * self.position:
                        reward = -1.7  # Trade reached the maximum stop loss
                        self.losing_trades += 1  # +1 losing trades count
                        print("Trade reached the maximum stop loss")
                    elif abs(trade_outcome) >= self.stop_loss_position_range[0] * self.position:
                        reward = -1  # Trade reached the stop loss
                        self.losing_trades += 1  # +1 losing trades count
                        print("Trade reached stop loss")
                    else:
                        # No reward (positive and negative) if the trade closed with no loss
                        reward = 0
                        print("Trade closed with no loss")

 #               if trade_within_range:
  #                  self.winning_trade_within_range += 1

    # reward based on profit/loss of the last trade
#        reward += trade_outcome
        if trade_outcome > 0:
            reward += 0.5
        print(f"Reward: {reward}")

        # reward for this episode
        self.episode_returns.append(reward)

        # cumulative returns
        self.cumulative_returns += reward

        # hourly returns for daily return calculation
#        self.hourly_returns.append(reward)

        self.overall_rewards += reward

        if self.current_step >= self.n_steps:
            done = True

        next_state = self.get_observation()
        return next_state, reward, done, {}


    def reset(self):
        self.current_step = 0
        self.position = 0
        self.position_open = 0
        episode_return = np.sum(self.episode_returns)
        self.episode_returns = []
        self.cumulative_returns += episode_return
        self.current_week_start = 0
        return self.get_observation()

    def render(self, mode='human'):
        if mode == 'human':
            print(f"Step: {self.current_step}")
            print(f"Open Position: {self.position}")
            print(f"Trades: {self.num_trades} | Profit/Loss: {self.profit_loss:.2f}")
            print(f"Balance: {self.balance:.2f}")
            print(f"Winning Trades: {self.winning_trades} | Losing Trades: {self.losing_trades}")
            print(f"Overall Rewards: {self.overall_rewards:.2f}")
            print(self.data.loc[self.current_step])

    def close(self):
        pass

    def get_observation(self):
        obs = self.data.loc[self.current_step, [
            'open', 'high', 'low', 'close', 'volume usdt', 'hour', 'day',
            'ema_13', 'ema_25', 'ema_32', 'ema_100', 'ema_200', 'vol_close_ema_3', 'vol_close_ema_6', 'vol_close_ema_12'
        ]].values.astype(np.float32)
        return obs / obs.max()

# %% [markdown]
# ## <span style="color:#5E6997"> DRL Agent Architecture </span> <a class="anchor" id="agent"></a>

# %% [markdown]
# # DRL Agent v1

# %%
num_episodes = 5000
print_interval = 100

env = CryptoTradingEnv(train_df)

obs = env.reset()

agent = PPO("MlpPolicy", DummyVecEnv([lambda: env]), verbose=1, tensorboard_log="./ppo_logs/")

max_steps = 5000 # I was getting error for out of index so i limited the max step

for episode in range(num_episodes):
    obs = np.array(obs, dtype=np.float32)
    action, _ = agent.predict(obs, deterministic=False)

    remaining_steps = min(max_steps - env.current_step, env.n_steps)

    if remaining_steps > 0:
        obs, reward, done, _ = env.step(action)
        env.render()

#    if done:
#        obs = env.reset()

    if (episode + 1) % print_interval == 0:
        print(f"Episode {episode + 1}: Final Rewards: {env.cumulative_returns:.2f} | Total Trades: {env.num_trades}")
# Out:
# Streaming output truncated to the last 5000 lines.
# ema_13                     47633.347661
# ema_25                     47864.364544
# ema_32                     48033.941795
# ema_100                    48473.409103
# ema_200                    48635.544102
# vol_close                      0.020615
# vol_close_ema_3                0.019054
# vol_close_ema_6                0.017789
# vol_close_ema_12               0.016843
# Name: 4812, dtype: object
# Reward: 0
# Step: 4813
# Open Position: 1
# Trades: 805 | Profit/Loss: 41581.03
# Balance: 141581.03
# Winning Trades: 436 | Losing Trades: 368
# Overall Rewards: 28.40
# date                2021-03-05 17:00:00
# open                           47656.65
# high                           48237.42
# low                             47320.0
# close                          48096.01
# volume usdt                   169030692
# tradecount                        73267
# hour                                 17
# day                                   5
# ema_13                     47699.442281
# ema_25                     47882.183425
# ema_32                     48037.703504
# ema_100                    48465.935853
# ema_200                    48630.175604
# vol_close                      0.019075
# vol_close_ema_3                0.019064
# vol_close_ema_6                0.018156
# vol_close_ema_12               0.017186
# Name: 4813, dtype: object
# Reward: 0
# Step: 4814
# Open Position: 1
# Trades: 805 | Profit/Loss: 41581.03
# Balance: 141581.03
# Winning Trades: 436 | Losing Trades: 368
# Overall Rewards: 28.40
# date                2021-03-05 18:00:00
# open                            48096.0
# high                            48558.5
# low                            47918.38
# close                          48478.11
# volume usdt                   146912675
# tradecount                       102775
# hour                                 18
# day                                   5
# ema_13                     47810.680527
# ema_25                     47928.023931
# ema_32                     48064.394807
# ema_100                    48466.176926
# ema_200                    48628.662513
# vol_close                      0.013204
# vol_close_ema_3                0.016134
# vol_close_ema_6                0.016741
# vol_close_ema_12               0.016574
# Name: 4814, dtype: object
# Reward: 0
# Step: 4815
# Open Position: 1
# Trades: 805 | Profit/Loss: 41581.03
# Balance: 141581.03
# Winning Trades: 436 | Losing Trades: 368
# Overall Rewards: 28.40
# date                2021-03-05 19:00:00
# open                           48478.12
# high                            49400.0
# low                             48310.4
# close                          49295.47
# volume usdt                   180194818
# tradecount                        81593
# hour                                 19
# day                                   5
# ema_13                     48022.793308
# ema_25                      48033.21209
# ema_32                     48139.005425
# ema_100                    48482.598571
# ema_200                    48635.297414
# vol_close                      0.022103
# vol_close_ema_3                0.019119
# vol_close_ema_6                0.018273
# vol_close_ema_12               0.017424
# Name: 4815, dtype: object
# Reward: 0
# Step: 4816
# Open Position: 1
# Trades: 805 | Profit/Loss: 41581.03
# Balance: 141581.03
# Winning Trades: 436 | Losing Trades: 368
# Overall Rewards: 28.40
# date                2021-03-05 20:00:00
# open                           49285.76
# high                           49448.93
# low                            48832.17
# close                          49173.85
# volume usdt                   143449027
# tradecount                        98086
# hour                                 20
# day                                   5
# ema_13                     48187.229979
# ema_25                     48120.953468
# ema_32                     48201.723278
# ema_100                    48496.286718
# ema_200                    48640.656146
# vol_close                      0.012542
# vol_close_ema_3                0.015831
# vol_close_ema_6                0.016636
# vol_close_ema_12               0.016673
# Name: 4816, dtype: object
# Reward: 0
# Step: 4817
# Open Position: 1
# Trades: 805 | Profit/Loss: 41581.03
# Balance: 141581.03
# Winning Trades: 436 | Losing Trades: 368
# Overall Rewards: 28.40
# date                2021-03-05 21:00:00
# open                           49173.85
# high                            49398.0
# low                            48890.97
# close                          49035.21
# volume usdt                   100533177
# tradecount                        49623
# hour                                 21
# day                                   5
# ema_13                     48308.369982
# ema_25                     48191.280893
# ema_32                     48252.237625
# ema_100                    48506.958466
# ema_200                    48644.582055
# vol_close                       0.01034
# vol_close_ema_3                0.013085
# vol_close_ema_6                0.014837
# vol_close_ema_12               0.015699
# Name: 4817, dtype: object
# Reward: 0
# Step: 4818
# Open Position: 1
# Trades: 805 | Profit/Loss: 41581.03
# Balance: 141581.03
# Winning Trades: 436 | Losing Trades: 368
# Overall Rewards: 28.40
# date                2021-03-05 22:00:00
# open                            49035.2
# high                           49389.99
# low                            48673.71
# close                          49061.76
# volume usdt                    87064645
# tradecount                        68027
# hour                                 22
# day                                   5
# ema_13                     48415.997127
# ema_25                     48258.240825
# ema_32                     48301.299587
# ema_100                    48517.944635
# ema_200                    48648.733079
# vol_close                        0.0146
# vol_close_ema_3                0.013842
# vol_close_ema_6                0.014769
# vol_close_ema_12                0.01553
# Name: 4818, dtype: object
# Closed trade at step 4819
# ------------------------------> Trade outcome: 1194.3199999999997
# Reward: 1.5
# Step: 4819
# Open Position: 0
# Trades: 805 | Profit/Loss: 42775.35
# Balance: 142775.35
# Winning Trades: 437 | Losing Trades: 368
# Overall Rewards: 29.90
# date                2021-03-05 23:00:00
# open                           49061.77
# high                           49160.29
# low                            48579.59
# close                          48751.71
# volume usdt                    98728784
# tradecount                        56088
# hour                                 23
# day                                   5
# ema_13                     48463.956109
# ema_25                     48296.199992
# ema_32                     48328.597188
# ema_100                    48522.573652
# ema_200                    48649.757725
# vol_close                      0.011911
# vol_close_ema_3                0.012877
# vol_close_ema_6                0.013953
# vol_close_ema_12               0.014973
# Name: 4819, dtype: object
# Reward: 0
# Step: 4820
# Open Position: 0
# Trades: 805 | Profit/Loss: 42775.35
# Balance: 142775.35
# Winning Trades: 437 | Losing Trades: 368
# Overall Rewards: 29.90
# date                2021-03-06 00:00:00
# open                           48746.81
# high                            49156.0
# low                            48675.67
# close                          48808.05
# volume usdt                    90328263
# tradecount                        50809
# hour                                  0
# day                                   6
# ema_13                     48513.112379
# ema_25                      48335.57307
# ema_32                     48357.654934
# ema_100                    48528.226649
# ema_200                    48651.332773
# vol_close                      0.009841
# vol_close_ema_3                0.011359
# vol_close_ema_6                0.012778
# vol_close_ema_12               0.014184
# Name: 4820, dtype: object
# Reward: 0
# Step: 4821
# Open Position: 0
# Trades: 805 | Profit/Loss: 42775.35
# Balance: 142775.35
# Winning Trades: 437 | Losing Trades: 368
# Overall Rewards: 29.90
# date                2021-03-06 01:00:00
# open                           48807.83
# high                           48901.65
# low                             48520.0
# close                          48647.38
# volume usdt                    62960628
# tradecount                        36753
# hour                                  1
# day                                   6
# ema_13                     48532.293468
# ema_25                     48359.558218
# ema_32                     48375.214029
# ema_100                    48530.586121
# ema_200                    48651.293442
# vol_close                      0.007845
# vol_close_ema_3                0.009602
# vol_close_ema_6                0.011369
# vol_close_ema_12               0.013209
# Name: 4821, dtype: object
# Reward: 0
# Step: 4822
# Open Position: 0
# Trades: 805 | Profit/Loss: 42775.35
# Balance: 142775.35
# Winning Trades: 437 | Losing Trades: 368
# Overall Rewards: 29.90
# date                2021-03-06 02:00:00
# open                       48644.103755
# high                       48694.330451
# low                        48200.454407
# close                       48694.23662
# volume usdt                          24
# tradecount                            0
# hour                                  2
# day                                   6
# ema_13                     48555.428204
# ema_25                     48385.302711
# ema_32                     48394.548731
# ema_100                    48533.826725
# ema_200                    48651.720737
# vol_close                      0.010142
# vol_close_ema_3                0.009872
# vol_close_ema_6                0.011018
# vol_close_ema_12               0.012737
# Name: 4822, dtype: object
# Opened trade at step 4823 with position size: 7138.77
# Reward: 0
# Step: 4823
# Open Position: 1
# Trades: 806 | Profit/Loss: 42775.35
# Balance: 142775.35
# Winning Trades: 437 | Losing Trades: 368
# Overall Rewards: 29.90
# date                2021-03-06 03:00:00
# open                           48647.37
# high                           48801.81
# low                             48350.0
# close                          48657.72
# volume usdt                    39764114
# tradecount                        24356
# hour                                  3
# day                                   6
# ema_13                     48570.041318
# ema_25                     48406.257887
# ema_32                     48410.498505
# ema_100                    48536.280057
# ema_200                    48651.780431
# vol_close                      0.009285
# vol_close_ema_3                0.009579
# vol_close_ema_6                0.010523
# vol_close_ema_12               0.012206
# Name: 4823, dtype: object
# Closed trade at step 4824
# ------------------------------> Trade outcome: 10.349999999998545
# Reward: 1.5
# Step: 4824
# Open Position: 0
# Trades: 806 | Profit/Loss: 42785.70
# Balance: 142785.70
# Winning Trades: 438 | Losing Trades: 368
# Overall Rewards: 31.40
# date                2021-03-06 04:00:00
# open                           48657.72
# high                           48687.49
# low                            48115.83
# close                          48451.16
# volume usdt                    83446085
# tradecount                        65417
# hour                                  4
# day                                   6
# ema_13                     48553.058272
# ema_25                     48409.711895
# ema_32                     48412.962838
# ema_100                    48534.594512
# ema_200                    48649.784208
# vol_close                      0.011799
# vol_close_ema_3                0.010689
# vol_close_ema_6                0.010888
# vol_close_ema_12               0.012143
# Name: 4824, dtype: object
# Opened trade at step 4825 with position size: 7139.28
# Reward: 0
# Step: 4825
# Open Position: 1
# Trades: 807 | Profit/Loss: 42785.70
# Balance: 142785.70
# Winning Trades: 438 | Losing Trades: 368
# Overall Rewards: 31.40
# date                2021-03-06 05:00:00
# open                           48450.12
# high                           48895.32
# low                             48193.0
# close                          48496.28
# volume usdt                    80307402
# tradecount                        60397
# hour                                  5
# day                                   6
# ema_13                     48544.947091
# ema_25                      48416.37098
# ema_32                     48418.012363
# ema_100                    48533.835809
# ema_200                    48648.256803
# vol_close                      0.014482
# vol_close_ema_3                0.012585
# vol_close_ema_6                0.011915
# vol_close_ema_12               0.012503
# Name: 4825, dtype: object
# Closed trade at step 4826
# ------------------------------> Trade outcome: 46.14999999999418
# Reward: 1.5
# Step: 4826
# Open Position: 0
# Trades: 807 | Profit/Loss: 42831.85
# Balance: 142831.85
# Winning Trades: 439 | Losing Trades: 368
# Overall Rewards: 32.90
# date                2021-03-06 06:00:00
# open                           48496.27
# high                           48971.29
# low                            48482.17
# close                           48922.0
# volume usdt                    85589316
# tradecount                        45201
# hour                                  6
# day                                   6
# ema_13                     48598.811792
# ema_25                      48455.26552
# ema_32                     48448.557068
# ema_100                    48541.522228
# ema_200                    48650.980616
# vol_close                      0.009998
# vol_close_ema_3                0.011292
# vol_close_ema_6                0.011367
# vol_close_ema_12               0.012118
# Name: 4826, dtype: object
# Reward: 0
# Step: 4827
# Open Position: 0
# Trades: 807 | Profit/Loss: 42831.85
# Balance: 142831.85
# Winning Trades: 439 | Losing Trades: 368
# Overall Rewards: 32.90
# date                2021-03-06 07:00:00
# open                            48922.0
# high                           49117.32
# low                            48772.24
# close                          48820.12
# volume usdt                    80636496
# tradecount                        44370
# hour                                  7
# day                                   6
# ema_13                      48630.42725
# ema_25                      48483.33125
# ema_32                     48471.076034
# ema_100                    48547.039016
# ema_200                    48652.663595
# vol_close                      0.007068
# vol_close_ema_3                 0.00918
# vol_close_ema_6                0.010139
# vol_close_ema_12               0.011341
# Name: 4827, dtype: object
# Reward: 0
# Step: 4828
# Open Position: 0
# Trades: 807 | Profit/Loss: 42831.85
# Balance: 142831.85
# Winning Trades: 439 | Losing Trades: 368
# Overall Rewards: 32.90
# date                2021-03-06 08:00:00
# open                           48820.13
# high                            49100.0
# low                             48600.0
# close                          48641.64
# volume usdt                   109189858
# tradecount                        94092
# hour                                  8
# day                                   6
# ema_13                     48632.029072
# ema_25                     48495.508846
# ema_32                     48481.413244
# ema_100                    48548.912303
# ema_200                    48652.553907
# vol_close                      0.010279
# vol_close_ema_3                 0.00973
# vol_close_ema_6                0.010179
# vol_close_ema_12               0.011177
# Name: 4828, dtype: object
# Reward: 0
# Step: 4829
# Open Position: 0
# Trades: 807 | Profit/Loss: 42831.85
# Balance: 142831.85
# Winning Trades: 439 | Losing Trades: 368
# Overall Rewards: 32.90
# date                2021-03-06 09:00:00
# open                           48641.65
# high                            48785.0
# low                            48270.01
# close                           48335.1
# volume usdt                    91307736
# tradecount                        48858
# hour                                  9
# day                                   6
# ema_13                     48589.610633
# ema_25                     48483.169704
# ema_32                     48472.545775
# ema_100                    48544.678396
# ema_200                    48649.395162
# vol_close                      0.010655
# vol_close_ema_3                0.010192
# vol_close_ema_6                0.010315
# vol_close_ema_12               0.011097
# Name: 4829, dtype: object
# Reward: 0
# Step: 4830
# Open Position: 0
# Trades: 807 | Profit/Loss: 42831.85
# Balance: 142831.85
# Winning Trades: 439 | Losing Trades: 368
# Overall Rewards: 32.90
# date                2021-03-06 10:00:00
# open                           48335.22
# high                           48499.99
# low                             48000.0
# close                          48035.36
# volume usdt                   103866218
# tradecount                        86010
# hour                                 10
# day                                   6
# ema_13                     48510.431971
# ema_25                     48448.722803
# ema_32                     48446.049667
# ema_100                    48534.592883
# ema_200                    48643.285359
# vol_close                      0.010409
# vol_close_ema_3                  0.0103
# vol_close_ema_6                0.010342
# vol_close_ema_12               0.010991
# Name: 4830, dtype: object
# Opened trade at step 4831 with position size: 7141.59
# Reward: 0
# Step: 4831
# Open Position: 1
# Trades: 808 | Profit/Loss: 42831.85
# Balance: 142831.85
# Winning Trades: 439 | Losing Trades: 368
# Overall Rewards: 32.90
# date                2021-03-06 11:00:00
# open                           48035.37
# high                           48331.91
# low                             48000.0
# close                          48171.01
# volume usdt                    67556133
# tradecount                        65040
# hour                                 11
# day                                   6
# ema_13                     48461.943118
# ema_25                      48427.36028
# ema_32                     48429.380596
# ema_100                    48527.393222
# ema_200                    48638.586102
# vol_close                       0.00689
# vol_close_ema_3                0.008595
# vol_close_ema_6                0.009356
# vol_close_ema_12                0.01036
# Name: 4831, dtype: object
# Closed trade at step 4832
# ------------------------------> Trade outcome: 135.64999999999418
# Reward: 1.5
# Step: 4832
# Open Position: 0
# Trades: 808 | Profit/Loss: 42967.50
# Balance: 142967.50
# Winning Trades: 440 | Losing Trades: 368
# Overall Rewards: 34.40
# date                2021-03-06 12:00:00
# open                           48171.02
# high                           48212.85
# low                            47401.82
# close                          47660.74
# volume usdt                   157314265
# tradecount                       107114
# hour                                 12
# day                                   6
# ema_13                      48347.48553
# ema_25                     48368.389489
# ema_32                     48382.796318
# ema_100                    48510.231772
# ema_200                     48628.85629
# vol_close                      0.017017
# vol_close_ema_3                0.012806
# vol_close_ema_6                0.011544
# vol_close_ema_12               0.011384
# Name: 4832, dtype: object
# Reward: 0
# Step: 4833
# Open Position: 0
# Trades: 808 | Profit/Loss: 42967.50
# Balance: 142967.50
# Winning Trades: 440 | Losing Trades: 368
# Overall Rewards: 34.40
# date                2021-03-06 13:00:00
# open                           47660.75
# high                           47753.39
# low                             47070.0
# close                           47320.3
# volume usdt                   147223560
# tradecount                       111334
# hour                                 13
# day                                   6
# ema_13                      48200.74474
# ema_25                     48287.767221
# ema_32                     48318.402602
# ema_100                    48486.668766
# ema_200                    48615.835829
# vol_close                      0.014442
# vol_close_ema_3                0.013624
# vol_close_ema_6                0.012372
# vol_close_ema_12               0.011855
# Name: 4833, dtype: object
# Reward: 0
# Step: 4834
# Open Position: 0
# Trades: 808 | Profit/Loss: 42967.50
# Balance: 142967.50
# Winning Trades: 440 | Losing Trades: 368
# Overall Rewards: 34.40
# date                2021-03-06 14:00:00
# open                            47320.3
# high                           47725.51
# low                            47201.12
# close                          47560.96
# volume usdt                    86454117
# tradecount                        85390
# hour                                 14
# day                                   6
# ema_13                      48109.34692
# ema_25                     48231.858973
# ema_32                     48272.496989
# ema_100                      48468.3379
# ema_200                    48605.339552
# vol_close                      0.011026
# vol_close_ema_3                0.012325
# vol_close_ema_6                0.011988
# vol_close_ema_12               0.011727
# Name: 4834, dtype: object
# Opened trade at step 4835 with position size: 7148.37
# Reward: 0
# Step: 4835
# Open Position: 1
# Trades: 809 | Profit/Loss: 42967.50
# Balance: 142967.50
# Winning Trades: 440 | Losing Trades: 368
# Overall Rewards: 34.40
# date                2021-03-06 15:00:00
# open                           47562.67
# high                           47712.69
# low                            47238.32
# close                          47267.88
# volume usdt                    70130991
# tradecount                        64970
# hour                                 15
# day                                   6
# ema_13                      47989.13736
# ema_25                     48157.706744
# ema_32                     48211.611111
# ema_100                    48444.566456
# ema_200                    48592.031497
# vol_close                      0.010036
# vol_close_ema_3                 0.01118
# vol_close_ema_6                 0.01143
# vol_close_ema_12               0.011467
# Name: 4835, dtype: object
# Reward: 0
# Step: 4836
# Open Position: 1
# Trades: 809 | Profit/Loss: 42967.50
# Balance: 142967.50
# Winning Trades: 440 | Losing Trades: 368
# Overall Rewards: 34.40
# date                2021-03-06 16:00:00
# open                           47267.88
# high                           47941.03
# low                            47104.85
# close                          47757.43
# volume usdt                   118538410
# tradecount                        67272
# hour                                 16
# day                                   6
# ema_13                     47956.036308
# ema_25                     48126.916226
# ema_32                     48184.084983
# ema_100                    48430.959794
# ema_200                    48583.727005
# vol_close                      0.017509
# vol_close_ema_3                0.014345
# vol_close_ema_6                0.013167
# vol_close_ema_12               0.012396
# Name: 4836, dtype: object
# Closed trade at step 4837
# ------------------------------> Trade outcome: 192.4100000000035
# Reward: 1.5
# Step: 4837
# Open Position: 0
# Trades: 809 | Profit/Loss: 43159.91
# Balance: 143159.91
# Winning Trades: 441 | Losing Trades: 368
# Overall Rewards: 35.90
# date                2021-03-06 17:00:00
# open                           47755.08
# high                            48450.0
# low                            47655.01
# close                          48250.69
# volume usdt                   128615239
# tradecount                        74126
# hour                                 17
# day                                   6
# ema_13                     47998.129693
# ema_25                     48136.437285
# ema_32                     48188.121651
# ema_100                    48427.390095
# ema_200                    48580.413204
# vol_close                      0.016476
# vol_close_ema_3                 0.01541
# vol_close_ema_6                0.014112
# vol_close_ema_12               0.013024
# Name: 4837, dtype: object
# Opened trade at step 4838 with position size: 7158.00
# Reward: 0
# Step: 4838
# Open Position: 1
# Trades: 810 | Profit/Loss: 43159.91
# Balance: 143159.91
# Winning Trades: 441 | Losing Trades: 368
# Overall Rewards: 35.90
# date                2021-03-06 18:00:00
# open                            48250.7
# high                            48623.0
# low                            48109.79
# close                           48473.3
# volume usdt                    96878694
# tradecount                        60766
# hour                                 18
# day                                   6
# ema_13                     48066.011165
# ema_25                     48162.349802
# ema_32                     48205.405187
# ema_100                    48428.299202
# ema_200                    48579.347401
# vol_close                      0.010587
# vol_close_ema_3                0.012999
# vol_close_ema_6                0.013105
# vol_close_ema_12               0.012649
# Name: 4838, dtype: object
# Reward: 0
# Step: 4839
# Open Position: 1
# Trades: 810 | Profit/Loss: 43159.91
# Balance: 143159.91
# Winning Trades: 441 | Losing Trades: 368
# Overall Rewards: 35.90
# date                2021-03-06 19:00:00
# open                            48473.3
# high                            48690.6
# low                            48248.27
# close                          48341.01
# volume usdt                    76741498
# tradecount                        55227
# hour                                 19
# day                                   6
# ema_13                     48105.296713
# ema_25                     48176.092894
# ema_32                     48213.623661
# ema_100                    48426.570703
# ema_200                    48576.975884
# vol_close                       0.00915
# vol_close_ema_3                0.011075
# vol_close_ema_6                0.011975
# vol_close_ema_12               0.012111
# Name: 4839, dtype: object
# Closed trade at step 4840
# ------------------------------> Trade outcome: 90.30000000000291
# Reward: 1.5
# Step: 4840
# Open Position: 0
# Trades: 810 | Profit/Loss: 43250.21
# Balance: 143250.21
# Winning Trades: 442 | Losing Trades: 368
# Overall Rewards: 37.40
# date                2021-03-06 20:00:00
# open                            48341.0
# high                           48734.84
# low                            48223.36
# close                           48518.5
# volume usdt                   115903829
# tradecount                        64961
# hour                                 20
# day                                   6
# ema_13                     48164.325754
# ema_25                     48202.431902
# ema_32                     48232.101015
# ema_100                    48428.391085
# ema_200                    48576.394035
# vol_close                      0.010542
# vol_close_ema_3                0.010808
# vol_close_ema_6                0.011566
# vol_close_ema_12                0.01187
# Name: 4840, dtype: object
# Opened trade at step 4841 with position size: 7162.51
# Reward: 0
# Step: 4841
# Open Position: 1
# Trades: 811 | Profit/Loss: 43250.21
# Balance: 143250.21
# Winning Trades: 442 | Losing Trades: 368
# Overall Rewards: 37.40
# date                2021-03-06 21:00:00
# open                           48518.51
# high                            48723.0
# low                            48264.63
# close                          48578.71
# volume usdt                    83333486
# tradecount                        45864
# hour                                 21
# day                                   6
# ema_13                     48223.523504
# ema_25                     48231.376371
# ema_32                      48253.10762
# ema_100                    48431.367697
# ema_200                    48576.417079
# vol_close                      0.009436
# vol_close_ema_3                0.010122
# vol_close_ema_6                0.010957
# vol_close_ema_12               0.011495
# Name: 4841, dtype: object
# Closed trade at step 4842
# ------------------------------> Trade outcome: 58.70999999999913
# Reward: 1.5
# Step: 4842
# Open Position: 0
# Trades: 811 | Profit/Loss: 43308.92
# Balance: 143308.92
# Winning Trades: 443 | Losing Trades: 368
# Overall Rewards: 38.90
# date                2021-03-06 22:00:00
# open                           48577.22
# high                            49200.0
# low                            48463.75
# close                          48920.88
# volume usdt                    97393079
# tradecount                        64007
# hour                                 22
# day                                   6
# ema_13                      48323.14586
# ema_25                     48284.415112
# ema_32                     48293.578673
# ema_100                     48441.06101
# ema_200                    48579.844571
# vol_close                       0.01505
# vol_close_ema_3                0.012586
# vol_close_ema_6                0.012126
# vol_close_ema_12               0.012042
# Name: 4842, dtype: object
# Opened trade at step 4843 with position size: 7165.45
# Reward: 0
# Step: 4843
# Open Position: 1
# Trades: 812 | Profit/Loss: 43308.92
# Balance: 143308.92
# Winning Trades: 443 | Losing Trades: 368
# Overall Rewards: 38.90
# date                2021-03-06 23:00:00
# open                           48920.87
# high                           49120.01
# low                             48805.0
# close                           48882.2
# volume usdt                    70431289
# tradecount                        54140
# hour                                 23
# day                                   6
# ema_13                     48403.010737
# ema_25                     48330.398565
# ema_32                     48329.252693
# ema_100                    48449.796436
# ema_200                    48582.853083
# vol_close                      0.006444
# vol_close_ema_3                0.009515
# vol_close_ema_6                0.010503
# vol_close_ema_12               0.011181
# Name: 4843, dtype: object
# Closed trade at step 4844
# ------------------------------> Trade outcome: -38.67000000000553
# Trade reached the maximum stop loss
# Reward: -1.7
# Step: 4844
# Open Position: 0
# Trades: 812 | Profit/Loss: 43270.25
# Balance: 143270.25
# Winning Trades: 443 | Losing Trades: 369
# Overall Rewards: 37.20
# date                2021-03-07 00:00:00
# open                            48882.2
# high                            49312.0
# low                             48882.2
# close                          49203.25
# volume usdt                   103198225
# tradecount                        50983
# hour                                  0
# day                                   7
# ema_13                     48517.330632
# ema_25                     48397.540983
# ema_32                     48382.222227
# ema_100                    48464.716308
# ema_200                    48589.026186
# vol_close                      0.008735
# vol_close_ema_3                0.009125
# vol_close_ema_6                0.009998
# vol_close_ema_12               0.010805
# Name: 4844, dtype: object
# Opened trade at step 4845 with position size: 7163.51
# Reward: 0
# Step: 4845
# Open Position: 1
# Trades: 813 | Profit/Loss: 43270.25
# Balance: 143270.25
# Winning Trades: 443 | Losing Trades: 369
# Overall Rewards: 37.20
# date                2021-03-07 01:00:00
# open                           49203.25
# high                            49490.0
# low                            48982.17
# close                          49121.95
# volume usdt                   106634203
# tradecount                        55306
# hour                                  1
# day                                   7
# ema_13                     48603.704827
# ema_25                     48453.264753
# ema_32                     48427.054213
# ema_100                    48477.730837
# ema_200                    48594.328911
# vol_close                      0.010338
# vol_close_ema_3                0.009732
# vol_close_ema_6                0.010095
# vol_close_ema_12               0.010733
# Name: 4845, dtype: object
# Closed trade at step 4846
# ------------------------------> Trade outcome: -81.30000000000291
# Trade reached the maximum stop loss
# Reward: -1.7
# Step: 4846
# Open Position: 0
# Trades: 813 | Profit/Loss: 43188.95
# Balance: 143188.95
# Winning Trades: 443 | Losing Trades: 370
# Overall Rewards: 35.50
# date                2021-03-07 02:00:00
# open                           49121.95
# high                            49851.0
# low                            49052.91
# close                          49550.58
# volume usdt                   127803055
# tradecount                        66389
# hour                                  2
# day                                   7
# ema_13                     48738.972709
# ema_25                     48537.673619
# ema_32                     48495.146685
# ema_100                    48498.975375
# ema_200                    48603.843847
# vol_close                      0.016107
# vol_close_ema_3                0.012919
# vol_close_ema_6                0.011813
# vol_close_ema_12                0.01156
# Name: 4846, dtype: object
# Reward: 0
# Step: 4847
# Open Position: 0
# Trades: 813 | Profit/Loss: 43188.95
# Balance: 143188.95
# Winning Trades: 443 | Losing Trades: 370
# Overall Rewards: 35.50
# date                2021-03-07 03:00:00
# open                           49550.57
# high                           49900.99
# low                            49433.88
# close                          49551.44
# volume usdt                    96921818
# tradecount                        45080
# hour                                  3
# day                                   7
# ema_13                     48855.039465
# ema_25                     48615.655648
# ema_32                     48559.164462
# ema_100                    48519.816258
# ema_200                    48613.272664
# vol_close                      0.009427
# vol_close_ema_3                0.011173
# vol_close_ema_6                0.011131
# vol_close_ema_12               0.011231
# Name: 4847, dtype: object
# Opened trade at step 4848 with position size: 7159.45
# Reward: 0
# Step: 4848
# Open Position: 1
# Trades: 814 | Profit/Loss: 43188.95
# Balance: 143188.95
# Winning Trades: 443 | Losing Trades: 370
# Overall Rewards: 35.50
# date                2021-03-07 04:00:00
# open                           49551.43
# high                           49687.98
# low                             49296.8
# close                          49436.18
# volume usdt                    75402078
# tradecount                        39760
# hour                                  4
# day                                   7
# ema_13                     48938.059541
# ema_25                     48678.772906
# ema_32                     48612.316918
# ema_100                    48537.962075
# ema_200                    48621.460797
# vol_close                      0.007913
# vol_close_ema_3                0.009543
# vol_close_ema_6                0.010212
# vol_close_ema_12               0.010721
# Name: 4848, dtype: object
# Reward: 0
# Step: 4849
# Open Position: 1
# Trades: 814 | Profit/Loss: 43188.95
# Balance: 143188.95
# Winning Trades: 443 | Losing Trades: 370
# Overall Rewards: 35.50
# date                2021-03-07 05:00:00
# open                           49436.18
# high                           49459.25
# low                            49111.11
# close                           49342.0
# volume usdt                    77820439
# tradecount                        42161
# hour                                  5
# day                                   7
# ema_13                     48995.765321
# ema_25                     48729.790375
# ema_32                     48656.540136
# ema_100                    48553.883618
# ema_200                    48628.630341
# vol_close                      0.007056
# vol_close_ema_3                0.008299
# vol_close_ema_6                 0.00931
# vol_close_ema_12               0.010157
# Name: 4849, dtype: object
# Reward: 0
# Step: 4850
# Open Position: 1
# Trades: 814 | Profit/Loss: 43188.95
# Balance: 143188.95
# Winning Trades: 443 | Losing Trades: 370
# Overall Rewards: 35.50
# date                2021-03-07 06:00:00
# open                            49342.0
# high                            49650.0
# low                            49146.68
# close                          49458.56
# volume usdt                    73428066
# tradecount                        40988
# hour                                  6
# day                                   7
# ema_13                     49061.878847
# ema_25                     48785.849576
# ema_32                       48705.1474
# ema_100                    48571.798002
# ema_200                    48636.888348
# vol_close                      0.010177
# vol_close_ema_3                0.009238
# vol_close_ema_6                0.009557
# vol_close_ema_12                0.01016
# Name: 4850, dtype: object
# Reward: 0
# Step: 4851
# Open Position: 1
# Trades: 814 | Profit/Loss: 43188.95
# Balance: 143188.95
# Winning Trades: 443 | Losing Trades: 370
# Overall Rewards: 35.50
# date                2021-03-07 07:00:00
# open                           49459.61
# high                           50179.17
# low                            49327.57
# close                          50052.68
# volume usdt                    98810047
# tradecount                        59667
# hour                                  7
# day                                   7
# ema_13                     49203.421869
# ema_25                     48883.298071
# ema_32                     48786.816042
# ema_100                    48601.122398
# ema_200                    48650.975827
# vol_close                      0.017014
# vol_close_ema_3                0.013126
# vol_close_ema_6                0.011688
# vol_close_ema_12               0.011214
# Name: 4851, dtype: object
# Closed trade at step 4852
# ------------------------------> Trade outcome: 490.4099999999962
# Reward: 1.5
# Step: 4852
# Open Position: 0
# Trades: 814 | Profit/Loss: 43679.36
# Balance: 143679.36
# Winning Trades: 444 | Losing Trades: 370
# Overall Rewards: 37.00
# date                2021-03-07 08:00:00
# open                           50041.84
# high                           50839.54
# low                            50041.84
# close                          50383.09
# volume usdt                   217681722
# tradecount                       102837
# hour                                  8
# day                                   7
# ema_13                     49371.945887
# ema_25                     48998.666681
# ema_32                     48883.559919
# ema_100                    48636.408885
# ema_200                    48668.210794
# vol_close                      0.015833
# vol_close_ema_3                0.014479
# vol_close_ema_6                0.012872
# vol_close_ema_12               0.011925
# Name: 4852, dtype: object
# Opened trade at step 4853 with position size: 7183.97
# Reward: 0
# Step: 4853
# Open Position: 1
# Trades: 815 | Profit/Loss: 43679.36
# Balance: 143679.36
# Winning Trades: 444 | Losing Trades: 370
# Overall Rewards: 37.00
# date                2021-03-07 09:00:00
# open                           50384.11
# high                           51148.22
# low                            50384.11
# close                          50943.02
# volume usdt                   214282779
# tradecount                        92581
# hour                                  9
# day                                   7
# ema_13                     49596.385046
# ema_25                     49148.232321
# ema_32                     49008.375681
# ema_100                    48682.084353
# ema_200                    48690.845711
# vol_close                      0.014999
# vol_close_ema_3                0.014739
# vol_close_ema_6                 0.01348
# vol_close_ema_12               0.012398
# Name: 4853, dtype: object
# Reward: 0
# Step: 4854
# Open Position: 1
# Trades: 815 | Profit/Loss: 43679.36
# Balance: 143679.36
# Winning Trades: 444 | Losing Trades: 370
# Overall Rewards: 37.00
# date                2021-03-07 10:00:00
# open                           50942.82
# high                           50985.84
# low                             50448.3
# close                          50612.92
# volume usdt                   143295201
# tradecount                        77271
# hour                                 10
# day                                   7
# ema_13                     49741.604325
# ema_25                     49260.900604
# ema_32                     49105.620791
# ema_100                    48720.318722
# ema_200                    48709.970829
# vol_close                      0.010621
# vol_close_ema_3                 0.01268
# vol_close_ema_6                0.012663
# vol_close_ema_12               0.012125
# Name: 4854, dtype: object
# Reward: 0
# Step: 4855
# Open Position: 1
# Trades: 815 | Profit/Loss: 43679.36
# Balance: 143679.36
# Winning Trades: 444 | Losing Trades: 370
# Overall Rewards: 37.00
# date                2021-03-07 11:00:00
# open                           50612.92
# high                           50899.22
# low                            50472.81
# close                          50705.52
# volume usdt                   104312733
# tradecount                        95481
# hour                                 11
# day                                   7
# ema_13                     49879.306565
# ema_25                     49372.025173
# ema_32                      49202.58438
# ema_100                    48759.629638
# ema_200                    48729.827039
# vol_close                       0.00841
# vol_close_ema_3                0.010545
# vol_close_ema_6                0.011448
# vol_close_ema_12               0.011553
# Name: 4855, dtype: object
# Closed trade at step 4856
# ------------------------------> Trade outcome: 321.4099999999962
# Reward: 1.5
# Step: 4856
# Open Position: 0
# Trades: 815 | Profit/Loss: 44000.77
# Balance: 144000.77
# Winning Trades: 445 | Losing Trades: 370
# Overall Rewards: 38.50
# date                2021-03-07 12:00:00
# open                           50705.52
# high                           50827.68
# low                            50391.19
# close                           50746.2
# volume usdt                    97483870
# tradecount                        98865
# hour                                 12
# day                                   7
# ema_13                     50003.148484
# ema_25                     49477.730928
# ema_32                     49296.136842
# ema_100                    48798.967665
# ema_200                    48749.890452
# vol_close                      0.008601
# vol_close_ema_3                0.009573
# vol_close_ema_6                0.010634
# vol_close_ema_12               0.011099
# Name: 4856, dtype: object
# Reward: 0
# Step: 4857
# Open Position: 0
# Trades: 815 | Profit/Loss: 44000.77
# Balance: 144000.77
# Winning Trades: 445 | Losing Trades: 370
# Overall Rewards: 38.50
# date                2021-03-07 13:00:00
# open                            50746.2
# high                            50850.0
# low                            50504.22
# close                          50764.44
# volume usdt                    74825391
# tradecount                        78201
# hour                                 13
# day                                   7
# ema_13                     50111.904415
# ema_25                     49576.708549
# ema_32                     49385.124912
# ema_100                    48837.887909
# ema_200                    48769.935721
# vol_close                      0.006811
# vol_close_ema_3                0.008192
# vol_close_ema_6                0.009542
# vol_close_ema_12               0.010439
# Name: 4857, dtype: object
# Opened trade at step 4858 with position size: 7200.04
# Reward: 0
# Step: 4858
# Open Position: 1
# Trades: 816 | Profit/Loss: 44000.77
# Balance: 144000.77
# Winning Trades: 445 | Losing Trades: 370
# Overall Rewards: 38.50
# date                2021-03-07 14:00:00
# open                           50764.44
# high                            51250.0
# low                            50130.65
# close                          50646.34
# volume usdt                   175437666
# tradecount                       132882
# hour                                 14
# day                                   7
# ema_13                     50188.252356
# ema_25                     49658.987892
# ema_32                      49461.56219
# ema_100                    48873.698842
# ema_200                     48788.60641
# vol_close                      0.022101
# vol_close_ema_3                0.015147
# vol_close_ema_6                0.013131
# vol_close_ema_12               0.012233
# Name: 4858, dtype: object
# Reward: 0
# Step: 4859
# Open Position: 1
# Trades: 816 | Profit/Loss: 44000.77
# Balance: 144000.77
# Winning Trades: 445 | Losing Trades: 370
# Overall Rewards: 38.50
# date                2021-03-07 15:00:00
# open                           50644.47
# high                           50827.93
# low                             50375.0
# close                          50585.23
# volume usdt                    86620571
# tradecount                        82961
# hour                                 15
# day                                   7
# ema_13                     50244.963448
# ema_25                     49730.237285
# ema_32                     49529.663269
# ema_100                    48907.590548
# ema_200                    48806.483262
# vol_close                      0.008954
# vol_close_ema_3                 0.01205
# vol_close_ema_6                0.011937
# vol_close_ema_12               0.011729
# Name: 4859, dtype: object
# Closed trade at step 4860
# ------------------------------> Trade outcome: -179.20999999999913
# Trade reached the maximum stop loss
# Reward: -1.7
# Step: 4860
# Open Position: 0
# Trades: 816 | Profit/Loss: 43821.56
# Balance: 143821.56
# Winning Trades: 445 | Losing Trades: 371
# Overall Rewards: 36.80
# date                2021-03-07 16:00:00
# open                           50585.23
# high                            51352.1
# low                            50585.23
# close                           51052.9
# volume usdt                   182478942
# tradecount                       142491
# hour                                 16
# day                                   7
# ema_13                     50360.382955
# ema_25                      49831.98057
# ema_32                     49621.980647
# ema_100                    48950.071923
# ema_200                    48828.835667
# vol_close                      0.015021
# vol_close_ema_3                0.013536
# vol_close_ema_6                0.012818
# vol_close_ema_12               0.012235
# Name: 4860, dtype: object
# Reward: 0
# Step: 4861
# Open Position: 0
# Trades: 816 | Profit/Loss: 43821.56
# Balance: 143821.56
# Winning Trades: 445 | Losing Trades: 371
# Overall Rewards: 36.80
# date                2021-03-07 17:00:00
# open                           51052.89
# high                            51201.0
# low                            50757.59
# close                          51075.93
# volume usdt                   111189340
# tradecount                        72122
# hour                                 17
# day                                   7
# ema_13                     50462.603962
# ema_25                     49927.668988
# ema_32                      49710.09879
# ema_100                    48992.168123
# ema_200                    48851.194815
# vol_close                      0.008681
# vol_close_ema_3                0.011109
# vol_close_ema_6                0.011636
# vol_close_ema_12               0.011689
# Name: 4861, dtype: object
# Reward: 0
# Step: 4862
# Open Position: 0
# Trades: 816 | Profit/Loss: 43821.56
# Balance: 143821.56
# Winning Trades: 445 | Losing Trades: 371
# Overall Rewards: 36.80
# date                2021-03-07 18:00:00
# open                           51075.92
# high                           51085.71
# low                             50368.2
# close                          50412.31
# volume usdt                    96571298
# tradecount                        55137
# hour                                 18
# day                                   7
# ema_13                      50455.41911
# ema_25                     49964.949066
# ema_32                     49752.657045
# ema_100                    49020.289744
# ema_200                    48866.728299
# vol_close                      0.014233
# vol_close_ema_3                0.012671
# vol_close_ema_6                0.012378
# vol_close_ema_12                0.01208
# Name: 4862, dtype: object
# Reward: 0
# Step: 4863
# Open Position: 0
# Trades: 816 | Profit/Loss: 43821.56
# Balance: 143821.56
# Winning Trades: 445 | Losing Trades: 371
# Overall Rewards: 36.80
# date                2021-03-07 19:00:00
# open                           50412.31
# high                           50580.21
# low                             50250.0
# close                          50381.68
# volume usdt                    82922192
# tradecount                        56614
# hour                                 19
# day                                   7
# ema_13                     50444.884951
# ...
# ema_200                    53275.010581
# vol_close                      0.014656
# vol_close_ema_3                0.013339
# vol_close_ema_6                0.013761
# vol_close_ema_12               0.014102
# Name: 4983, dtype: object
# Opened trade at step 4984 with position size: 7506.74
# Reward: 0
# Step: 4984
# Open Position: 1
# Trades: 834 | Profit/Loss: 50134.79
# Balance: 150134.79
# Winning Trades: 458 | Losing Trades: 375
# Overall Rewards: 49.50
# date                2021-03-12 20:00:00
# open                           56942.41
# high                            57200.0
# low                             56400.0
# close                           56696.8
# volume usdt                   197381436
# tradecount                       103916
# hour                                 20
# day                                   5
# ema_13                     56841.493888
# ema_25                     56760.981144
# ema_32                     56677.146629
# ema_100                    55158.119185
# ema_200                    53309.058237
# vol_close                       0.01411
# vol_close_ema_3                0.013725
# vol_close_ema_6                0.013861
# vol_close_ema_12               0.014103
# Name: 4984, dtype: object
# Reward: 0
# Step: 4985
# Open Position: 1
# Trades: 834 | Profit/Loss: 50134.79
# Balance: 150134.79
# Winning Trades: 458 | Losing Trades: 375
# Overall Rewards: 49.50
# date                2021-03-12 21:00:00
# open                           56696.81
# high                            57170.0
# low                            56262.14
# close                          56936.78
# volume usdt                   144882646
# tradecount                       123258
# hour                                 21
# day                                   5
# ema_13                      56855.10619
# ema_25                     56774.504133
# ema_32                     56692.881985
# ema_100                    55193.340191
# ema_200                    53345.154971
# vol_close                      0.015945
# vol_close_ema_3                0.014835
# vol_close_ema_6                0.014456
# vol_close_ema_12               0.014386
# Name: 4985, dtype: object
# Reward: 0
# Step: 4986
# Open Position: 1
# Trades: 834 | Profit/Loss: 50134.79
# Balance: 150134.79
# Winning Trades: 458 | Losing Trades: 375
# Overall Rewards: 49.50
# date                2021-03-12 22:00:00
# open                           56936.78
# high                           57465.38
# low                            56859.06
# close                          57157.29
# volume usdt                   128889329
# tradecount                       107068
# hour                                 22
# day                                   5
# ema_13                     56898.275306
# ema_25                       56803.9492
# ema_32                     56721.027925
# ema_100                    55232.230286
# ema_200                    53383.086663
# vol_close                      0.010608
# vol_close_ema_3                0.012721
# vol_close_ema_6                0.013357
# vol_close_ema_12               0.013805
# Name: 4986, dtype: object
# Closed trade at step 4987
# ------------------------------> Trade outcome: 214.87999999999738
# Reward: 1.5
# Step: 4987
# Open Position: 0
# Trades: 834 | Profit/Loss: 50349.67
# Balance: 150349.67
# Winning Trades: 459 | Losing Trades: 375
# Overall Rewards: 51.00
# date                2021-03-12 23:00:00
# open                           57157.29
# high                            57500.0
# low                            57153.68
# close                          57221.72
# volume usdt                   109588876
# tradecount                        80631
# hour                                 23
# day                                   5
# ema_13                     56944.481691
# ema_25                     56836.085415
# ema_32                       56751.3729
# ema_100                    55271.626122
# ema_200                     53421.28202
# vol_close                      0.006052
# vol_close_ema_3                0.009387
# vol_close_ema_6                 0.01127
# vol_close_ema_12               0.012612
# Name: 4987, dtype: object
# Reward: 0
# Step: 4988
# Open Position: 0
# Trades: 834 | Profit/Loss: 50349.67
# Balance: 150349.67
# Winning Trades: 459 | Losing Trades: 375
# Overall Rewards: 51.00
# date                2021-03-13 00:00:00
# open                           57221.72
# high                            57307.2
# low                            56312.91
# close                          56689.35
# volume usdt                   165168453
# tradecount                       113394
# hour                                  0
# day                                   6
# ema_13                     56908.034306
# ema_25                     56824.798076
# ema_32                     56747.613936
# ema_100                    55299.699862
# ema_200                    53453.800109
# vol_close                      0.017539
# vol_close_ema_3                0.013463
# vol_close_ema_6                0.013061
# vol_close_ema_12                0.01337
# Name: 4988, dtype: object
# Reward: 0
# Step: 4989
# Open Position: 0
# Trades: 834 | Profit/Loss: 50349.67
# Balance: 150349.67
# Winning Trades: 459 | Losing Trades: 375
# Overall Rewards: 51.00
# date                2021-03-13 01:00:00
# open                           56689.36
# high                            56707.0
# low                            56081.59
# close                          56386.39
# volume usdt                   132887327
# tradecount                        74110
# hour                                  1
# day                                   6
# ema_13                     56833.513691
# ema_25                     56791.074377
# ema_32                     56725.721576
# ema_100                    55321.218479
# ema_200                    53482.980108
# vol_close                      0.011092
# vol_close_ema_3                0.012277
# vol_close_ema_6                0.012498
# vol_close_ema_12                0.01302
# Name: 4989, dtype: object
# Opened trade at step 4990 with position size: 7517.48
# Reward: 0
# Step: 4990
# Open Position: 1
# Trades: 835 | Profit/Loss: 50349.67
# Balance: 150349.67
# Winning Trades: 459 | Losing Trades: 375
# Overall Rewards: 51.00
# date                2021-03-13 02:00:00
# open                           56386.39
# high                           56639.54
# low                            56078.23
# close                          56473.41
# volume usdt                   123160401
# tradecount                        60691
# hour                                  2
# day                                   6
# ema_13                     56782.070307
# ema_25                     56766.638656
# ema_32                     56710.429965
# ema_100                    55344.034153
# ema_200                    53512.735629
# vol_close                      0.009939
# vol_close_ema_3                0.011108
# vol_close_ema_6                0.011767
# vol_close_ema_12               0.012546
# Name: 4990, dtype: object
# Closed trade at step 4991
# ------------------------------> Trade outcome: 87.02000000000407
# Reward: 1.5
# Step: 4991
# Open Position: 0
# Trades: 835 | Profit/Loss: 50436.69
# Balance: 150436.69
# Winning Trades: 460 | Losing Trades: 375
# Overall Rewards: 52.50
# date                2021-03-13 03:00:00
# open                           56473.41
# high                            56790.0
# low                            56308.98
# close                          56694.32
# volume usdt                   107744213
# tradecount                        54805
# hour                                  3
# day                                   6
# ema_13                     56769.534549
# ema_25                     56761.075683
# ema_32                     56709.453604
# ema_100                    55370.772486
# ema_200                    53544.393185
# vol_close                      0.008484
# vol_close_ema_3                0.009796
# vol_close_ema_6                0.010829
# vol_close_ema_12               0.011921
# Name: 4991, dtype: object
# Reward: 0
# Step: 4992
# Open Position: 0
# Trades: 835 | Profit/Loss: 50436.69
# Balance: 150436.69
# Winning Trades: 460 | Losing Trades: 375
# Overall Rewards: 52.50
# date                2021-03-13 04:00:00
# open                           56694.32
# high                            56899.0
# low                            56257.47
# close                          56896.32
# volume usdt                    87520343
# tradecount                        52050
# hour                                  4
# day                                   6
# ema_13                     56787.646756
# ema_25                     56771.479092
# ema_32                      56720.77884
# ema_100                    55400.981348
# ema_200                    53577.745691
# vol_close                      0.011275
# vol_close_ema_3                0.010536
# vol_close_ema_6                0.010957
# vol_close_ema_12               0.011822
# Name: 4992, dtype: object
# Reward: 0
# Step: 4993
# Open Position: 0
# Trades: 835 | Profit/Loss: 50436.69
# Balance: 150436.69
# Winning Trades: 460 | Losing Trades: 375
# Overall Rewards: 52.50
# date                2021-03-13 05:00:00
# open                           56882.74
# high                           57090.46
# low                             56610.0
# close                          56744.89
# volume usdt                    81423247
# tradecount                        49512
# hour                                  5
# day                                   6
# ema_13                     56781.538648
# ema_25                     56769.433777
# ema_32                     56722.240122
# ema_100                      55427.5934
# ema_200                    53609.259565
# vol_close                      0.008467
# vol_close_ema_3                0.009501
# vol_close_ema_6                0.010245
# vol_close_ema_12               0.011306
# Name: 4993, dtype: object
# Reward: 0
# Step: 4994
# Open Position: 0
# Trades: 835 | Profit/Loss: 50436.69
# Balance: 150436.69
# Winning Trades: 460 | Losing Trades: 375
# Overall Rewards: 52.50
# date                2021-03-13 06:00:00
# open                           56744.89
# high                           57060.86
# low                            56491.92
# close                          56931.58
# volume usdt                    99851921
# tradecount                        57668
# hour                                  6
# day                                   6
# ema_13                     56802.973127
# ema_25                     56781.906563
# ema_32                     56734.927388
# ema_100                    55457.375313
# ema_200                    53642.317479
# vol_close                      0.009993
# vol_close_ema_3                0.009747
# vol_close_ema_6                0.010173
# vol_close_ema_12               0.011104
# Name: 4994, dtype: object
# Reward: 0
# Step: 4995
# Open Position: 0
# Trades: 835 | Profit/Loss: 50436.69
# Balance: 150436.69
# Winning Trades: 460 | Losing Trades: 375
# Overall Rewards: 52.50
# date                2021-03-13 07:00:00
# open                           56931.57
# high                           57389.58
# low                             56753.9
# close                           57343.7
# volume usdt                   113909859
# tradecount                        69690
# hour                                  7
# day                                   6
# ema_13                     56880.219823
# ema_25                     56825.121443
# ema_32                     56771.822698
# ema_100                    55494.728277
# ema_200                    53679.147156
# vol_close                      0.011085
# vol_close_ema_3                0.010416
# vol_close_ema_6                0.010434
# vol_close_ema_12               0.011101
# Name: 4995, dtype: object
# Reward: 0
# Step: 4996
# Open Position: 0
# Trades: 835 | Profit/Loss: 50436.69
# Balance: 150436.69
# Winning Trades: 460 | Losing Trades: 375
# Overall Rewards: 52.50
# date                2021-03-13 08:00:00
# open                            57343.7
# high                           57649.03
# low                             57126.2
# close                          57434.31
# volume usdt                   169868896
# tradecount                        85667
# hour                                  8
# day                                   6
# ema_13                     56959.375563
# ema_25                     56871.982101
# ema_32                     56811.973443
# ema_100                    55533.135836
# ema_200                    53716.511961
# vol_close                      0.009103
# vol_close_ema_3                 0.00976
# vol_close_ema_6                0.010054
# vol_close_ema_12               0.010794
# Name: 4996, dtype: object
# Reward: 0
# Step: 4997
# Open Position: 0
# Trades: 835 | Profit/Loss: 50436.69
# Balance: 150436.69
# Winning Trades: 460 | Losing Trades: 375
# Overall Rewards: 52.50
# date                2021-03-13 09:00:00
# open                            57434.3
# high                           57614.52
# low                            57253.31
# close                          57610.77
# volume usdt                   104898332
# tradecount                        62926
# hour                                  9
# day                                   6
# ema_13                     57052.431911
# ema_25                      56928.81194
# ema_32                     56860.385356
# ema_100                    55574.277107
# ema_200                    53755.260797
# vol_close                       0.00627
# vol_close_ema_3                0.008015
# vol_close_ema_6                0.008973
# vol_close_ema_12               0.010098
# Name: 4997, dtype: object
# Opened trade at step 4998 with position size: 7521.83
# Reward: 0
# Step: 4998
# Open Position: 1
# Trades: 836 | Profit/Loss: 50436.69
# Balance: 150436.69
# Winning Trades: 460 | Losing Trades: 375
# Overall Rewards: 52.50
# date                2021-03-13 10:00:00
# open                           57610.77
# high                            59850.0
# low                            57446.81
# close                          59448.19
# volume usdt                   750024014
# tradecount                       308276
# hour                                 10
# day                                   6
# ema_13                     57394.683066
# ema_25                     57122.610252
# ema_32                     57017.222001
# ema_100                    55650.988253
# ema_200                    53811.906858
# vol_close                      0.040425
# vol_close_ema_3                 0.02422
# vol_close_ema_6                0.017959
# vol_close_ema_12               0.014763
# Name: 4998, dtype: object
# Reward: 0
# Step: 4999
# Open Position: 1
# Trades: 836 | Profit/Loss: 50436.69
# Balance: 150436.69
# Winning Trades: 460 | Losing Trades: 375
# Overall Rewards: 52.50
# date                2021-03-13 11:00:00
# open                            59448.2
# high                            60200.0
# low                            59420.99
# close                          59849.74
# volume usdt                   544708721
# tradecount                       230042
# hour                                 11
# day                                   6
# ema_13                     57745.405485
# ema_25                     57332.389463
# ema_32                     57188.889758
# ema_100                    55734.131852
# ema_200                      53871.9848
# vol_close                      0.013016
# vol_close_ema_3                0.018618
# vol_close_ema_6                0.016547
# vol_close_ema_12               0.014495
# Name: 4999, dtype: object
# Reward: 0
# Step: 5000
# Open Position: 1
# Trades: 836 | Profit/Loss: 50436.69
# Balance: 150436.69
# Winning Trades: 460 | Losing Trades: 375
# Overall Rewards: 52.50
# date                2021-03-13 12:00:00
# open                           59853.58
# high                            60500.0
# low                            59232.53
# close                          59911.99
# volume usdt                   352958745
# tradecount                       152578
# hour                                 12
# day                                   6
# ema_13                     58054.917559
# ema_25                     57530.820274
# ema_32                     57353.926137
# ema_100                    55816.861716
# ema_200                    53932.084354
# vol_close                      0.021156
# vol_close_ema_3                0.019887
# vol_close_ema_6                0.017864
# vol_close_ema_12               0.015519
# Name: 5000, dtype: object
# Episode 5000: Final Rewards: 52.50 | Total Trades: 836

# %%
#%load_ext tensorboard

# %%
#%tensorboard --logdir ./ppo_logs/

# %% [markdown]
# ### Save configuration

# %%
agent.save('v1_ppodrl')

# %% [markdown]
# # Test Validation Phase

# %% [markdown]
# ### Import / load validation data

# %%
val_data = train_df

# %%
val_data = val_data.reset_index(drop=True)

# %%
val_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27812 entries, 0 to 27811
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   date              27812 non-null  datetime64[ns]
#  1   open              27812 non-null  float64
#  2   high              27812 non-null  float64
#  3   low               27812 non-null  float64
#  4   close             27812 non-null  float64
#  5   volume usdt       27812 non-null  int64
#  6   tradecount        27812 non-null  int64
#  7   hour              27812 non-null  int64
#  8   day               27812 non-null  int64
#  9   ema_13            27812 non-null  float64
#  10  ema_25            27812 non-null  float64
#  11  ema_32            27812 non-null  float64
#  12  ema_100           27812 non-null  float64
#  13  ema_200           27812 non-null  float64
#  14  vol_close         27812 non-null  float64
#  15  vol_close_ema_3   27812 non-null  float64
#  16  vol_close_ema_6   27812 non-null  float64
#  17  vol_close_ema_12  27812 non-null  float64
# dtypes: datetime64[ns](1), float64(13), int64(4)
# memory usage: 3.8 MB

# %%
val_data
# Out:
#                      date      open      high       low     close  \
# 0     2020-08-17 04:00:00  11844.72  11858.91  11802.35  11809.38
# 1     2020-08-17 05:00:00  11809.39  11836.90  11790.00  11800.01
# 2     2020-08-17 06:00:00  11800.00  11846.74  11785.23  11806.37
# 3     2020-08-17 07:00:00  11806.37  11843.01  11792.32  11807.21
# 4     2020-08-17 08:00:00  11806.94  11885.00  11806.91  11868.77
# ...                   ...       ...       ...       ...       ...
# 27807 2023-10-19 19:00:00  28646.98  28765.76  28645.00  28750.75
# 27808 2023-10-19 20:00:00  28750.75  28882.07  28684.80  28715.38
# 27809 2023-10-19 21:00:00  28715.39  28739.73  28604.09  28604.09
# 27810 2023-10-19 22:00:00  28604.09  28704.99  28598.60  28649.65
# 27811 2023-10-19 23:00:00  28649.64  28717.82  28630.19  28713.71
#
#        volume usdt  tradecount  hour  day        ema_13        ema_25  \
# 0         17196539       28800     4    1  11809.380000  11809.380000
# 1         19958274       28571     5    1  11804.334615  11804.507600
# 2         19327915       29762     6    1  11805.119921  11805.178699
# 3         22698672       33111     7    1  11805.768697  11805.749021
# 4         28031116       37458     8    1  11822.518351  11820.447106
# ...            ...         ...   ...  ...           ...           ...
# 27807     29840591       49985    19    4  28551.404418  28476.370598
# 27808     49976234       59830    20    4  28574.829501  28494.755937
# 27809     32056663       42623    21    4  28579.009572  28503.166249
# 27810     22004203       28479    22    4  28589.101062  28514.434230
# 27811     17582981       27099    23    4  28606.902339  28529.763135
#
#              ema_32       ema_100       ema_200  vol_close  vol_close_ema_3  \
# 0      11809.380000  11809.380000  11809.380000   0.004789         0.004789
# 1      11804.548594  11804.648150  11804.671575   0.003975         0.004382
# 2      11805.194058  11805.233617  11805.243387   0.005210         0.004796
# 3      11805.746245  11805.742633  11805.742440   0.004293         0.004545
# 4      11819.974205  11818.857316  11818.601316   0.006579         0.005562
# ...             ...           ...           ...        ...              ...
# 27807  28449.944844  28143.362798  27837.239673   0.004200         0.005770
# 27808  28466.031824  28154.689871  27845.977388   0.006870         0.006320
# 27809  28474.398986  28163.588884  27853.520797   0.004742         0.005531
# 27810  28485.020259  28173.213856  27861.442481   0.003713         0.004622
# 27811  28498.880244  28183.916750  27869.922755   0.003052         0.003837
#
#        vol_close_ema_6  vol_close_ema_12
# 0             0.004789          0.004789
# 1             0.004557          0.004664
# 2             0.004743          0.004748
# 3             0.004615          0.004678
# 4             0.005176          0.004971
# ...                ...               ...
# 27807         0.006508          0.006222
# 27808         0.006611          0.006322
# 27809         0.006077          0.006079
# 27810         0.005402          0.005715
# 27811         0.004730          0.005305
#
# [27812 rows x 18 columns]

# %%
pre_trained_agent = PPO.load('v1_ppodrl')

# %%
env_test = CryptoTradingEnv(val_data)
obs = env_test.reset()

num_episodes = 5000

for episode in range(num_episodes):
  obs = np.array(obs, dtype=np.float32)
  action, _ = pre_trained_agent.predict(obs, deterministic=False)
  remaining_steps = min(max_steps - env_test.current_step, env_test.n_steps)

  if remaining_steps > 0:
    obs, reward, done, _ = env_test.step(action)
    env_test.render()

  print(f"Episode: {episode}, Step: {env_test.current_step}, Action: {action}, Observation: {obs}")

  if (episode + 1) % print_interval == 0:
    print(f"Episode {episode + 1}: Final Rewards: {env_test.cumulative_returns:.2f} | Total Trades: {env_test.num_trades}")
# Out:
# Streaming output truncated to the last 5000 lines.
#  3.0836510e-04 3.0911915e-04 8.1404182e-11 7.3384701e-11 7.2366738e-11]
# Reward: 0
# Step: 4833
# Open Position: 1
# Trades: 792 | Profit/Loss: 7532.27
# Balance: 107532.27
# Winning Trades: 430 | Losing Trades: 361
# Overall Rewards: 31.30
# date                2021-03-06 13:00:00
# open                           47660.75
# high                           47753.39
# low                             47070.0
# close                           47320.3
# volume usdt                   147223560
# tradecount                       111334
# hour                                 13
# day                                   6
# ema_13                      48200.74474
# ema_25                     48287.767221
# ema_32                     48318.402602
# ema_100                    48486.668766
# ema_200                    48615.835829
# vol_close                      0.014442
# vol_close_ema_3                0.013624
# vol_close_ema_6                0.012372
# vol_close_ema_12               0.011855
# Name: 4833, dtype: object
# Episode: 4832, Step: 4833, Action: 0, Observation: [3.2373046e-04 3.2435972e-04 3.1971786e-04 3.2141802e-04 1.0000000e+00
#  8.8301093e-08 4.0754347e-08 3.2739833e-04 3.2798940e-04 3.2819749e-04
#  3.2934043e-04 3.3021779e-04 9.2538976e-11 8.4037305e-11 8.0521770e-11]
# Closed trade at step 4834
# ------------------------------> Trade outcome: -850.7199999999939
# Trade reached the maximum stop loss
# Reward: -1.7
# Step: 4834
# Open Position: 0
# Trades: 792 | Profit/Loss: 6681.55
# Balance: 106681.55
# Winning Trades: 430 | Losing Trades: 362
# Overall Rewards: 29.60
# date                2021-03-06 14:00:00
# open                            47320.3
# high                           47725.51
# low                            47201.12
# close                          47560.96
# volume usdt                    86454117
# tradecount                        85390
# hour                                 14
# day                                   6
# ema_13                      48109.34692
# ema_25                     48231.858973
# ema_32                     48272.496989
# ema_100                      48468.3379
# ema_200                    48605.339552
# vol_close                      0.011026
# vol_close_ema_3                0.012325
# vol_close_ema_6                0.011988
# vol_close_ema_12               0.011727
# Name: 4834, dtype: object
# Episode: 4833, Step: 4834, Action: 2, Observation: [5.4734584e-04 5.5203284e-04 5.4596731e-04 5.5012951e-04 1.0000000e+00
#  1.6193560e-07 6.9400976e-08 5.5647257e-04 5.5788964e-04 5.5835972e-04
#  5.6062499e-04 5.6220964e-04 1.4255859e-10 1.3865757e-10 1.3564598e-10]
# Opened trade at step 4835 with position size: 5334.08
# Reward: 0
# Step: 4835
# Open Position: 1
# Trades: 793 | Profit/Loss: 6681.55
# Balance: 106681.55
# Winning Trades: 430 | Losing Trades: 362
# Overall Rewards: 29.60
# date                2021-03-06 15:00:00
# open                           47562.67
# high                           47712.69
# low                            47238.32
# close                          47267.88
# volume usdt                    70130991
# tradecount                        64970
# hour                                 15
# day                                   6
# ema_13                      47989.13736
# ema_25                     48157.706744
# ema_32                     48211.611111
# ema_100                    48444.566456
# ema_200                    48592.031497
# vol_close                      0.010036
# vol_close_ema_3                 0.01118
# vol_close_ema_6                 0.01143
# vol_close_ema_12               0.011467
# Name: 4835, dtype: object
# Episode: 4834, Step: 4835, Action: 1, Observation: [6.7819760e-04 6.8033673e-04 6.7357271e-04 6.7399413e-04 1.0000000e+00
#  2.1388547e-07 8.5554184e-08 6.8427861e-04 6.8668224e-04 6.8745087e-04
#  6.9077261e-04 6.9287530e-04 1.5941995e-10 1.6297901e-10 1.6350749e-10]
# Closed trade at step 4836
# ------------------------------> Trade outcome: -294.7900000000009
# Trade reached the maximum stop loss
# Reward: -1.7
# Step: 4836
# Open Position: 0
# Trades: 793 | Profit/Loss: 6386.76
# Balance: 106386.76
# Winning Trades: 430 | Losing Trades: 363
# Overall Rewards: 27.90
# date                2021-03-06 16:00:00
# open                           47267.88
# high                           47941.03
# low                            47104.85
# close                          47757.43
# volume usdt                   118538410
# tradecount                        67272
# hour                                 16
# day                                   6
# ema_13                     47956.036308
# ema_25                     48126.916226
# ema_32                     48184.084983
# ema_100                    48430.959794
# ema_200                    48583.727005
# vol_close                      0.017509
# vol_close_ema_3                0.014345
# vol_close_ema_6                0.013167
# vol_close_ema_12               0.012396
# Name: 4836, dtype: object
# Episode: 4835, Step: 4836, Action: 2, Observation: [3.98755801e-04 4.04434570e-04 3.97380500e-04 4.02885693e-04
#  1.00000000e+00 1.34977356e-07 5.06165065e-08 4.04561142e-04
#  4.06002742e-04 4.06485022e-04 4.08567663e-04 4.09856410e-04
#  1.21012159e-10 1.11075739e-10 1.04577694e-10]
# Reward: 0
# Step: 4837
# Open Position: 0
# Trades: 793 | Profit/Loss: 6386.76
# Balance: 106386.76
# Winning Trades: 430 | Losing Trades: 363
# Overall Rewards: 27.90
# date                2021-03-06 17:00:00
# open                           47755.08
# high                            48450.0
# low                            47655.01
# close                          48250.69
# volume usdt                   128615239
# tradecount                        74126
# hour                                 17
# day                                   6
# ema_13                     47998.129693
# ema_25                     48136.437285
# ema_32                     48188.121651
# ema_100                    48427.390095
# ema_200                    48580.413204
# vol_close                      0.016476
# vol_close_ema_3                 0.01541
# vol_close_ema_6                0.014112
# vol_close_ema_12               0.013024
# Name: 4837, dtype: object
# Episode: 4836, Step: 4837, Action: 2, Observation: [3.7130187e-04 3.7670496e-04 3.7052383e-04 3.7515533e-04 1.0000000e+00
#  1.3217718e-07 4.6650769e-08 3.7319161e-04 3.7426699e-04 3.7466883e-04
#  3.7652918e-04 3.7771894e-04 1.1981795e-10 1.0972505e-10 1.0126428e-10]
# Reward: 0
# Step: 4838
# Open Position: 0
# Trades: 793 | Profit/Loss: 6386.76
# Balance: 106386.76
# Winning Trades: 430 | Losing Trades: 363
# Overall Rewards: 27.90
# date                2021-03-06 18:00:00
# open                            48250.7
# high                            48623.0
# low                            48109.79
# close                           48473.3
# volume usdt                    96878694
# tradecount                        60766
# hour                                 18
# day                                   6
# ema_13                     48066.011165
# ema_25                     48162.349802
# ema_32                     48205.405187
# ema_100                    48428.299202
# ema_200                    48579.347401
# vol_close                      0.010587
# vol_close_ema_3                0.012999
# vol_close_ema_6                0.013105
# vol_close_ema_12               0.012649
# Name: 4838, dtype: object
# Episode: 4837, Step: 4838, Action: 2, Observation: [4.9805274e-04 5.0189567e-04 4.9659825e-04 5.0035049e-04 1.0000000e+00
#  1.8579937e-07 6.1933122e-08 4.9614633e-04 4.9714081e-04 4.9758522e-04
#  4.9988599e-04 5.0144509e-04 1.3417754e-10 1.3527450e-10 1.3056803e-10]
# Opened trade at step 4839 with position size: 5319.34
# Reward: 0
# Step: 4839
# Open Position: 1
# Trades: 794 | Profit/Loss: 6386.76
# Balance: 106386.76
# Winning Trades: 430 | Losing Trades: 363
# Overall Rewards: 27.90
# date                2021-03-06 19:00:00
# open                            48473.3
# high                            48690.6
# low                            48248.27
# close                          48341.01
# volume usdt                    76741498
# tradecount                        55227
# hour                                 19
# day                                   6
# ema_13                     48105.296713
# ema_25                     48176.092894
# ema_32                     48213.623661
# ema_100                    48426.570703
# ema_200                    48576.975884
# vol_close                       0.00915
# vol_close_ema_3                0.011075
# vol_close_ema_6                0.011975
# vol_close_ema_12               0.012111
# Name: 4839, dtype: object
# Episode: 4838, Step: 4839, Action: 1, Observation: [6.3164392e-04 6.3447555e-04 6.2871160e-04 6.2992010e-04 1.0000000e+00
#  2.4758444e-07 7.8184556e-08 6.2684854e-04 6.2777108e-04 6.2826014e-04
#  6.3103501e-04 6.3299492e-04 1.4431011e-10 1.5604612e-10 1.5781480e-10]
# Closed trade at step 4840
# ------------------------------> Trade outcome: -132.3000000000029
# Trade reached the maximum stop loss
# Reward: -1.7
# Step: 4840
# Open Position: 0
# Trades: 794 | Profit/Loss: 6254.46
# Balance: 106254.46
# Winning Trades: 430 | Losing Trades: 364
# Overall Rewards: 26.20
# date                2021-03-06 20:00:00
# open                            48341.0
# high                           48734.84
# low                            48223.36
# close                           48518.5
# volume usdt                   115903829
# tradecount                        64961
# hour                                 20
# day                                   6
# ema_13                     48164.325754
# ema_25                     48202.431902
# ema_32                     48232.101015
# ema_100                    48428.391085
# ema_200                    48576.394035
# vol_close                      0.010542
# vol_close_ema_3                0.010808
# vol_close_ema_6                0.011566
# vol_close_ema_12                0.01187
# Name: 4840, dtype: object
# Episode: 4839, Step: 4840, Action: 2, Observation: [4.17078525e-04 4.20476514e-04 4.16063558e-04 4.18609969e-04
#  1.00000000e+00 1.72556852e-07 5.17670529e-08 4.15554212e-04
#  4.15882998e-04 4.16138966e-04 4.17832518e-04 4.19109478e-04
#  9.32520172e-11 9.97871369e-11 1.02408707e-10]
# Opened trade at step 4841 with position size: 5312.72
# Reward: 0
# Step: 4841
# Open Position: 1
# Trades: 795 | Profit/Loss: 6254.46
# Balance: 106254.46
# Winning Trades: 430 | Losing Trades: 364
# Overall Rewards: 26.20
# date                2021-03-06 21:00:00
# open                           48518.51
# high                            48723.0
# low                            48264.63
# close                          48578.71
# volume usdt                    83333486
# tradecount                        45864
# hour                                 21
# day                                   6
# ema_13                     48223.523504
# ema_25                     48231.376371
# ema_32                      48253.10762
# ema_100                    48431.367697
# ema_200                    48576.417079
# vol_close                      0.009436
# vol_close_ema_3                0.010122
# vol_close_ema_6                0.010957
# vol_close_ema_12               0.011495
# Name: 4841, dtype: object
# Episode: 4840, Step: 4841, Action: 1, Observation: [5.8222108e-04 5.8467494e-04 5.7917449e-04 5.8294344e-04 1.0000000e+00
#  2.5199952e-07 7.1999864e-08 5.7868118e-04 5.7877542e-04 5.7903625e-04
#  5.8117532e-04 5.8291591e-04 1.2146306e-10 1.3148510e-10 1.3794103e-10]
# Closed trade at step 4842
# ------------------------------> Trade outcome: 58.70999999999913
# Reward: 1.5
# Step: 4842
# Open Position: 0
# Trades: 795 | Profit/Loss: 6313.17
# Balance: 106313.17
# Winning Trades: 431 | Losing Trades: 364
# Overall Rewards: 27.70
# date                2021-03-06 22:00:00
# open                           48577.22
# high                            49200.0
# low                            48463.75
# close                          48920.88
# volume usdt                    97393079
# tradecount                        64007
# hour                                 22
# day                                   6
# ema_13                      48323.14586
# ema_25                     48284.415112
# ema_32                     48293.578673
# ema_100                     48441.06101
# ema_200                    48579.844571
# vol_close                       0.01505
# vol_close_ema_3                0.012586
# vol_close_ema_6                0.012126
# vol_close_ema_12               0.012042
# Name: 4842, dtype: object
# Episode: 4841, Step: 4842, Action: 2, Observation: [4.9877487e-04 5.0516939e-04 4.9760978e-04 5.0230342e-04 1.0000000e+00
#  2.2588874e-07 6.1606016e-08 4.9616612e-04 4.9576844e-04 4.9586251e-04
#  4.9737684e-04 4.9880182e-04 1.2922761e-10 1.2451044e-10 1.2364312e-10]
# Opened trade at step 4843 with position size: 5315.66
# Reward: 0
# Step: 4843
# Open Position: 1
# Trades: 796 | Profit/Loss: 6313.17
# Balance: 106313.17
# Winning Trades: 431 | Losing Trades: 364
# Overall Rewards: 27.70
# date                2021-03-06 23:00:00
# open                           48920.87
# high                           49120.01
# low                             48805.0
# close                           48882.2
# volume usdt                    70431289
# tradecount                        54140
# hour                                 23
# day                                   6
# ema_13                     48403.010737
# ema_25                     48330.398565
# ema_32                     48329.252693
# ema_100                    48449.796436
# ema_200                    48582.853083
# vol_close                      0.006444
# vol_close_ema_3                0.009515
# vol_close_ema_6                0.010503
# vol_close_ema_12               0.011181
# Name: 4843, dtype: object
# Episode: 4842, Step: 4843, Action: 1, Observation: [6.9459004e-04 6.9741748e-04 6.9294486e-04 6.9404097e-04 1.0000000e+00
#  3.2655942e-07 8.5189413e-08 6.8723736e-04 6.8620639e-04 6.8619009e-04
#  6.8790163e-04 6.8979076e-04 1.3509724e-10 1.4912367e-10 1.5874761e-10]
# Reward: 0
# Step: 4844
# Open Position: 1
# Trades: 796 | Profit/Loss: 6313.17
# Balance: 106313.17
# Winning Trades: 431 | Losing Trades: 364
# Overall Rewards: 27.70
# date                2021-03-07 00:00:00
# open                            48882.2
# high                            49312.0
# low                             48882.2
# close                          49203.25
# volume usdt                   103198225
# tradecount                        50983
# hour                                  0
# day                                   7
# ema_13                     48517.330632
# ema_25                     48397.540983
# ema_32                     48382.222227
# ema_100                    48464.716308
# ema_200                    48589.026186
# vol_close                      0.008735
# vol_close_ema_3                0.009125
# vol_close_ema_6                0.009998
# vol_close_ema_12               0.010805
# Name: 4844, dtype: object
# Episode: 4843, Step: 4844, Action: 1, Observation: [4.7367287e-04 4.7783769e-04 4.7367287e-04 4.7678387e-04 1.0000000e+00
#  0.0000000e+00 6.7830626e-08 4.7013728e-04 4.6897648e-04 4.6882805e-04
#  4.6962741e-04 4.7083202e-04 8.8423366e-11 9.6880483e-11 1.0469707e-10]
# Closed trade at step 4845
# ------------------------------> Trade outcome: 282.3799999999974
# Reward: 1.5
# Step: 4845
# Open Position: 0
# Trades: 796 | Profit/Loss: 6595.55
# Balance: 106595.55
# Winning Trades: 432 | Losing Trades: 364
# Overall Rewards: 29.20
# date                2021-03-07 01:00:00
# open                           49203.25
# high                            49490.0
# low                            48982.17
# close                          49121.95
# volume usdt                   106634203
# tradecount                        55306
# hour                                  1
# day                                   7
# ema_13                     48603.704827
# ema_25                     48453.264753
# ema_32                     48427.054213
# ema_100                    48477.730837
# ema_200                    48594.328911
# vol_close                      0.010338
# vol_close_ema_3                0.009732
# vol_close_ema_6                0.010095
# vol_close_ema_12               0.010733
# Name: 4845, dtype: object
# Episode: 4844, Step: 4845, Action: 2, Observation: [4.61420917e-04 4.64110024e-04 4.59347677e-04 4.60658484e-04
#  1.00000000e+00 9.37785405e-09 6.56449828e-08 4.55798465e-04
#  4.54387657e-04 4.54141875e-04 4.54617111e-04 4.55710542e-04
#  9.12619147e-11 9.46704659e-11 1.00650606e-10]
# Reward: 0
# Step: 4846
# Open Position: 0
# Trades: 796 | Profit/Loss: 6595.55
# Balance: 106595.55
# Winning Trades: 432 | Losing Trades: 364
# Overall Rewards: 29.20
# date                2021-03-07 02:00:00
# open                           49121.95
# high                            49851.0
# low                            49052.91
# close                          49550.58
# volume usdt                   127803055
# tradecount                        66389
# hour                                  2
# day                                   7
# ema_13                     48738.972709
# ema_25                     48537.673619
# ema_32                     48495.146685
# ema_100                    48498.975375
# ema_200                    48603.843847
# vol_close                      0.016107
# vol_close_ema_3                0.012919
# vol_close_ema_6                0.011813
# vol_close_ema_12                0.01156
# Name: 4846, dtype: object
# Episode: 4845, Step: 4846, Action: 2, Observation: [3.84356623e-04 3.90061090e-04 3.83816398e-04 3.87710432e-04
#  1.00000000e+00 1.56490785e-08 5.47717747e-08 3.81360005e-04
#  3.79784906e-04 3.79452191e-04 3.79482139e-04 3.80302663e-04
#  1.01086056e-10 9.24286966e-11 9.04480102e-11]
# Opened trade at step 4847 with position size: 5329.78
# Reward: 0
# Step: 4847
# Open Position: 1
# Trades: 797 | Profit/Loss: 6595.55
# Balance: 106595.55
# Winning Trades: 432 | Losing Trades: 364
# Overall Rewards: 29.20
# date                2021-03-07 03:00:00
# open                           49550.57
# high                           49900.99
# low                            49433.88
# close                          49551.44
# volume usdt                    96921818
# tradecount                        45080
# hour                                  3
# day                                   7
# ema_13                     48855.039465
# ema_25                     48615.655648
# ema_32                     48559.164462
# ema_100                    48519.816258
# ema_200                    48613.272664
# vol_close                      0.009427
# vol_close_ema_3                0.011173
# vol_close_ema_6                0.011131
# vol_close_ema_12               0.011231
# Name: 4847, dtype: object
# Episode: 4846, Step: 4847, Action: 1, Observation: [5.1124272e-04 5.1485817e-04 5.1003869e-04 5.1125168e-04 1.0000000e+00
#  3.0952783e-08 7.2223159e-08 5.0406647e-04 5.0159660e-04 5.0101377e-04
#  5.0060777e-04 5.0157204e-04 1.1527784e-10 1.1484498e-10 1.1588119e-10]
# Closed trade at step 4848
# ------------------------------> Trade outcome: 0.8600000000005821
# Reward: 1.5
# Step: 4848
# Open Position: 0
# Trades: 797 | Profit/Loss: 6596.41
# Balance: 106596.41
# Winning Trades: 433 | Losing Trades: 364
# Overall Rewards: 30.70
# date                2021-03-07 04:00:00
# open                           49551.43
# high                           49687.98
# low                             49296.8
# close                          49436.18
# volume usdt                    75402078
# tradecount                        39760
# hour                                  4
# day                                   7
# ema_13                     48938.059541
# ema_25                     48678.772906
# ema_32                     48612.316918
# ema_100                    48537.962075
# ema_200                    48621.460797
# vol_close                      0.007913
# vol_close_ema_3                0.009543
# vol_close_ema_6                0.010212
# vol_close_ema_12               0.010721
# Name: 4848, dtype: object
# Episode: 4847, Step: 4848, Action: 2, Observation: [6.5716263e-04 6.5897359e-04 6.5378571e-04 6.5563415e-04 1.0000000e+00
#  5.3048936e-08 9.2835634e-08 6.4902799e-04 6.4558926e-04 6.4470788e-04
#  6.4372178e-04 6.4482918e-04 1.2655994e-10 1.3542745e-10 1.4218259e-10]
# Opened trade at step 4849 with position size: 5329.82
# Reward: 0
# Step: 4849
# Open Position: 1
# Trades: 798 | Profit/Loss: 6596.41
# Balance: 106596.41
# Winning Trades: 433 | Losing Trades: 364
# Overall Rewards: 30.70
# date                2021-03-07 05:00:00
# open                           49436.18
# high                           49459.25
# low                            49111.11
# close                           49342.0
# volume usdt                    77820439
# tradecount                        42161
# hour                                  5
# day                                   7
# ema_13                     48995.765321
# ema_25                     48729.790375
# ema_32                     48656.540136
# ema_100                    48553.883618
# ema_200                    48628.630341
# vol_close                      0.007056
# vol_close_ema_3                0.008299
# vol_close_ema_6                 0.00931
# vol_close_ema_12               0.010157
# Name: 4849, dtype: object
# Episode: 4848, Step: 4849, Action: 1, Observation: [6.3525955e-04 6.3555600e-04 6.3108240e-04 6.3404936e-04 1.0000000e+00
#  6.4250472e-08 8.9950660e-08 6.2960020e-04 6.2618242e-04 6.2524114e-04
#  6.2392198e-04 6.2488246e-04 1.0664637e-10 1.1963229e-10 1.3051821e-10]
# Reward: 0
# Step: 4850
# Open Position: 1
# Trades: 798 | Profit/Loss: 6596.41
# Balance: 106596.41
# Winning Trades: 433 | Losing Trades: 364
# Overall Rewards: 30.70
# date                2021-03-07 06:00:00
# open                            49342.0
# high                            49650.0
# low                            49146.68
# close                          49458.56
# volume usdt                    73428066
# tradecount                        40988
# hour                                  6
# day                                   7
# ema_13                     49061.878847
# ema_25                     48785.849576
# ema_32                       48705.1474
# ema_100                    48571.798002
# ema_200                    48636.888348
# vol_close                      0.010177
# vol_close_ema_3                0.009238
# vol_close_ema_6                0.009557
# vol_close_ema_12                0.01016
# Name: 4850, dtype: object
# Episode: 4849, Step: 4850, Action: 1, Observation: [6.7197741e-04 6.7617197e-04 6.6931738e-04 6.7356479e-04 1.0000000e+00
#  8.1712628e-08 9.5331401e-08 6.6816248e-04 6.6440331e-04 6.6330429e-04
#  6.6148821e-04 6.6237460e-04 1.2580931e-10 1.3016119e-10 1.3836673e-10]
# Closed trade at step 4851
# ------------------------------> Trade outcome: 23.43000000000029
# Reward: 1.5
# Step: 4851
# Open Position: 0
# Trades: 798 | Profit/Loss: 6619.84
# Balance: 106619.84
# Winning Trades: 434 | Losing Trades: 364
# Overall Rewards: 32.20
# date                2021-03-07 07:00:00
# open                           49459.61
# high                           50179.17
# low                            49327.57
# close                          50052.68
# volume usdt                    98810047
# tradecount                        59667
# hour                                  7
# day                                   7
# ema_13                     49203.421869
# ema_25                     48883.298071
# ema_32                     48786.816042
# ema_100                    48601.122398
# ema_200                    48650.975827
# vol_close                      0.017014
# vol_close_ema_3                0.013126
# vol_close_ema_6                0.011688
# vol_close_ema_12               0.011214
# Name: 4851, dtype: object
# Episode: 4850, Step: 4851, Action: 2, Observation: [5.0055241e-04 5.0783472e-04 4.9921614e-04 5.0655456e-04 1.0000000e+00
#  7.0843001e-08 7.0843001e-08 4.9795973e-04 4.9471989e-04 4.9374346e-04
#  4.9186416e-04 4.9236871e-04 1.3284078e-10 1.1828694e-10 1.1349529e-10]
# Reward: 0
# Step: 4852
# Open Position: 0
# Trades: 798 | Profit/Loss: 6619.84
# Balance: 106619.84
# Winning Trades: 434 | Losing Trades: 364
# Overall Rewards: 32.20
# date                2021-03-07 08:00:00
# open                           50041.84
# high                           50839.54
# low                            50041.84
# close                          50383.09
# volume usdt                   217681722
# tradecount                       102837
# hour                                  8
# day                                   7
# ema_13                     49371.945887
# ema_25                     48998.666681
# ema_32                     48883.559919
# ema_100                    48636.408885
# ema_200                    48668.210794
# vol_close                      0.015833
# vol_close_ema_3                0.014479
# vol_close_ema_6                0.012872
# vol_close_ema_12               0.011925
# Name: 4852, dtype: object
# Episode: 4851, Step: 4852, Action: 0, Observation: [2.2988535e-04 2.3354987e-04 2.2988535e-04 2.3145300e-04 1.0000000e+00
#  3.6750901e-08 3.2157040e-08 2.2680794e-04 2.2509316e-04 2.2456437e-04
#  2.2342900e-04 2.2357509e-04 6.6516140e-11 5.9132907e-11 5.4781676e-11]
# Opened trade at step 4853 with position size: 5330.99
# Reward: 0
# Step: 4853
# Open Position: 1
# Trades: 799 | Profit/Loss: 6619.84
# Balance: 106619.84
# Winning Trades: 434 | Losing Trades: 364
# Overall Rewards: 32.20
# date                2021-03-07 09:00:00
# open                           50384.11
# high                           51148.22
# low                            50384.11
# close                          50943.02
# volume usdt                   214282779
# tradecount                        92581
# hour                                  9
# day                                   7
# ema_13                     49596.385046
# ema_25                     49148.232321
# ema_32                     49008.375681
# ema_100                    48682.084353
# ema_200                    48690.845711
# vol_close                      0.014999
# vol_close_ema_3                0.014739
# vol_close_ema_6                 0.01348
# vol_close_ema_12               0.012398
# Name: 4853, dtype: object
# Episode: 4852, Step: 4853, Action: 1, Observation: [2.3512906e-04 2.3869495e-04 2.3512906e-04 2.3773735e-04 1.0000000e+00
#  4.2000575e-08 3.2667113e-08 2.3145297e-04 2.2936154e-04 2.2870887e-04
#  2.2718617e-04 2.2722706e-04 6.8784471e-11 6.2907117e-11 5.7857868e-11]
# Closed trade at step 4854
# ------------------------------> Trade outcome: 558.7099999999991
# Reward: 1.5
# Step: 4854
# Open Position: 0
# Trades: 799 | Profit/Loss: 7178.55
# Balance: 107178.55
# Winning Trades: 435 | Losing Trades: 364
# Overall Rewards: 33.70
# date                2021-03-07 10:00:00
# open                           50942.82
# high                           50985.84
# low                             50448.3
# close                          50612.92
# volume usdt                   143295201
# tradecount                        77271
# hour                                 10
# day                                   7
# ema_13                     49741.604325
# ema_25                     49260.900604
# ema_32                     49105.620791
# ema_100                    48720.318722
# ema_200                    48709.970829
# vol_close                      0.010621
# vol_close_ema_3                 0.01268
# vol_close_ema_6                0.012663
# vol_close_ema_12               0.012125
# Name: 4854, dtype: object
# Episode: 4853, Step: 4854, Action: 2, Observation: [3.5550960e-04 3.5580981e-04 3.5205856e-04 3.5320738e-04 1.0000000e+00
#  6.9786012e-08 4.8850207e-08 3.4712680e-04 3.4377218e-04 3.4268852e-04
#  3.3999968e-04 3.3992744e-04 8.8488432e-11 8.8369798e-11 8.4612109e-11]
# Reward: 0
# Step: 4855
# Open Position: 0
# Trades: 799 | Profit/Loss: 7178.55
# Balance: 107178.55
# Winning Trades: 435 | Losing Trades: 364
# Overall Rewards: 33.70
# date                2021-03-07 11:00:00
# open                           50612.92
# high                           50899.22
# low                            50472.81
# close                          50705.52
# volume usdt                   104312733
# tradecount                        95481
# hour                                 11
# day                                   7
# ema_13                     49879.306565
# ema_25                     49372.025173
# ema_32                      49202.58438
# ema_100                    48759.629638
# ema_200                    48729.827039
# vol_close                       0.00841
# vol_close_ema_3                0.010545
# vol_close_ema_6                0.011448
# vol_close_ema_12               0.011553
# Name: 4855, dtype: object
# Episode: 4854, Step: 4855, Action: 2, Observation: [4.85203665e-04 4.87948273e-04 4.83860465e-04 4.86091361e-04
#  1.00000000e+00 1.05452131e-07 6.71059013e-08 4.78170812e-04
#  4.73307708e-04 4.71683394e-04 4.67436970e-04 4.67151287e-04
#  1.01087874e-10 1.09744054e-10 1.10753254e-10]
# Reward: 0
# Step: 4856
# Open Position: 0
# Trades: 799 | Profit/Loss: 7178.55
# Balance: 107178.55
# Winning Trades: 435 | Losing Trades: 364
# Overall Rewards: 33.70
# date                2021-03-07 12:00:00
# open                           50705.52
# high                           50827.68
# low                            50391.19
# close                           50746.2
# volume usdt                    97483870
# tradecount                        98865
# hour                                 12
# day                                   7
# ema_13                     50003.148484
# ema_25                     49477.730928
# ema_32                     49296.136842
# ema_100                    48798.967665
# ema_200                    48749.890452
# vol_close                      0.008601
# vol_close_ema_3                0.009573
# vol_close_ema_6                0.010634
# vol_close_ema_12               0.011099
# Name: 4856, dtype: object
# Episode: 4855, Step: 4856, Action: 2, Observation: [5.20142668e-04 5.21395763e-04 5.16918255e-04 5.20559959e-04
#  1.00000000e+00 1.23097280e-07 7.18067525e-08 5.12937666e-04
#  5.07547869e-04 5.05685050e-04 5.00585069e-04 5.00081573e-04
#  9.82018078e-11 1.09089654e-10 1.13853621e-10]
# Reward: 0
# Step: 4857
# Open Position: 0
# Trades: 799 | Profit/Loss: 7178.55
# Balance: 107178.55
# Winning Trades: 435 | Losing Trades: 364
# Overall Rewards: 33.70
# date                2021-03-07 13:00:00
# open                            50746.2
# high                            50850.0
# low                            50504.22
# close                          50764.44
# volume usdt                    74825391
# tradecount                        78201
# hour                                 13
# day                                   7
# ema_13                     50111.904415
# ema_25                     49576.708549
# ema_32                     49385.124912
# ema_100                    48837.887909
# ema_200                    48769.935721
# vol_close                      0.006811
# vol_close_ema_3                0.008192
# vol_close_ema_6                0.009542
# vol_close_ema_12               0.010439
# Name: 4857, dtype: object
# Episode: 4856, Step: 4857, Action: 0, Observation: [6.7819492e-04 6.7958212e-04 6.7496096e-04 6.7843869e-04 1.0000000e+00
#  1.7373782e-07 9.3551130e-08 6.6971791e-04 6.6256529e-04 6.6000491e-04
#  6.5269135e-04 6.5178325e-04 1.0948525e-10 1.2752610e-10 1.3951529e-10]
# Reward: 0
# Step: 4858
# Open Position: 0
# Trades: 799 | Profit/Loss: 7178.55
# Balance: 107178.55
# Winning Trades: 435 | Losing Trades: 364
# Overall Rewards: 33.70
# date                2021-03-07 14:00:00
# open                           50764.44
# high                            51250.0
# low                            50130.65
# close                          50646.34
# volume usdt                   175437666
# tradecount                       132882
# hour                                 14
# day                                   7
# ema_13                     50188.252356
# ema_25                     49658.987892
# ema_32                      49461.56219
# ema_100                    48873.698842
# ema_200                     48788.60641
# vol_close                      0.022101
# vol_close_ema_3                0.015147
# vol_close_ema_6                0.013131
# vol_close_ema_12               0.012233
# Name: 4858, dtype: object
# Episode: 4857, Step: 4858, Action: 0, Observation: [2.8935887e-04 2.9212655e-04 2.8574621e-04 2.8868567e-04 1.0000000e+00
#  7.9800422e-08 3.9900211e-08 2.8607456e-04 2.8305774e-04 2.8193241e-04
#  2.7858157e-04 2.7809653e-04 8.6337160e-11 7.4844290e-11 6.9730992e-11]
# Reward: 0
# Step: 4859
# Open Position: 0
# Trades: 799 | Profit/Loss: 7178.55
# Balance: 107178.55
# Winning Trades: 435 | Losing Trades: 364
# Overall Rewards: 33.70
# date                2021-03-07 15:00:00
# open                           50644.47
# high                           50827.93
# low                             50375.0
# close                          50585.23
# volume usdt                    86620571
# tradecount                        82961
# hour                                 15
# day                                   7
# ema_13                     50244.963448
# ema_25                     49730.237285
# ema_32                     49529.663269
# ema_100                    48907.590548
# ema_200                    48806.483262
# vol_close                      0.008954
# vol_close_ema_3                 0.01205
# vol_close_ema_6                0.011937
# vol_close_ema_12               0.011729
# Name: 4859, dtype: object
# Episode: 4858, Step: 4859, Action: 2, Observation: [5.8467023e-04 5.8678823e-04 5.8155932e-04 5.8398634e-04 1.0000000e+00
#  1.7316903e-07 8.0812214e-08 5.8005814e-04 5.7411584e-04 5.7180028e-04
#  5.6461868e-04 5.6345144e-04 1.3911586e-10 1.3780979e-10 1.3540527e-10]
# Reward: 0
# Step: 4860
# Open Position: 0
# Trades: 799 | Profit/Loss: 7178.55
# Balance: 107178.55
# Winning Trades: 435 | Losing Trades: 364
# Overall Rewards: 33.70
# date                2021-03-07 16:00:00
# open                           50585.23
# high                            51352.1
# low                            50585.23
# close                           51052.9
# volume usdt                   182478942
# tradecount                       142491
# hour                                 16
# day                                   7
# ema_13                     50360.382955
# ema_25                      49831.98057
# ema_32                     49621.980647
# ema_100                    48950.071923
# ema_200                    48828.835667
# vol_close                      0.015021
# vol_close_ema_3                0.013536
# vol_close_ema_6                0.012818
# vol_close_ema_12               0.012235
# Name: 4860, dtype: object
# Episode: 4859, Step: 4860, Action: 0, Observation: [2.7721134e-04 2.8141384e-04 2.7721134e-04 2.7977419e-04 1.0000000e+00
#  8.7681350e-08 3.8360589e-08 2.7597914e-04 2.7308345e-04 2.7193263e-04
#  2.6825050e-04 2.6758615e-04 7.4176727e-11 7.0245275e-11 6.7050886e-11]
# Reward: 0
# Step: 4861
# Open Position: 0
# Trades: 799 | Profit/Loss: 7178.55
# Balance: 107178.55
# Winning Trades: 435 | Losing Trades: 364
# Overall Rewards: 33.70
# date                2021-03-07 17:00:00
# open                           51052.89
# high                            51201.0
# low                            50757.59
# close                          51075.93
# volume usdt                   111189340
# tradecount                        72122
# hour                                 17
# day                                   7
# ema_13                     50462.603962
# ema_25                     49927.668988
# ema_32                      49710.09879
# ema_100                    48992.168123
# ema_200                    48851.194815
# vol_close                      0.008681
# vol_close_ema_3                0.011109
# vol_close_ema_6                0.011636
# vol_close_ema_12               0.011689
# Name: 4861, dtype: object
# Episode: 4860, Step: 4861, Action: 2, Observation: [4.5915274e-04 4.6048476e-04 4.5649690e-04 4.5935993e-04 1.0000000e+00
#  1.5289235e-07 6.2955671e-08 4.5384391e-04 4.4903284e-04 4.4707611e-04
#  4.4061927e-04 4.3935142e-04 9.9906507e-11 1.0465314e-10 1.0512345e-10]
# Reward: 0
# Step: 4862
# Open Position: 0
# Trades: 799 | Profit/Loss: 7178.55
# Balance: 107178.55
# Winning Trades: 435 | Losing Trades: 364
# Overall Rewards: 33.70
# date                2021-03-07 18:00:00
# open                           51075.92
# high                           51085.71
# low                             50368.2
# close                          50412.31
# volume usdt                    96571298
# tradecount                        55137
# hour                                 18
# day                                   7
# ema_13                      50455.41911
# ema_25                     49964.949066
# ema_32                     49752.657045
# ema_100                    49020.289744
# ema_200                    48866.728299
# vol_close                      0.014233
# vol_close_ema_3                0.012671
# vol_close_ema_6                0.012378
# vol_close_ema_12                0.01208
# Name: 4862, dtype: object
# Episode: 4861, Step: 4862, Action: 2, Observation: [5.2889343e-04 5.2899477e-04 5.2156491e-04 5.2202167e-04 1.0000000e+00
#  1.8639079e-07 7.2485307e-08 5.2246806e-04 5.1738921e-04 5.1519094e-04
#  5.0760724e-04 5.0601707e-04 1.3120552e-10 1.2817657e-10 1.2508920e-10]
# Reward: 0
# Step: 4863
# Open Position: 0
# Trades: 799 | Profit/Loss: 7178.55
# Balance: 107178.55
# Winning Trades: 435 | Losing Trades: 364
# Overall Rewards: 33.70
# date                2021-03-07 19:00:00
# open                           50412.31
# high                           50580.21
# low                             50250.0
# close                          50381.68
# volume usdt                    82922192
# tradecount                        56614
# hour                                 19
# day                                   7
# ema_13                     50444.884951
# ema_25                     49997.005292
# ema_32                     49790.779648
# ema_100                    49047.247967
# ema_200                    48881.802446
# vol_close                      0.006554
# vol_close_ema_3                0.009612
# vol_close_ema_6                0.010714
# vol_close_ema_12                0.01123
# Name: 4863, dtype: object
# Episode: 4862, Step: 4863, Action: 0, Observation: [6.07947120e-04 6.09971932e-04 6.05989771e-04 6.07577735e-04
#  1.00000000e+00 2.29130464e-07 8.44164845e-08 6.08340022e-04
#  6.02938759e-04 6.00451836e-04 5.91485179e-04 5.89489995e-04
#  1.15921044e-10 1.29207561e-10 1.35426892e-10]
# Opened trade at step 4864 with position size: 5358.93
# Reward: 0
# Step: 4864
# Open Position: 1
# Trades: 800 | Profit/Loss: 7178.55
# Balance: 107178.55
# Winning Trades: 435 | Losing Trades: 364
# Overall Rewards: 33.70
# date                2021-03-07 20:00:00
# open                           50381.69
# high                           50381.69
# low                            49758.01
# close                          50036.64
# volume usdt                   131910393
# tradecount                        75982
# hour                                 20
# day                                   7
# ema_13                     50386.564244
# ema_25                     50000.054115
# ema_32                     49805.680275
# ema_100                    49066.839889
# ema_200                    48893.293367
# vol_close                      0.012464
# vol_close_ema_3                0.011038
# vol_close_ema_6                0.011214
# vol_close_ema_12                0.01142
# Name: 4864, dtype: object
# Episode: 4863, Step: 4864, Action: 1, Observation: [3.8193876e-04 3.8193876e-04 3.7721070e-04 3.7932297e-04 1.0000000e+00
#  1.5161808e-07 5.3066326e-08 3.8197570e-04 3.7904561e-04 3.7757208e-04
#  3.7197099e-04 3.7065535e-04 8.3681402e-11 8.5014204e-11 8.6572624e-11]
# Closed trade at step 4865
# ------------------------------> Trade outcome: -345.06000000000495
# Trade reached the maximum stop loss
# Reward: -1.7
# Step: 4865
# Open Position: 0
# Trades: 800 | Profit/Loss: 6833.49
# Balance: 106833.49
# Winning Trades: 435 | Losing Trades: 365
# Overall Rewards: 32.00
# date                2021-03-07 21:00:00
# open                           50036.63
# high                           50265.81
# low                            49833.08
# close                          50086.12
# volume usdt                    72905829
# tradecount                        46097
# hour                                 21
# day                                   7
# ema_13                     50343.643638
# ema_25                     50006.674568
# ema_32                     49822.676622
# ema_100                    49087.023653
# ema_200                    48905.162288
# vol_close                       0.00864
# vol_close_ema_3                0.009839
# vol_close_ema_6                0.010479
# vol_close_ema_12               0.010992
# Name: 4865, dtype: object
# Episode: 4864, Step: 4865, Action: 2, Observation: [6.8631861e-04 6.8946212e-04 6.8352662e-04 6.8699743e-04 1.0000000e+00
#  2.8804280e-07 9.6014269e-08 6.9052971e-04 6.8590778e-04 6.8338396e-04
#  6.7329349e-04 6.7079905e-04 1.3495605e-10 1.4372890e-10 1.5077148e-10]
# Reward: 0
# Step: 4866
# Open Position: 0
# Trades: 800 | Profit/Loss: 6833.49
# Balance: 106833.49
# Winning Trades: 435 | Losing Trades: 365
# Overall Rewards: 32.00
# date                2021-03-07 22:00:00
# open                           50086.11
# high                           50784.12
# low                            49986.39
# close                          50498.55
# volume usdt                    76506985
# tradecount                        57815
# hour                                 22
# day                                   7
# ema_13                     50365.773118
# ema_25                      50044.51114
# ema_32                     49863.638645
# ema_100                     49114.97467
# ema_200                    48921.016892
# vol_close                      0.015797
# vol_close_ema_3                0.012818
# vol_close_ema_6                0.011998
# vol_close_ema_12               0.011731
# Name: 4866, dtype: object
# Episode: 4865, Step: 4866, Action: 0, Observation: [6.5466063e-04 6.6378410e-04 6.5335725e-04 6.6005153e-04 1.0000000e+00
#  2.8755545e-07 9.1494918e-08 6.5831601e-04 6.5411691e-04 6.5175275e-04
#  6.4196723e-04 6.3943205e-04 1.6754137e-10 1.5682518e-10 1.5333691e-10]
# Opened trade at step 4867 with position size: 5341.67
# Reward: 0
# Step: 4867
# Open Position: 1
# Trades: 801 | Profit/Loss: 6833.49
# Balance: 106833.49
# Winning Trades: 435 | Losing Trades: 365
# Overall Rewards: 32.00
# date                2021-03-07 23:00:00
# open                           50498.56
# high                           51450.03
# low                            50480.89
# close                          50971.75
# volume usdt                   150433067
# tradecount                        90430
# hour                                 23
# day                                   7
# ema_13                     50452.341244
# ema_25                     50115.837206
# ema_32                     49930.796909
# ema_100                    49151.742498
# ema_200                    48941.422197
# vol_close                      0.019013
# vol_close_ema_3                0.015916
# vol_close_ema_6                0.014003
# vol_close_ema_12               0.012852
# Name: 4867, dtype: object
# Episode: 4866, Step: 4867, Action: 1, Observation: [3.3568789e-04 3.4201276e-04 3.3557042e-04 3.3883340e-04 1.0000000e+00
#  1.5289191e-07 4.6532321e-08 3.3538064e-04 3.3314375e-04 3.3191370e-04
#  3.2673494e-04 3.2533685e-04 1.0579908e-10 9.3081418e-11 8.5430968e-11]
# Reward: 0
# Step: 4868
# Open Position: 1
# Trades: 801 | Profit/Loss: 6833.49
# Balance: 106833.49
# Winning Trades: 435 | Losing Trades: 365
# Overall Rewards: 32.00
# date                2021-03-08 00:00:00
# open                           50959.11
# high                            51685.0
# low                            50843.59
# close                           51491.1
# volume usdt                   167532221
# tradecount                        87283
# hour                                  0
# day                                   1
# ema_13                     50600.735352
# ema_25                     50221.626652
# ema_32                     50025.360733
# ema_100                    49198.066409
# ema_200                    48966.792125
# vol_close                      0.016341
# vol_close_ema_3                0.016128
# vol_close_ema_6                0.014671
# vol_close_ema_12               0.013388
# Name: 4868, dtype: object
# Episode: 4867, Step: 4868, Action: 1, Observation: [3.0417496e-04 3.0850782e-04 3.0348543e-04 3.0735042e-04 1.0000000e+00
#  0.0000000e+00 5.9690008e-09 3.0203583e-04 2.9977292e-04 2.9860143e-04
#  2.9366330e-04 2.9228284e-04 9.6269728e-11 8.7568973e-11 7.9915657e-11]
# Reward: 0
# Step: 4869
# Open Position: 1
# Trades: 801 | Profit/Loss: 6833.49
# Balance: 106833.49
# Winning Trades: 435 | Losing Trades: 365
# Overall Rewards: 32.00
# date                2021-03-08 01:00:00
# open                            51491.1
# high                           51847.38
# low                            51250.05
# close                           51557.7
# volume usdt                   133321736
# tradecount                        68603
# hour                                  1
# day                                   1
# ema_13                     50737.444587
# ema_25                     50324.401525
# ema_32                     50118.229779
# ema_100                    49244.791827
# ema_200                    48992.572303
# vol_close                      0.011586
# vol_close_ema_3                0.013857
# vol_close_ema_6                0.013789
# vol_close_ema_12               0.013111
# Name: 4869, dtype: object
# Episode: 4868, Step: 4869, Action: 0, Observation: [3.86216852e-04 3.88889166e-04 3.84408806e-04 3.86716390e-04
#  1.00000000e+00 7.50065254e-09 7.50065254e-09 3.80563928e-04
#  3.77465854e-04 3.75919422e-04 3.69368063e-04 3.67476256e-04
#  1.03936318e-10 1.03428044e-10 9.83417792e-11]
# Closed trade at step 4870
# ------------------------------> Trade outcome: 1059.1399999999994
# Reward: 1.5
# Step: 4870
# Open Position: 0
# Trades: 801 | Profit/Loss: 7892.63
# Balance: 107892.63
# Winning Trades: 436 | Losing Trades: 365
# Overall Rewards: 33.50
# date                2021-03-08 02:00:00
# open                            51557.7
# high                           51594.22
# low                            50481.84
# close                          50730.82
# volume usdt                   148006874
# tradecount                        91650
# hour                                  2
# day                                   1
# ema_13                     50736.498218
# ema_25                     50355.664484
# ema_32                     50155.356459
# ema_100                    49274.218127
# ema_200                      49009.8683
# vol_close                      0.021927
# vol_close_ema_3                0.017892
# vol_close_ema_6                0.016114
# vol_close_ema_12               0.014467
# Name: 4870, dtype: object
# Episode: 4869, Step: 4870, Action: 2, Observation: [3.48346628e-04 3.48593370e-04 3.41077655e-04 3.42759886e-04
#  1.00000000e+00 1.35128850e-08 6.75644252e-09 3.42798245e-04
#  3.40225146e-04 3.38871789e-04 3.32918426e-04 3.31132353e-04
#  1.20886537e-10 1.08875485e-10 9.77481915e-11]
# Reward: 0
# Step: 4871
# Open Position: 0
# Trades: 801 | Profit/Loss: 7892.63
# Balance: 107892.63
# Winning Trades: 436 | Losing Trades: 365
# Overall Rewards: 33.50
# date                2021-03-08 03:00:00
# open                           50730.82
# high                           50808.32
# low                            50234.98
# close                          50598.49
# volume usdt                   131406017
# tradecount                        78549
# hour                                  3
# day                                   1
# ema_13                     50716.782758
# ema_25                      50374.34337
# ema_32                     50182.213038
# ema_100                    49300.441333
# ema_200                    49025.675481
# vol_close                      0.011331
# vol_close_ema_3                0.014612
# vol_close_ema_6                0.014748
# vol_close_ema_12               0.013985
# Name: 4871, dtype: object
# Episode: 4870, Step: 4871, Action: 0, Observation: [3.86061613e-04 3.86651402e-04 3.82288272e-04 3.85054591e-04
#  1.00000000e+00 2.28300046e-08 7.61000152e-09 3.85954801e-04
#  3.83348844e-04 3.81886726e-04 3.75176431e-04 3.73085466e-04
#  1.11194325e-10 1.12230059e-10 1.06425167e-10]
# Opened trade at step 4872 with position size: 5394.63
# Reward: 0
# Step: 4872
# Open Position: 1
# Trades: 802 | Profit/Loss: 7892.63
# Balance: 107892.63
# Winning Trades: 436 | Losing Trades: 365
# Overall Rewards: 33.50
# date                2021-03-08 04:00:00
# open                           50598.49
# high                            50598.5
# low                             50100.0
# close                          50417.44
# volume usdt                   113395708
# tradecount                        74157
# hour                                  4
# day                                   1
# ema_13                     50674.019507
# ...
# vol_close_ema_6                 0.01127
# vol_close_ema_12               0.012612
# Name: 4987, dtype: object
# Episode: 4986, Step: 4987, Action: 2, Observation: [5.2156101e-04 5.2468828e-04 5.2152807e-04 5.2214897e-04 1.0000000e+00
#  2.0987531e-07 4.5625068e-08 5.1961915e-04 5.1863003e-04 5.1785703e-04
#  5.0435431e-04 4.8746992e-04 8.5654671e-11 1.0283618e-10 1.1508786e-10]
# Reward: 0
# Step: 4988
# Open Position: 0
# Trades: 818 | Profit/Loss: 16408.01
# Balance: 116408.01
# Winning Trades: 451 | Losing Trades: 367
# Overall Rewards: 52.60
# date                2021-03-13 00:00:00
# open                           57221.72
# high                            57307.2
# low                            56312.91
# close                          56689.35
# volume usdt                   165168453
# tradecount                       113394
# hour                                  0
# day                                   6
# ema_13                     56908.034306
# ema_25                     56824.798076
# ema_32                     56747.613936
# ema_100                    55299.699862
# ema_200                    53453.800109
# vol_close                      0.017539
# vol_close_ema_3                0.013463
# vol_close_ema_6                0.013061
# vol_close_ema_12                0.01337
# Name: 4988, dtype: object
# Episode: 4987, Step: 4988, Action: 0, Observation: [3.4644461e-04 3.4696216e-04 3.4094229e-04 3.4322144e-04 1.0000000e+00
#  0.0000000e+00 3.6326551e-08 3.4454543e-04 3.4404147e-04 3.4357418e-04
#  3.3480788e-04 3.2363203e-04 8.1510944e-11 7.9076891e-11 8.0949712e-11]
# Reward: 0
# Step: 4989
# Open Position: 0
# Trades: 818 | Profit/Loss: 16408.01
# Balance: 116408.01
# Winning Trades: 451 | Losing Trades: 367
# Overall Rewards: 52.60
# date                2021-03-13 01:00:00
# open                           56689.36
# high                            56707.0
# low                            56081.59
# close                          56386.39
# volume usdt                   132887327
# tradecount                        74110
# hour                                  1
# day                                   6
# ema_13                     56833.513691
# ema_25                     56791.074377
# ema_32                     56725.721576
# ema_100                    55321.218479
# ema_200                    53482.980108
# vol_close                      0.011092
# vol_close_ema_3                0.012277
# vol_close_ema_6                0.012498
# vol_close_ema_12                0.01302
# Name: 4989, dtype: object
# Episode: 4988, Step: 4989, Action: 0, Observation: [4.2659717e-04 4.2672994e-04 4.2202362e-04 4.2431729e-04 1.0000000e+00
#  7.5251716e-09 4.5151033e-08 4.2768198e-04 4.2736260e-04 4.2687083e-04
#  4.1630169e-04 4.0246864e-04 9.2388583e-11 9.4051808e-11 9.7975850e-11]
# Reward: 0
# Step: 4990
# Open Position: 0
# Trades: 818 | Profit/Loss: 16408.01
# Balance: 116408.01
# Winning Trades: 451 | Losing Trades: 367
# Overall Rewards: 52.60
# date                2021-03-13 02:00:00
# open                           56386.39
# high                           56639.54
# low                            56078.23
# close                          56473.41
# volume usdt                   123160401
# tradecount                        60691
# hour                                  2
# day                                   6
# ema_13                     56782.070307
# ema_25                     56766.638656
# ema_32                     56710.429965
# ema_100                    55344.034153
# ema_200                    53512.735629
# vol_close                      0.009939
# vol_close_ema_3                0.011108
# vol_close_ema_6                0.011767
# vol_close_ema_12               0.012546
# Name: 4990, dtype: object
# Episode: 4989, Step: 4990, Action: 0, Observation: [4.5782889e-04 4.5988435e-04 4.5532681e-04 4.5853545e-04 1.0000000e+00
#  1.6238985e-08 4.8716959e-08 4.6104161e-04 4.6091632e-04 4.6045994e-04
#  4.4936550e-04 4.3449627e-04 9.0193922e-11 9.5543462e-11 1.0186590e-10]
# Opened trade at step 4991 with position size: 5820.40
# Reward: 0
# Step: 4991
# Open Position: 1
# Trades: 819 | Profit/Loss: 16408.01
# Balance: 116408.01
# Winning Trades: 451 | Losing Trades: 367
# Overall Rewards: 52.60
# date                2021-03-13 03:00:00
# open                           56473.41
# high                            56790.0
# low                            56308.98
# close                          56694.32
# volume usdt                   107744213
# tradecount                        54805
# hour                                  3
# day                                   6
# ema_13                     56769.534549
# ema_25                     56761.075683
# ema_32                     56709.453604
# ema_100                    55370.772486
# ema_200                    53544.393185
# vol_close                      0.008484
# vol_close_ema_3                0.009796
# vol_close_ema_6                0.010829
# vol_close_ema_12               0.011921
# Name: 4991, dtype: object
# Episode: 4990, Step: 4991, Action: 1, Observation: [5.24143339e-04 5.27081662e-04 5.22617192e-04 5.26193646e-04
#  1.00000000e+00 2.78437220e-08 5.56874440e-08 5.26891730e-04
#  5.26813208e-04 5.26334101e-04 5.13909501e-04 4.96958441e-04
#  9.09225958e-11 1.00508879e-10 1.10641794e-10]
# Reward: 0
# Step: 4992
# Open Position: 1
# Trades: 819 | Profit/Loss: 16408.01
# Balance: 116408.01
# Winning Trades: 451 | Losing Trades: 367
# Overall Rewards: 52.60
# date                2021-03-13 04:00:00
# open                           56694.32
# high                            56899.0
# low                            56257.47
# close                          56896.32
# volume usdt                    87520343
# tradecount                        52050
# hour                                  4
# day                                   6
# ema_13                     56787.646756
# ema_25                     56771.479092
# ema_32                      56720.77884
# ema_100                    55400.981348
# ema_200                    53577.745691
# vol_close                      0.011275
# vol_close_ema_3                0.010536
# vol_close_ema_6                0.010957
# vol_close_ema_12               0.011822
# Name: 4992, dtype: object
# Episode: 4991, Step: 4992, Action: 0, Observation: [6.4778450e-04 6.5012311e-04 6.4279302e-04 6.5009249e-04 1.0000000e+00
#  4.5703658e-08 6.8555487e-08 6.4885081e-04 6.4866612e-04 6.4808677e-04
#  6.3300692e-04 6.1217474e-04 1.2038233e-10 1.2519064e-10 1.3507365e-10]
# Reward: 0
# Step: 4993
# Open Position: 1
# Trades: 819 | Profit/Loss: 16408.01
# Balance: 116408.01
# Winning Trades: 451 | Losing Trades: 367
# Overall Rewards: 52.60
# date                2021-03-13 05:00:00
# open                           56882.74
# high                           57090.46
# low                             56610.0
# close                          56744.89
# volume usdt                    81423247
# tradecount                        49512
# hour                                  5
# day                                   6
# ema_13                     56781.538648
# ema_25                     56769.433777
# ema_32                     56722.240122
# ema_100                      55427.5934
# ema_200                    53609.259565
# vol_close                      0.008467
# vol_close_ema_3                0.009501
# vol_close_ema_6                0.010245
# vol_close_ema_12               0.011306
# Name: 4993, dtype: object
# Episode: 4992, Step: 4993, Action: 0, Observation: [6.9860561e-04 7.0115674e-04 6.9525599e-04 6.9691264e-04 1.0000000e+00
#  6.1407526e-08 7.3689030e-08 6.9736276e-04 6.9721404e-04 6.9663441e-04
#  6.8073423e-04 6.5840234e-04 1.1669223e-10 1.2582871e-10 1.3884964e-10]
# Reward: 0
# Step: 4994
# Open Position: 1
# Trades: 819 | Profit/Loss: 16408.01
# Balance: 116408.01
# Winning Trades: 451 | Losing Trades: 367
# Overall Rewards: 52.60
# date                2021-03-13 06:00:00
# open                           56744.89
# high                           57060.86
# low                            56491.92
# close                          56931.58
# volume usdt                    99851921
# tradecount                        57668
# hour                                  6
# day                                   6
# ema_13                     56802.973127
# ema_25                     56781.906563
# ema_32                     56734.927388
# ema_100                    55457.375313
# ema_200                    53642.317479
# vol_close                      0.009993
# vol_close_ema_3                0.009747
# vol_close_ema_6                0.010173
# vol_close_ema_12               0.011104
# Name: 4994, dtype: object
# Episode: 4993, Step: 4994, Action: 1, Observation: [5.6829042e-04 5.7145482e-04 5.6575699e-04 5.7016005e-04 1.0000000e+00
#  6.0088979e-08 6.0088979e-08 5.6887208e-04 5.6866114e-04 5.6819065e-04
#  5.5539620e-04 5.3721870e-04 9.7618851e-11 1.0188474e-10 1.1120180e-10]
# Closed trade at step 4995
# ------------------------------> Trade outcome: 458.1599999999962
# Reward: 1.5
# Step: 4995
# Open Position: 0
# Trades: 819 | Profit/Loss: 16866.17
# Balance: 116866.17
# Winning Trades: 452 | Losing Trades: 367
# Overall Rewards: 54.10
# date                2021-03-13 07:00:00
# open                           56931.57
# high                           57389.58
# low                             56753.9
# close                           57343.7
# volume usdt                   113909859
# tradecount                        69690
# hour                                  7
# day                                   6
# ema_13                     56880.219823
# ema_25                     56825.121443
# ema_32                     56771.822698
# ema_100                    55494.728277
# ema_200                    53679.147156
# vol_close                      0.011085
# vol_close_ema_3                0.010416
# vol_close_ema_6                0.010434
# vol_close_ema_12               0.011101
# Name: 4995, dtype: object
# Episode: 4994, Step: 4995, Action: 2, Observation: [4.9979496e-04 5.0381571e-04 4.9823517e-04 5.0341297e-04 1.0000000e+00
#  6.1452099e-08 5.2673229e-08 4.9934414e-04 4.9886043e-04 4.9839256e-04
#  4.8718107e-04 4.7124235e-04 9.1444533e-11 9.1598507e-11 9.7453386e-11]
# Opened trade at step 4996 with position size: 5843.31
# Reward: 0
# Step: 4996
# Open Position: 1
# Trades: 820 | Profit/Loss: 16866.17
# Balance: 116866.17
# Winning Trades: 452 | Losing Trades: 367
# Overall Rewards: 54.10
# date                2021-03-13 08:00:00
# open                            57343.7
# high                           57649.03
# low                             57126.2
# close                          57434.31
# volume usdt                   169868896
# tradecount                        85667
# hour                                  8
# day                                   6
# ema_13                     56959.375563
# ema_25                     56871.982101
# ema_32                     56811.973443
# ema_100                    55533.135836
# ema_200                    53716.511961
# vol_close                      0.009103
# vol_close_ema_3                 0.00976
# vol_close_ema_6                0.010054
# vol_close_ema_12               0.010794
# Name: 4996, dtype: object
# Episode: 4995, Step: 4996, Action: 1, Observation: [3.3757620e-04 3.3937368e-04 3.3629581e-04 3.3810962e-04 1.0000000e+00
#  4.7095142e-08 3.5321357e-08 3.3531373e-04 3.3479926e-04 3.3444600e-04
#  3.2691762e-04 3.1622336e-04 5.7454687e-11 5.9185185e-11 6.3540458e-11]
# Closed trade at step 4997
# ------------------------------> Trade outcome: 90.60000000000582
# Reward: 1.5
# Step: 4997
# Open Position: 0
# Trades: 820 | Profit/Loss: 16956.77
# Balance: 116956.77
# Winning Trades: 453 | Losing Trades: 367
# Overall Rewards: 55.60
# date                2021-03-13 09:00:00
# open                            57434.3
# high                           57614.52
# low                            57253.31
# close                          57610.77
# volume usdt                   104898332
# tradecount                        62926
# hour                                  9
# day                                   6
# ema_13                     57052.431911
# ema_25                      56928.81194
# ema_32                     56860.385356
# ema_100                    55574.277107
# ema_200                    53755.260797
# vol_close                       0.00627
# vol_close_ema_3                0.008015
# vol_close_ema_6                0.008973
# vol_close_ema_12               0.010098
# Name: 4997, dtype: object
# Episode: 4996, Step: 4997, Action: 2, Observation: [5.4752349e-04 5.4924149e-04 5.4579804e-04 5.4920575e-04 1.0000000e+00
#  8.5797360e-08 5.7198239e-08 5.4388313e-04 5.4270466e-04 5.4205232e-04
#  5.2979181e-04 5.1245105e-04 7.6405396e-11 8.5536259e-11 9.6260735e-11]
# Opened trade at step 4998 with position size: 5847.84
# Reward: 0
# Step: 4998
# Open Position: 1
# Trades: 821 | Profit/Loss: 16956.77
# Balance: 116956.77
# Winning Trades: 453 | Losing Trades: 367
# Overall Rewards: 55.60
# date                2021-03-13 10:00:00
# open                           57610.77
# high                            59850.0
# low                            57446.81
# close                          59448.19
# volume usdt                   750024014
# tradecount                       308276
# hour                                 10
# day                                   6
# ema_13                     57394.683066
# ema_25                     57122.610252
# ema_32                     57017.222001
# ema_100                    55650.988253
# ema_200                    53811.906858
# vol_close                      0.040425
# vol_close_ema_3                 0.02422
# vol_close_ema_6                0.017959
# vol_close_ema_12               0.014763
# Name: 4998, dtype: object
# Episode: 4997, Step: 4998, Action: 1, Observation: [7.6811899e-05 7.9797450e-05 7.6593293e-05 7.9261721e-05 1.0000000e+00
#  1.3332906e-08 7.9997440e-09 7.6523793e-05 7.6161043e-05 7.6020529e-05
#  7.4198942e-05 7.1746916e-05 3.2292131e-11 2.3944558e-11 1.9683822e-11]
# Reward: 0
# Step: 4999
# Open Position: 1
# Trades: 821 | Profit/Loss: 16956.77
# Balance: 116956.77
# Winning Trades: 453 | Losing Trades: 367
# Overall Rewards: 55.60
# date                2021-03-13 11:00:00
# open                            59448.2
# high                            60200.0
# low                            59420.99
# close                          59849.74
# volume usdt                   544708721
# tradecount                       230042
# hour                                 11
# day                                   6
# ema_13                     57745.405485
# ema_25                     57332.389463
# ema_32                     57188.889758
# ema_100                    55734.131852
# ema_200                      53871.9848
# vol_close                      0.013016
# vol_close_ema_3                0.018618
# vol_close_ema_6                0.016547
# vol_close_ema_12               0.014495
# Name: 4999, dtype: object
# Episode: 4998, Step: 4999, Action: 1, Observation: [1.0913759e-04 1.1051778e-04 1.0908764e-04 1.0987475e-04 1.0000000e+00
#  2.0194278e-08 1.1015061e-08 1.0601153e-04 1.0525330e-04 1.0498986e-04
#  1.0231914e-04 9.8900535e-05 3.4179708e-11 3.0377222e-11 2.6609692e-11]
# Reward: 0
# Step: 5000
# Open Position: 1
# Trades: 821 | Profit/Loss: 16956.77
# Balance: 116956.77
# Winning Trades: 453 | Losing Trades: 367
# Overall Rewards: 55.60
# date                2021-03-13 12:00:00
# open                           59853.58
# high                            60500.0
# low                            59232.53
# close                          59911.99
# volume usdt                   352958745
# tradecount                       152578
# hour                                 12
# day                                   6
# ema_13                     58054.917559
# ema_25                     57530.820274
# ema_32                     57353.926137
# ema_100                    55816.861716
# ema_200                    53932.084354
# vol_close                      0.021156
# vol_close_ema_3                0.019887
# vol_close_ema_6                0.017864
# vol_close_ema_12               0.015519
# Name: 5000, dtype: object
# Episode: 4999, Step: 5000, Action: 1, Observation: [1.6957670e-04 1.7140813e-04 1.6781715e-04 1.6974218e-04 1.0000000e+00
#  3.3998308e-08 1.6999154e-08 1.6448075e-04 1.6299587e-04 1.6249470e-04
#  1.5813990e-04 1.5279997e-04 5.6343010e-11 5.0610831e-11 4.3969165e-11]
# Episode 5000: Final Rewards: 55.60 | Total Trades: 821

# %% [markdown]
# ### Thank you for taking the time to go through my notebook
